# %%
import pandas as pd

# %%
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('train.csv')

# %%
df = pd.read_csv('train.csv')
X_train, X_test, Y_train, Y_test = train_test_split(df['x'], df['y'], test_size = .2 )

# %%
X_train.head()
# Out:
# 662    35.0
# 196     4.0
# 571    35.0
# 119    70.0
# 618    46.0
# Name: x, dtype: float64

# %%
Y_train.head()
# Out:
# 333    50.0
# 165    73.0
# 143    25.0
# 583    10.0
# 65     50.0
# Name: y, dtype: float64

# %%
df = df.dropna()

# %%
df
# Out:
#         x          y
# 0    24.0  21.549452
# 1    50.0  47.464463
# 2    15.0  17.218656
# 3    38.0  36.586398
# 4    87.0  87.288984
# ..    ...        ...
# 695  58.0  58.595006
# 696  93.0  94.625094
# 697  82.0  88.603770
# 698  66.0  63.648685
# 699  97.0  94.975266
#
# [699 rows x 2 columns]

# %%
! pip install tensorflow

# %%
# !pip install sklearn

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense
from sklearn.metrics import accuracy_score

# %%
X_train, X_test, Y_train, Y_test = train_test_split(df['x'], df['y'], test_size = .2 )

X_train = X_train.astype(int)
Y_train = Y_train.astype(int)
X_test = X_test.astype(int)
Y_test = X_test.astype(int)

model = Sequential()
model.add(Dense(units = 32, kernel_initializer='normal', activation = 'relu', input_dim = 1))
#model.add(Dense(units = 64, activation = 'relu'))
#model.add(Dense(units = 1, activation = ''))

# %%
model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = 'accuracy')

# %%
model.fit(X_train, Y_train, epochs = 100 , batch_size=1)
# Out:
# Epoch 1/100
# 559/559 [==============================] - 1s 2ms/step - loss: 11.8879 - accuracy: 0.0089
# Epoch 2/100
# 559/559 [==============================] - 1s 2ms/step - loss: 11.8777 - accuracy: 0.0107
# Epoch 3/100
# 559/559 [==============================] - 1s 2ms/step - loss: 11.8722 - accuracy: 0.0107
# Epoch 4/100
# 559/559 [==============================] - 1s 2ms/step - loss: 11.9106 - accuracy: 0.0107
# Epoch 5/100
# 559/559 [==============================] - 1s 1ms/step - loss: 11.9066 - accuracy: 0.0125
# Epoch 6/100
# 559/559 [==============================] - 1s 2ms/step - loss: 11.8934 - accuracy: 0.0125
# Epoch 7/100
# 559/559 [==============================] - 1s 2ms/step - loss: 11.8857 - accuracy: 0.0125
# Epoch 8/100
# 559/559 [==============================] - 1s 2ms/step - loss: 11.8851 - accuracy: 0.0125
# Epoch 9/100
# 559/559 [==============================] - 1s 2ms/step - loss: 11.8776 - accuracy: 0.0125
# Epoch 10/100
# ...

# %%
len(X_train)
# Out:
# 559

# %%
len(Y_train)
# Out:
# 560

# %%
Y_result = model.predict(X_test)
# Out:
# 5/5 [==============================] - 0s 3ms/step

# %%
accuracy_score(Y_test, Y_result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [165], in <cell line: 1>()
# ----> 1 accuracy_score(Y_test, Y_result)
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:211, in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     145 """Accuracy classification score.
#     146
#     147 In multilabel classification, this function computes subset accuracy:
#    (...)
#     207 0.5
#     208 """
#     210 # Compute accuracy for each possible representation
# --> 211 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     212 check_consistent_length(y_true, y_pred, sample_weight)
#     213 if y_type.startswith("multilabel"):
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:93, in _check_targets(y_true, y_pred)
#      90     y_type = {"multiclass"}
#      92 if len(y_type) > 1:
# ---> 93     raise ValueError(
# ...

# %%
X_train, X_test, Y_train, Y_test = train_test_split(df['x'], df['y'], test_size = .2 )

X_train = X_train.astype(float)
Y_train = Y_train.astype(float)
X_test = X_test.astype(float)
Y_test = X_test.astype(float)

model=Sequential()
model.add(Dense(units=1,kernel_initializer='normal', activation='relu',input_dim=1))
# model.add(Dense(units=64, activation='relu'))
# model.add(Dense(units=1 , activation='linear'))
model.compile(loss='mean_squared_error', optimizer='adam' , metrics=['accuracy'])
model.fit(X_train, Y_train, epochs=200, batch_size=32)
# Out:
# Epoch 1/200
# 18/18 [==============================] - 1s 2ms/step - loss: 76339160.0000 - accuracy: 0.0125
# Epoch 2/200
# 18/18 [==============================] - 0s 3ms/step - loss: 25580.7988 - accuracy: 0.0143
# Epoch 3/200
# 18/18 [==============================] - 0s 3ms/step - loss: 25580.7988 - accuracy: 0.0143
# Epoch 4/200
# 18/18 [==============================] - 0s 3ms/step - loss: 25580.7988 - accuracy: 0.0143
# Epoch 5/200
# 18/18 [==============================] - 0s 2ms/step - loss: 25580.7988 - accuracy: 0.0143
# Epoch 6/200
# 18/18 [==============================] - 0s 3ms/step - loss: 25580.7988 - accuracy: 0.0143
# Epoch 7/200
# 18/18 [==============================] - 0s 2ms/step - loss: 25580.7988 - accuracy: 0.0143
# Epoch 8/200
# 18/18 [==============================] - 0s 4ms/step - loss: 25580.7988 - accuracy: 0.0143
# Epoch 9/200
# 18/18 [==============================] - 0s 2ms/step - loss: 25580.7988 - accuracy: 0.0143
# Epoch 10/200
# ...

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv')
plt.plot(df['x'], df['y'])
plt.show()

# %%
df
# Out:
#         x     y
# 0    24.0  24.0
# 1    50.0  50.0
# 2    15.0  15.0
# 3    38.0  38.0
# 4    87.0  87.0
# ..    ...   ...
# 695  58.0  58.0
# 696  93.0  93.0
# 697  82.0  82.0
# 698  66.0  66.0
# 699  97.0  97.0
#
# [700 rows x 2 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
X = df.iloc[:,0].values.reshape(-1,1)
Y = df.iloc[:,0].values.reshape(-1,1)
model.fit(X = X, y = Y)
# Out:
# LinearRegression()
