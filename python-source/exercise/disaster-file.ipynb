# %%
import pandas as pd

# %%
sheet_name = "수난"
df = pd.read_excel("2020년 지자체 사고 8종 마이크로데이터-수난.xlsx", sheet_name = "수난")
df
# Out:
#        no.       신고년월일   월   신고시각   시간 분류   발생장소_시   발생장소_구 발생장소_동 발생장소_리  \
# 0        1  2020-01-01   1  00:54  00~03시     충청남도      서산시    부석면   간월도리
# 1        2  2020-01-01   1  02:00  00~03시     전라남도      보성군    회천면    동율리
# 2        3  2020-01-01   1  07:19  06~09시      강원도      양양군    현남면    인구리
# 3        4  2020-01-01   1  07:21  06~09시     경상남도      거제시    사등면    사등리
# 4        5  2020-01-01   1  07:25  06~09시     전라남도      영광군    염산면    두우리
# ...    ...         ...  ..    ...     ...      ...      ...    ...    ...
# 7394  7395  2020-12-30  12  17:42  15~18시  제주특별자치도      제주시     연동     연동
# 7395  7396  2020-12-31  12  06:51  06~09시     경상북도      문경시    동로면    노은리
# 7396  7397  2020-12-31  12  13:15  12~15시      경기도  고양시 덕양구   행주외동   행주외동
# 7397  7398  2020-12-31  12  14:52  12~15시      경기도     동두천시    생연동    생연동
# 7398  7399  2020-12-31  12  20:44  18~21시    인천광역시       중구    을왕동    을왕동
#
#          발생장소 구분  세부 유형   교량 도로(지면) 등 시설물/건축물 차량 등 기타미상  사망자수  부상자수
# 0         하천, 바다   기타미상  NaN      NaN     NaN  NaN  NaN     0     1
# 1         하천, 바다   기타미상  NaN      NaN     NaN  NaN  NaN     0     0
# 2         하천, 바다   기타미상  NaN      NaN     NaN  NaN  NaN     0     0
# 3         하천, 바다  실족/추락  NaN      NaN     NaN    ㅇ  NaN     2     0
# 4         하천, 바다  실족/추락  NaN      NaN     NaN    ㅇ  NaN     0     0
# ...          ...    ...  ...      ...     ...  ...  ...   ...   ...
# 7394  다중이용(복합)시설  시설물침수  NaN      NaN       ㅇ  NaN  NaN     0     0
# 7395      하천, 바다  실족/추락  NaN      NaN     NaN    ㅇ  NaN     1     0
# 7396      하천, 바다   기타미상  NaN      NaN     NaN  NaN  NaN     0     0
# 7397      하천, 바다   기타미상  NaN      NaN     NaN  NaN  NaN     0     1
# 7398      하천, 바다   기타미상  NaN      NaN     NaN  NaN  NaN     0     0
#
# [7399 rows x 18 columns]

# %%
df= df.iloc[:,[1,2,3,4,5,16,17]]
df
# Out:
#            신고년월일   월   신고시각   시간 분류   발생장소_시  사망자수  부상자수
# 0     2020-01-01   1  00:54  00~03시     충청남도     0     1
# 1     2020-01-01   1  02:00  00~03시     전라남도     0     0
# 2     2020-01-01   1  07:19  06~09시      강원도     0     0
# 3     2020-01-01   1  07:21  06~09시     경상남도     2     0
# 4     2020-01-01   1  07:25  06~09시     전라남도     0     0
# ...          ...  ..    ...     ...      ...   ...   ...
# 7394  2020-12-30  12  17:42  15~18시  제주특별자치도     0     0
# 7395  2020-12-31  12  06:51  06~09시     경상북도     1     0
# 7396  2020-12-31  12  13:15  12~15시      경기도     0     0
# 7397  2020-12-31  12  14:52  12~15시      경기도     0     1
# 7398  2020-12-31  12  20:44  18~21시    인천광역시     0     0
#
# [7399 rows x 7 columns]

# %%
df['위험도'] = (df.사망자수*2 + df.부상자수 +1)
df
# Out:
# C:\Users\seoye\AppData\Local\Temp\ipykernel_12000\3955662879.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['위험도'] = (df.사망자수*2 + df.부상자수 +1)
#            신고년월일   월   신고시각   시간 분류   발생장소_시  사망자수  부상자수  위험도
# 0     2020-01-01   1  00:54  00~03시     충청남도     0     1    2
# 1     2020-01-01   1  02:00  00~03시     전라남도     0     0    1
# 2     2020-01-01   1  07:19  06~09시      강원도     0     0    1
# 3     2020-01-01   1  07:21  06~09시     경상남도     2     0    5
# 4     2020-01-01   1  07:25  06~09시     전라남도     0     0    1
# ...          ...  ..    ...     ...      ...   ...   ...  ...
# 7394  2020-12-30  12  17:42  15~18시  제주특별자치도     0     0    1
# 7395  2020-12-31  12  06:51  06~09시     경상북도     1     0    3
# 7396  2020-12-31  12  13:15  12~15시      경기도     0     0    1
# 7397  2020-12-31  12  14:52  12~15시      경기도     0     1    2
# 7398  2020-12-31  12  20:44  18~21시    인천광역시     0     0    1
#
# [7399 rows x 8 columns]

# %%
! pip install snscrape
# Out:
# Collecting snscrape
#   Using cached snscrape-0.4.3.20220106-py3-none-any.whl (59 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\seoye\anaconda3\lib\site-packages (from snscrape) (4.11.1)
# Requirement already satisfied: filelock in c:\users\seoye\anaconda3\lib\site-packages (from snscrape) (3.6.0)
# Requirement already satisfied: requests[socks] in c:\users\seoye\anaconda3\lib\site-packages (from snscrape) (2.27.1)
# Requirement already satisfied: lxml in c:\users\seoye\anaconda3\lib\site-packages (from snscrape) (4.8.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\seoye\anaconda3\lib\site-packages (from beautifulsoup4->snscrape) (2.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\seoye\anaconda3\lib\site-packages (from requests[socks]->snscrape) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\seoye\anaconda3\lib\site-packages (from requests[socks]->snscrape) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\seoye\anaconda3\lib\site-packages (from requests[socks]->snscrape) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\seoye\anaconda3\lib\site-packages (from requests[socks]->snscrape) (2021.10.8)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\seoye\anaconda3\lib\site-packages (from requests[socks]->snscrape) (1.7.1)
# Installing collected packages: snscrape
# Successfully installed snscrape-0.4.3.20220106

# %%
import snscrape.modules.twitter as sntwitter
from datetime import datetime,timedelta
date_format = '%Y-%m-%d'
target_list = []
search_date = ''
tweet_read =[]
check_row=0
for index, disaster in df.iterrows():
    from_time = int(disaster[3][0:2])
    to_time = int (disaster[3][3:5])
    since_date = datetime.strptime(disaster[0],date_format)
    until_date = since_date + timedelta(days=1)
    print(since_date)
    print(until_date)
    if check_row % 10 == 0:
        print("current row=" +str(check_row))
    query = '태풍 since:'+since_date.strftime('%Y-%m-%d')+' until:' +until_date.strftime('%Y-%m-%d')
    if search_date != since_date:
        search_date =since_date
        tweet_read = []
        for tweet in sntwitter.TwitterSearchScraper(query).get_items():
            #print(vars(tweet))
            tweet_hour = tweet.date.hour
            if tweet_hour >= from_time and tweet_hour <= to_time:
                list = [disaster[0], disaster[1], disaster[2], disaster[3], disaster[4], disaster[5], disaster[6], disaster[7], tweet.content]
                target_list.append(list)
    else:
        for tweet in tweet_read:
            tweet_hour = tweet.date.hour
            if tweet_hour >= from_time and tweet_hour <= to_time:
                list = [disaster[0], disaster[1], disaster[2], disaster[3], disaster[4], disaster[5], disaster[6], disaster[7], tweet.content]
                target_list.append(list)
    check_row = check_row+1
            
target_df = pd.DataFrame(target_list, columns = ['신고년월일', '월', '신고시각', '시간분류', '발생장소','사망자수', '부상자수', '위험도', '트윗'])
target_df
# Out:
# 2020-01-01 00:00:00
# 2020-01-02 00:00:00
# current row=0
# 2020-01-01 00:00:00
# 2020-01-02 00:00:00
# 2020-01-01 00:00:00
# 2020-01-02 00:00:00
# 2020-01-01 00:00:00
# 2020-01-02 00:00:00
# 2020-01-01 00:00:00
# 2020-01-02 00:00:00
# 2020-01-01 00:00:00
# 2020-01-02 00:00:00
# 2020-01-01 00:00:00
# 2020-01-02 00:00:00
# 2020-01-01 00:00:00
# 2020-01-02 00:00:00
# 2020-01-01 00:00:00
# 2020-01-02 00:00:00
# 2020-01-01 00:00:00
# 2020-01-02 00:00:00
# 2020-01-01 00:00:00
# 2020-01-02 00:00:00
# current row=10
# 2020-01-01 00:00:00
# 2020-01-02 00:00:00
# 2020-01-02 00:00:00
# 2020-01-03 00:00:00
# 2020-01-02 00:00:00
# 2020-01-03 00:00:00
# 2020-01-02 00:00:00
# 2020-01-03 00:00:00
# 2020-01-02 00:00:00
# 2020-01-03 00:00:00
# 2020-01-02 00:00:00
# 2020-01-03 00:00:00
# 2020-01-02 00:00:00
# 2020-01-03 00:00:00
# 2020-01-02 00:00:00
# 2020-01-03 00:00:00
# 2020-01-02 00:00:00
# 2020-01-03 00:00:00
# 2020-01-02 00:00:00
# 2020-01-03 00:00:00
# current row=20
# 2020-01-02 00:00:00
# 2020-01-03 00:00:00
# 2020-01-02 00:00:00
# 2020-01-03 00:00:00
# 2020-01-02 00:00:00
# 2020-01-03 00:00:00
# 2020-01-02 00:00:00
# 2020-01-03 00:00:00
# 2020-01-03 00:00:00
# 2020-01-04 00:00:00
# 2020-01-03 00:00:00
# 2020-01-04 00:00:00
# 2020-01-03 00:00:00
# 2020-01-04 00:00:00
# 2020-01-03 00:00:00
# 2020-01-04 00:00:00
# 2020-01-03 00:00:00
# 2020-01-04 00:00:00
# 2020-01-03 00:00:00
# 2020-01-04 00:00:00
# current row=30
# 2020-01-03 00:00:00
# 2020-01-04 00:00:00
# 2020-01-03 00:00:00
# 2020-01-04 00:00:00
# 2020-01-03 00:00:00
# 2020-01-04 00:00:00
# 2020-01-04 00:00:00
# 2020-01-05 00:00:00
# 2020-01-04 00:00:00
# 2020-01-05 00:00:00
# 2020-01-04 00:00:00
# 2020-01-05 00:00:00
# 2020-01-05 00:00:00
# 2020-01-06 00:00:00
# 2020-01-05 00:00:00
# 2020-01-06 00:00:00
# 2020-01-05 00:00:00
# 2020-01-06 00:00:00
# 2020-01-05 00:00:00
# 2020-01-06 00:00:00
# current row=40
# 2020-01-05 00:00:00
# 2020-01-06 00:00:00
# 2020-01-05 00:00:00
# 2020-01-06 00:00:00
# 2020-01-05 00:00:00
# 2020-01-06 00:00:00
# 2020-01-06 00:00:00
# 2020-01-07 00:00:00
# 2020-01-06 00:00:00
# 2020-01-07 00:00:00
# 2020-01-06 00:00:00
# 2020-01-07 00:00:00
# 2020-01-06 00:00:00
# 2020-01-07 00:00:00
# 2020-01-07 00:00:00
# 2020-01-08 00:00:00
# 2020-01-07 00:00:00
# 2020-01-08 00:00:00
# 2020-01-07 00:00:00
# 2020-01-08 00:00:00
# current row=50
# 2020-01-07 00:00:00
# 2020-01-08 00:00:00
# 2020-01-07 00:00:00
# 2020-01-08 00:00:00
# 2020-01-07 00:00:00
# 2020-01-08 00:00:00
# 2020-01-07 00:00:00
# 2020-01-08 00:00:00
# 2020-01-07 00:00:00
# 2020-01-08 00:00:00
# 2020-01-07 00:00:00
# 2020-01-08 00:00:00
# 2020-01-07 00:00:00
# 2020-01-08 00:00:00
# 2020-01-07 00:00:00
# 2020-01-08 00:00:00
# 2020-01-07 00:00:00
# 2020-01-08 00:00:00
# 2020-01-07 00:00:00
# 2020-01-08 00:00:00
# current row=60
# 2020-01-07 00:00:00
# 2020-01-08 00:00:00
# 2020-01-07 00:00:00
# 2020-01-08 00:00:00
# 2020-01-08 00:00:00
# 2020-01-09 00:00:00
# 2020-01-08 00:00:00
# 2020-01-09 00:00:00
# 2020-01-08 00:00:00
# 2020-01-09 00:00:00
# 2020-01-08 00:00:00
# 2020-01-09 00:00:00
# 2020-01-08 00:00:00
# 2020-01-09 00:00:00
# 2020-01-08 00:00:00
# 2020-01-09 00:00:00
# 2020-01-08 00:00:00
# 2020-01-09 00:00:00
# 2020-01-08 00:00:00
# 2020-01-09 00:00:00
# current row=70
# 2020-01-08 00:00:00
# 2020-01-09 00:00:00
# 2020-01-08 00:00:00
# 2020-01-09 00:00:00
# 2020-01-08 00:00:00
# 2020-01-09 00:00:00
# 2020-01-08 00:00:00
# 2020-01-09 00:00:00
# 2020-01-08 00:00:00
# 2020-01-09 00:00:00
# 2020-01-09 00:00:00
# 2020-01-10 00:00:00
# 2020-01-09 00:00:00
# 2020-01-10 00:00:00
# 2020-01-09 00:00:00
# 2020-01-10 00:00:00
# 2020-01-09 00:00:00
# 2020-01-10 00:00:00
# 2020-01-09 00:00:00
# 2020-01-10 00:00:00
# current row=80
# 2020-01-10 00:00:00
# 2020-01-11 00:00:00
# 2020-01-10 00:00:00
# 2020-01-11 00:00:00
# 2020-01-10 00:00:00
# 2020-01-11 00:00:00
# 2020-01-10 00:00:00
# 2020-01-11 00:00:00
# 2020-01-10 00:00:00
# 2020-01-11 00:00:00
# 2020-01-10 00:00:00
# 2020-01-11 00:00:00
# 2020-01-11 00:00:00
# 2020-01-12 00:00:00
# 2020-01-11 00:00:00
# 2020-01-12 00:00:00
# 2020-01-11 00:00:00
# 2020-01-12 00:00:00
# 2020-01-11 00:00:00
# 2020-01-12 00:00:00
# current row=90
# 2020-01-11 00:00:00
# 2020-01-12 00:00:00
# 2020-01-11 00:00:00
# 2020-01-12 00:00:00
# 2020-01-11 00:00:00
# 2020-01-12 00:00:00
# 2020-01-11 00:00:00
# 2020-01-12 00:00:00
# 2020-01-11 00:00:00
# 2020-01-12 00:00:00
# 2020-01-11 00:00:00
# 2020-01-12 00:00:00
# 2020-01-12 00:00:00
# 2020-01-13 00:00:00
# 2020-01-12 00:00:00
# 2020-01-13 00:00:00
# 2020-01-12 00:00:00
# 2020-01-13 00:00:00
# 2020-01-12 00:00:00
# 2020-01-13 00:00:00
# current row=100
# 2020-01-12 00:00:00
# 2020-01-13 00:00:00
# 2020-01-12 00:00:00
# 2020-01-13 00:00:00
# 2020-01-12 00:00:00
# 2020-01-13 00:00:00
# 2020-01-12 00:00:00
# 2020-01-13 00:00:00
# 2020-01-12 00:00:00
# 2020-01-13 00:00:00
# 2020-01-12 00:00:00
# 2020-01-13 00:00:00
# 2020-01-12 00:00:00
# 2020-01-13 00:00:00
# 2020-01-12 00:00:00
# 2020-01-13 00:00:00
# 2020-01-12 00:00:00
# 2020-01-13 00:00:00
# 2020-01-13 00:00:00
# 2020-01-14 00:00:00
# current row=110
# 2020-01-13 00:00:00
# 2020-01-14 00:00:00
# 2020-01-14 00:00:00
# 2020-01-15 00:00:00
# 2020-01-14 00:00:00
# 2020-01-15 00:00:00
# 2020-01-14 00:00:00
# 2020-01-15 00:00:00
# 2020-01-14 00:00:00
# 2020-01-15 00:00:00
# 2020-01-14 00:00:00
# 2020-01-15 00:00:00
# 2020-01-14 00:00:00
# 2020-01-15 00:00:00
# 2020-01-14 00:00:00
# 2020-01-15 00:00:00
# 2020-01-14 00:00:00
# 2020-01-15 00:00:00
# 2020-01-14 00:00:00
# 2020-01-15 00:00:00
# current row=120
# 2020-01-14 00:00:00
# 2020-01-15 00:00:00
# 2020-01-15 00:00:00
# 2020-01-16 00:00:00
# 2020-01-15 00:00:00
# 2020-01-16 00:00:00
# 2020-01-15 00:00:00
# 2020-01-16 00:00:00
# 2020-01-15 00:00:00
# 2020-01-16 00:00:00
# 2020-01-16 00:00:00
# 2020-01-17 00:00:00
# 2020-01-16 00:00:00
# 2020-01-17 00:00:00
# 2020-01-16 00:00:00
# 2020-01-17 00:00:00
# 2020-01-16 00:00:00
# 2020-01-17 00:00:00
# 2020-01-16 00:00:00
# 2020-01-17 00:00:00
# current row=130
# 2020-01-17 00:00:00
# 2020-01-18 00:00:00
# 2020-01-17 00:00:00
# 2020-01-18 00:00:00
# 2020-01-17 00:00:00
# 2020-01-18 00:00:00
# 2020-01-17 00:00:00
# 2020-01-18 00:00:00
# 2020-01-17 00:00:00
# 2020-01-18 00:00:00
# 2020-01-18 00:00:00
# 2020-01-19 00:00:00
# 2020-01-18 00:00:00
# 2020-01-19 00:00:00
# 2020-01-18 00:00:00
# 2020-01-19 00:00:00
# 2020-01-18 00:00:00
# 2020-01-19 00:00:00
# 2020-01-18 00:00:00
# 2020-01-19 00:00:00
# current row=140
# 2020-01-18 00:00:00
# 2020-01-19 00:00:00
# 2020-01-19 00:00:00
# 2020-01-20 00:00:00
# 2020-01-19 00:00:00
# 2020-01-20 00:00:00
# 2020-01-19 00:00:00
# 2020-01-20 00:00:00
# 2020-01-19 00:00:00
# 2020-01-20 00:00:00
# 2020-01-19 00:00:00
# 2020-01-20 00:00:00
# 2020-01-19 00:00:00
# 2020-01-20 00:00:00
# 2020-01-19 00:00:00
# 2020-01-20 00:00:00
# 2020-01-20 00:00:00
# 2020-01-21 00:00:00
# 2020-01-20 00:00:00
# 2020-01-21 00:00:00
# current row=150
# 2020-01-20 00:00:00
# 2020-01-21 00:00:00
# 2020-01-20 00:00:00
# 2020-01-21 00:00:00
# 2020-01-20 00:00:00
# 2020-01-21 00:00:00
# 2020-01-20 00:00:00
# 2020-01-21 00:00:00
# 2020-01-20 00:00:00
# 2020-01-21 00:00:00
# 2020-01-20 00:00:00
# 2020-01-21 00:00:00
# 2020-01-20 00:00:00
# 2020-01-21 00:00:00
# 2020-01-21 00:00:00
# 2020-01-22 00:00:00
# 2020-01-21 00:00:00
# 2020-01-22 00:00:00
# 2020-01-21 00:00:00
# 2020-01-22 00:00:00
# current row=160
# 2020-01-21 00:00:00
# 2020-01-22 00:00:00
# 2020-01-21 00:00:00
# 2020-01-22 00:00:00
# 2020-01-21 00:00:00
# 2020-01-22 00:00:00
# 2020-01-21 00:00:00
# 2020-01-22 00:00:00
# 2020-01-22 00:00:00
# 2020-01-23 00:00:00
# 2020-01-22 00:00:00
# 2020-01-23 00:00:00
# 2020-01-22 00:00:00
# 2020-01-23 00:00:00
# 2020-01-23 00:00:00
# 2020-01-24 00:00:00
# 2020-01-23 00:00:00
# 2020-01-24 00:00:00
# 2020-01-23 00:00:00
# 2020-01-24 00:00:00
# current row=170
# 2020-01-23 00:00:00
# 2020-01-24 00:00:00
# 2020-01-23 00:00:00
# 2020-01-24 00:00:00
# 2020-01-24 00:00:00
# 2020-01-25 00:00:00
# 2020-01-24 00:00:00
# 2020-01-25 00:00:00
# 2020-01-24 00:00:00
# 2020-01-25 00:00:00
# 2020-01-24 00:00:00
# 2020-01-25 00:00:00
# 2020-01-24 00:00:00
# 2020-01-25 00:00:00
# 2020-01-24 00:00:00
# 2020-01-25 00:00:00
# 2020-01-24 00:00:00
# 2020-01-25 00:00:00
# 2020-01-24 00:00:00
# 2020-01-25 00:00:00
# current row=180
# 2020-01-24 00:00:00
# 2020-01-25 00:00:00
# 2020-01-24 00:00:00
# 2020-01-25 00:00:00
# 2020-01-25 00:00:00
# 2020-01-26 00:00:00
# 2020-01-25 00:00:00
# 2020-01-26 00:00:00
# 2020-01-25 00:00:00
# 2020-01-26 00:00:00
# 2020-01-25 00:00:00
# 2020-01-26 00:00:00
# 2020-01-25 00:00:00
# 2020-01-26 00:00:00
# 2020-01-25 00:00:00
# 2020-01-26 00:00:00
# 2020-01-25 00:00:00
# 2020-01-26 00:00:00
# 2020-01-25 00:00:00
# 2020-01-26 00:00:00
# current row=190
# 2020-01-25 00:00:00
# 2020-01-26 00:00:00
# 2020-01-25 00:00:00
# 2020-01-26 00:00:00
# 2020-01-25 00:00:00
# 2020-01-26 00:00:00
# 2020-01-25 00:00:00
# 2020-01-26 00:00:00
# 2020-01-26 00:00:00
# 2020-01-27 00:00:00
# 2020-01-26 00:00:00
# 2020-01-27 00:00:00
# 2020-01-26 00:00:00
# 2020-01-27 00:00:00
# 2020-01-26 00:00:00
# 2020-01-27 00:00:00
# 2020-01-27 00:00:00
# 2020-01-28 00:00:00
# 2020-01-27 00:00:00
# 2020-01-28 00:00:00
# current row=200
# 2020-01-27 00:00:00
# 2020-01-28 00:00:00
# 2020-01-27 00:00:00
# 2020-01-28 00:00:00
# 2020-01-27 00:00:00
# 2020-01-28 00:00:00
# 2020-01-27 00:00:00
# 2020-01-28 00:00:00
# 2020-01-27 00:00:00
# 2020-01-28 00:00:00
# 2020-01-27 00:00:00
# 2020-01-28 00:00:00
# 2020-01-27 00:00:00
# 2020-01-28 00:00:00
# 2020-01-27 00:00:00
# 2020-01-28 00:00:00
# 2020-01-27 00:00:00
# 2020-01-28 00:00:00
# 2020-01-28 00:00:00
# 2020-01-29 00:00:00
# current row=210
# 2020-01-28 00:00:00
# 2020-01-29 00:00:00
# 2020-01-28 00:00:00
# 2020-01-29 00:00:00
# 2020-01-28 00:00:00
# 2020-01-29 00:00:00
# 2020-01-28 00:00:00
# 2020-01-29 00:00:00
# 2020-01-28 00:00:00
# 2020-01-29 00:00:00
# 2020-01-28 00:00:00
# 2020-01-29 00:00:00
# 2020-01-29 00:00:00
# 2020-01-30 00:00:00
# 2020-01-29 00:00:00
# 2020-01-30 00:00:00
# 2020-01-29 00:00:00
# 2020-01-30 00:00:00
# 2020-01-29 00:00:00
# 2020-01-30 00:00:00
# current row=220
# 2020-01-29 00:00:00
# 2020-01-30 00:00:00
# 2020-01-29 00:00:00
# 2020-01-30 00:00:00
# 2020-01-29 00:00:00
# 2020-01-30 00:00:00
# 2020-01-29 00:00:00
# 2020-01-30 00:00:00
# 2020-01-29 00:00:00
# 2020-01-30 00:00:00
# 2020-01-30 00:00:00
# 2020-01-31 00:00:00
# 2020-01-30 00:00:00
# 2020-01-31 00:00:00
# 2020-01-30 00:00:00
# 2020-01-31 00:00:00
# 2020-01-30 00:00:00
# 2020-01-31 00:00:00
# 2020-01-30 00:00:00
# 2020-01-31 00:00:00
# current row=230
# 2020-01-31 00:00:00
# 2020-02-01 00:00:00
# 2020-01-31 00:00:00
# 2020-02-01 00:00:00
# 2020-01-31 00:00:00
# 2020-02-01 00:00:00
# 2020-01-31 00:00:00
# 2020-02-01 00:00:00
# 2020-02-01 00:00:00
# 2020-02-02 00:00:00
# 2020-02-01 00:00:00
# 2020-02-02 00:00:00
# 2020-02-01 00:00:00
# 2020-02-02 00:00:00
# 2020-02-01 00:00:00
# 2020-02-02 00:00:00
# 2020-02-01 00:00:00
# 2020-02-02 00:00:00
# 2020-02-02 00:00:00
# 2020-02-03 00:00:00
# current row=240
# 2020-02-02 00:00:00
# 2020-02-03 00:00:00
# 2020-02-03 00:00:00
# 2020-02-04 00:00:00
# 2020-02-03 00:00:00
# 2020-02-04 00:00:00
# 2020-02-03 00:00:00
# 2020-02-04 00:00:00
# 2020-02-03 00:00:00
# 2020-02-04 00:00:00
# 2020-02-03 00:00:00
# 2020-02-04 00:00:00
# 2020-02-03 00:00:00
# 2020-02-04 00:00:00
# 2020-02-03 00:00:00
# 2020-02-04 00:00:00
# 2020-02-03 00:00:00
# 2020-02-04 00:00:00
# 2020-02-03 00:00:00
# 2020-02-04 00:00:00
# current row=250
# 2020-02-04 00:00:00
# 2020-02-05 00:00:00
# 2020-02-04 00:00:00
# 2020-02-05 00:00:00
# 2020-02-04 00:00:00
# 2020-02-05 00:00:00
# 2020-02-04 00:00:00
# 2020-02-05 00:00:00
# 2020-02-04 00:00:00
# 2020-02-05 00:00:00
# 2020-02-05 00:00:00
# 2020-02-06 00:00:00
# 2020-02-05 00:00:00
# 2020-02-06 00:00:00
# 2020-02-05 00:00:00
# 2020-02-06 00:00:00
# 2020-02-05 00:00:00
# 2020-02-06 00:00:00
# 2020-02-06 00:00:00
# 2020-02-07 00:00:00
# current row=260
# 2020-02-06 00:00:00
# 2020-02-07 00:00:00
# 2020-02-06 00:00:00
# 2020-02-07 00:00:00
# 2020-02-06 00:00:00
# 2020-02-07 00:00:00
# 2020-02-06 00:00:00
# 2020-02-07 00:00:00
# 2020-02-07 00:00:00
# 2020-02-08 00:00:00
# 2020-02-07 00:00:00
# 2020-02-08 00:00:00
# 2020-02-07 00:00:00
# 2020-02-08 00:00:00
# 2020-02-07 00:00:00
# 2020-02-08 00:00:00
# 2020-02-07 00:00:00
# 2020-02-08 00:00:00
# 2020-02-07 00:00:00
# 2020-02-08 00:00:00
# current row=270
# 2020-02-07 00:00:00
# 2020-02-08 00:00:00
# 2020-02-08 00:00:00
# 2020-02-09 00:00:00
# 2020-02-08 00:00:00
# 2020-02-09 00:00:00
# 2020-02-08 00:00:00
# 2020-02-09 00:00:00
# 2020-02-08 00:00:00
# 2020-02-09 00:00:00
# 2020-02-08 00:00:00
# 2020-02-09 00:00:00
# 2020-02-08 00:00:00
# 2020-02-09 00:00:00
# 2020-02-08 00:00:00
# 2020-02-09 00:00:00
# 2020-02-08 00:00:00
# 2020-02-09 00:00:00
# 2020-02-09 00:00:00
# 2020-02-10 00:00:00
# current row=280
# 2020-02-09 00:00:00
# 2020-02-10 00:00:00
# 2020-02-09 00:00:00
# 2020-02-10 00:00:00
# 2020-02-09 00:00:00
# 2020-02-10 00:00:00
# 2020-02-09 00:00:00
# 2020-02-10 00:00:00
# 2020-02-09 00:00:00
# 2020-02-10 00:00:00
# 2020-02-09 00:00:00
# 2020-02-10 00:00:00
# 2020-02-09 00:00:00
# 2020-02-10 00:00:00
# 2020-02-09 00:00:00
# 2020-02-10 00:00:00
# 2020-02-09 00:00:00
# 2020-02-10 00:00:00
# 2020-02-09 00:00:00
# 2020-02-10 00:00:00
# current row=290
# 2020-02-09 00:00:00
# 2020-02-10 00:00:00
# 2020-02-09 00:00:00
# 2020-02-10 00:00:00
# 2020-02-10 00:00:00
# 2020-02-11 00:00:00
# 2020-02-10 00:00:00
# 2020-02-11 00:00:00
# 2020-02-10 00:00:00
# 2020-02-11 00:00:00
# 2020-02-10 00:00:00
# 2020-02-11 00:00:00
# 2020-02-10 00:00:00
# 2020-02-11 00:00:00
# 2020-02-11 00:00:00
# 2020-02-12 00:00:00
# 2020-02-11 00:00:00
# 2020-02-12 00:00:00
# 2020-02-11 00:00:00
# 2020-02-12 00:00:00
# current row=300
# 2020-02-11 00:00:00
# 2020-02-12 00:00:00
# 2020-02-11 00:00:00
# 2020-02-12 00:00:00
# 2020-02-11 00:00:00
# 2020-02-12 00:00:00
# 2020-02-11 00:00:00
# 2020-02-12 00:00:00
# 2020-02-12 00:00:00
# 2020-02-13 00:00:00
# 2020-02-12 00:00:00
# 2020-02-13 00:00:00
# 2020-02-12 00:00:00
# 2020-02-13 00:00:00
# 2020-02-12 00:00:00
# 2020-02-13 00:00:00
# 2020-02-12 00:00:00
# 2020-02-13 00:00:00
# 2020-02-12 00:00:00
# 2020-02-13 00:00:00
# current row=310
# 2020-02-12 00:00:00
# 2020-02-13 00:00:00
# 2020-02-12 00:00:00
# 2020-02-13 00:00:00
# 2020-02-12 00:00:00
# 2020-02-13 00:00:00
# 2020-02-12 00:00:00
# 2020-02-13 00:00:00
# 2020-02-12 00:00:00
# 2020-02-13 00:00:00
# 2020-02-13 00:00:00
# 2020-02-14 00:00:00
# 2020-02-13 00:00:00
# 2020-02-14 00:00:00
# 2020-02-13 00:00:00
# 2020-02-14 00:00:00
# 2020-02-13 00:00:00
# 2020-02-14 00:00:00
# 2020-02-13 00:00:00
# 2020-02-14 00:00:00
# current row=320
# 2020-02-13 00:00:00
# 2020-02-14 00:00:00
# 2020-02-13 00:00:00
# 2020-02-14 00:00:00
# 2020-02-13 00:00:00
# 2020-02-14 00:00:00
# 2020-02-13 00:00:00
# 2020-02-14 00:00:00
# 2020-02-14 00:00:00
# 2020-02-15 00:00:00
# 2020-02-14 00:00:00
# 2020-02-15 00:00:00
# 2020-02-14 00:00:00
# 2020-02-15 00:00:00
# 2020-02-14 00:00:00
# 2020-02-15 00:00:00
# 2020-02-14 00:00:00
# 2020-02-15 00:00:00
# 2020-02-14 00:00:00
# 2020-02-15 00:00:00
# current row=330
# 2020-02-14 00:00:00
# 2020-02-15 00:00:00
# 2020-02-14 00:00:00
# 2020-02-15 00:00:00
# 2020-02-14 00:00:00
# 2020-02-15 00:00:00
# 2020-02-15 00:00:00
# 2020-02-16 00:00:00
# 2020-02-15 00:00:00
# 2020-02-16 00:00:00
# 2020-02-15 00:00:00
# 2020-02-16 00:00:00
# 2020-02-15 00:00:00
# 2020-02-16 00:00:00
# 2020-02-15 00:00:00
# 2020-02-16 00:00:00
# 2020-02-15 00:00:00
# 2020-02-16 00:00:00
# 2020-02-15 00:00:00
# 2020-02-16 00:00:00
# current row=340
# 2020-02-15 00:00:00
# 2020-02-16 00:00:00
# 2020-02-16 00:00:00
# 2020-02-17 00:00:00
# 2020-02-16 00:00:00
# 2020-02-17 00:00:00
# 2020-02-16 00:00:00
# 2020-02-17 00:00:00
# 2020-02-16 00:00:00
# 2020-02-17 00:00:00
# 2020-02-16 00:00:00
# 2020-02-17 00:00:00
# 2020-02-16 00:00:00
# 2020-02-17 00:00:00
# 2020-02-16 00:00:00
# 2020-02-17 00:00:00
# 2020-02-16 00:00:00
# 2020-02-17 00:00:00
# 2020-02-16 00:00:00
# 2020-02-17 00:00:00
# current row=350
# 2020-02-16 00:00:00
# 2020-02-17 00:00:00
# 2020-02-16 00:00:00
# 2020-02-17 00:00:00
# 2020-02-16 00:00:00
# 2020-02-17 00:00:00
# 2020-02-16 00:00:00
# 2020-02-17 00:00:00
# 2020-02-17 00:00:00
# 2020-02-18 00:00:00
# 2020-02-17 00:00:00
# 2020-02-18 00:00:00
# 2020-02-17 00:00:00
# 2020-02-18 00:00:00
# 2020-02-17 00:00:00
# 2020-02-18 00:00:00
# 2020-02-17 00:00:00
# 2020-02-18 00:00:00
# 2020-02-17 00:00:00
# 2020-02-18 00:00:00
# current row=360
# 2020-02-17 00:00:00
# 2020-02-18 00:00:00
# 2020-02-18 00:00:00
# 2020-02-19 00:00:00
# 2020-02-18 00:00:00
# 2020-02-19 00:00:00
# 2020-02-18 00:00:00
# 2020-02-19 00:00:00
# 2020-02-18 00:00:00
# 2020-02-19 00:00:00
# 2020-02-18 00:00:00
# 2020-02-19 00:00:00
# 2020-02-18 00:00:00
# 2020-02-19 00:00:00
# 2020-02-19 00:00:00
# 2020-02-20 00:00:00
# 2020-02-19 00:00:00
# 2020-02-20 00:00:00
# 2020-02-19 00:00:00
# 2020-02-20 00:00:00
# current row=370
# 2020-02-19 00:00:00
# 2020-02-20 00:00:00
# 2020-02-19 00:00:00
# 2020-02-20 00:00:00
# 2020-02-19 00:00:00
# 2020-02-20 00:00:00
# 2020-02-19 00:00:00
# 2020-02-20 00:00:00
# 2020-02-19 00:00:00
# 2020-02-20 00:00:00
# 2020-02-19 00:00:00
# 2020-02-20 00:00:00
# 2020-02-19 00:00:00
# 2020-02-20 00:00:00
# 2020-02-20 00:00:00
# 2020-02-21 00:00:00
# 2020-02-20 00:00:00
# 2020-02-21 00:00:00
# 2020-02-20 00:00:00
# 2020-02-21 00:00:00
# current row=380
# 2020-02-20 00:00:00
# 2020-02-21 00:00:00
# 2020-02-20 00:00:00
# 2020-02-21 00:00:00
# 2020-02-20 00:00:00
# 2020-02-21 00:00:00
# 2020-02-20 00:00:00
# 2020-02-21 00:00:00
# 2020-02-20 00:00:00
# 2020-02-21 00:00:00
# 2020-02-20 00:00:00
# 2020-02-21 00:00:00
# 2020-02-20 00:00:00
# 2020-02-21 00:00:00
# 2020-02-21 00:00:00
# 2020-02-22 00:00:00
# 2020-02-21 00:00:00
# 2020-02-22 00:00:00
# 2020-02-21 00:00:00
# 2020-02-22 00:00:00
# current row=390
# 2020-02-21 00:00:00
# 2020-02-22 00:00:00
# 2020-02-21 00:00:00
# 2020-02-22 00:00:00
# 2020-02-21 00:00:00
# 2020-02-22 00:00:00
# 2020-02-21 00:00:00
# 2020-02-22 00:00:00
# 2020-02-21 00:00:00
# 2020-02-22 00:00:00
# 2020-02-21 00:00:00
# 2020-02-22 00:00:00
# 2020-02-21 00:00:00
# 2020-02-22 00:00:00
# 2020-02-22 00:00:00
# 2020-02-23 00:00:00
# 2020-02-22 00:00:00
# 2020-02-23 00:00:00
# 2020-02-22 00:00:00
# 2020-02-23 00:00:00
# current row=400
# 2020-02-22 00:00:00
# 2020-02-23 00:00:00
# 2020-02-22 00:00:00
# 2020-02-23 00:00:00
# 2020-02-22 00:00:00
# 2020-02-23 00:00:00
# 2020-02-22 00:00:00
# 2020-02-23 00:00:00
# 2020-02-23 00:00:00
# 2020-02-24 00:00:00
# 2020-02-23 00:00:00
# 2020-02-24 00:00:00
# 2020-02-23 00:00:00
# 2020-02-24 00:00:00
# 2020-02-23 00:00:00
# 2020-02-24 00:00:00
# 2020-02-23 00:00:00
# 2020-02-24 00:00:00
# 2020-02-24 00:00:00
# 2020-02-25 00:00:00
# current row=410
# 2020-02-24 00:00:00
# 2020-02-25 00:00:00
# 2020-02-24 00:00:00
# 2020-02-25 00:00:00
# 2020-02-24 00:00:00
# 2020-02-25 00:00:00
# 2020-02-24 00:00:00
# 2020-02-25 00:00:00
# 2020-02-25 00:00:00
# 2020-02-26 00:00:00
# 2020-02-25 00:00:00
# 2020-02-26 00:00:00
# 2020-02-25 00:00:00
# 2020-02-26 00:00:00
# 2020-02-25 00:00:00
# 2020-02-26 00:00:00
# 2020-02-25 00:00:00
# 2020-02-26 00:00:00
# 2020-02-25 00:00:00
# 2020-02-26 00:00:00
# current row=420
# 2020-02-26 00:00:00
# 2020-02-27 00:00:00
# 2020-02-26 00:00:00
# 2020-02-27 00:00:00
# 2020-02-26 00:00:00
# 2020-02-27 00:00:00
# 2020-02-26 00:00:00
# 2020-02-27 00:00:00
# 2020-02-26 00:00:00
# 2020-02-27 00:00:00
# 2020-02-26 00:00:00
# 2020-02-27 00:00:00
# 2020-02-26 00:00:00
# 2020-02-27 00:00:00
# 2020-02-26 00:00:00
# 2020-02-27 00:00:00
# 2020-02-27 00:00:00
# 2020-02-28 00:00:00
# 2020-02-27 00:00:00
# 2020-02-28 00:00:00
# current row=430
# 2020-02-27 00:00:00
# 2020-02-28 00:00:00
# 2020-02-27 00:00:00
# 2020-02-28 00:00:00
# 2020-02-28 00:00:00
# 2020-02-29 00:00:00
# 2020-02-28 00:00:00
# 2020-02-29 00:00:00
# 2020-02-28 00:00:00
# 2020-02-29 00:00:00
# 2020-02-29 00:00:00
# 2020-03-01 00:00:00
# 2020-02-29 00:00:00
# 2020-03-01 00:00:00
# 2020-02-29 00:00:00
# 2020-03-01 00:00:00
# 2020-02-29 00:00:00
# 2020-03-01 00:00:00
# 2020-02-29 00:00:00
# 2020-03-01 00:00:00
# current row=440
# 2020-02-29 00:00:00
# 2020-03-01 00:00:00
# 2020-02-29 00:00:00
# 2020-03-01 00:00:00
# 2020-02-29 00:00:00
# 2020-03-01 00:00:00
# 2020-02-29 00:00:00
# 2020-03-01 00:00:00
# 2020-02-29 00:00:00
# 2020-03-01 00:00:00
# 2020-02-29 00:00:00
# 2020-03-01 00:00:00
# 2020-03-01 00:00:00
# 2020-03-02 00:00:00
# 2020-03-01 00:00:00
# 2020-03-02 00:00:00
# 2020-03-01 00:00:00
# 2020-03-02 00:00:00
# 2020-03-01 00:00:00
# 2020-03-02 00:00:00
# current row=450
# 2020-03-01 00:00:00
# 2020-03-02 00:00:00
# 2020-03-01 00:00:00
# 2020-03-02 00:00:00
# 2020-03-01 00:00:00
# 2020-03-02 00:00:00
# 2020-03-01 00:00:00
# 2020-03-02 00:00:00
# 2020-03-01 00:00:00
# 2020-03-02 00:00:00
# 2020-03-01 00:00:00
# 2020-03-02 00:00:00
# 2020-03-01 00:00:00
# 2020-03-02 00:00:00
# 2020-03-02 00:00:00
# 2020-03-03 00:00:00
# 2020-03-02 00:00:00
# 2020-03-03 00:00:00
# 2020-03-02 00:00:00
# 2020-03-03 00:00:00
# current row=460
# 2020-03-02 00:00:00
# 2020-03-03 00:00:00
# 2020-03-02 00:00:00
# 2020-03-03 00:00:00
# 2020-03-02 00:00:00
# 2020-03-03 00:00:00
# 2020-03-03 00:00:00
# 2020-03-04 00:00:00
# 2020-03-03 00:00:00
# 2020-03-04 00:00:00
# 2020-03-03 00:00:00
# 2020-03-04 00:00:00
# 2020-03-03 00:00:00
# 2020-03-04 00:00:00
# 2020-03-03 00:00:00
# 2020-03-04 00:00:00
# 2020-03-03 00:00:00
# 2020-03-04 00:00:00
# 2020-03-03 00:00:00
# 2020-03-04 00:00:00
# current row=470
# 2020-03-03 00:00:00
# 2020-03-04 00:00:00
# 2020-03-04 00:00:00
# 2020-03-05 00:00:00
# 2020-03-04 00:00:00
# 2020-03-05 00:00:00
# 2020-03-04 00:00:00
# 2020-03-05 00:00:00
# 2020-03-04 00:00:00
# 2020-03-05 00:00:00
# 2020-03-04 00:00:00
# 2020-03-05 00:00:00
# 2020-03-05 00:00:00
# 2020-03-06 00:00:00
# 2020-03-05 00:00:00
# 2020-03-06 00:00:00
# 2020-03-05 00:00:00
# 2020-03-06 00:00:00
# 2020-03-05 00:00:00
# 2020-03-06 00:00:00
# current row=480
# 2020-03-05 00:00:00
# 2020-03-06 00:00:00
# 2020-03-05 00:00:00
# 2020-03-06 00:00:00
# 2020-03-06 00:00:00
# 2020-03-07 00:00:00
# 2020-03-06 00:00:00
# 2020-03-07 00:00:00
# 2020-03-06 00:00:00
# 2020-03-07 00:00:00
# 2020-03-06 00:00:00
# 2020-03-07 00:00:00
# 2020-03-06 00:00:00
# 2020-03-07 00:00:00
# 2020-03-07 00:00:00
# 2020-03-08 00:00:00
# 2020-03-07 00:00:00
# 2020-03-08 00:00:00
# 2020-03-07 00:00:00
# 2020-03-08 00:00:00
# current row=490
# 2020-03-07 00:00:00
# 2020-03-08 00:00:00
# 2020-03-07 00:00:00
# 2020-03-08 00:00:00
# 2020-03-08 00:00:00
# 2020-03-09 00:00:00
# 2020-03-08 00:00:00
# 2020-03-09 00:00:00
# 2020-03-08 00:00:00
# 2020-03-09 00:00:00
# 2020-03-08 00:00:00
# 2020-03-09 00:00:00
# 2020-03-08 00:00:00
# 2020-03-09 00:00:00
# 2020-03-08 00:00:00
# 2020-03-09 00:00:00
# 2020-03-08 00:00:00
# 2020-03-09 00:00:00
# 2020-03-08 00:00:00
# 2020-03-09 00:00:00
# current row=500
# 2020-03-09 00:00:00
# 2020-03-10 00:00:00
# 2020-03-09 00:00:00
# 2020-03-10 00:00:00
# 2020-03-10 00:00:00
# 2020-03-11 00:00:00
# 2020-03-10 00:00:00
# 2020-03-11 00:00:00
# 2020-03-10 00:00:00
# 2020-03-11 00:00:00
# 2020-03-10 00:00:00
# 2020-03-11 00:00:00
# 2020-03-10 00:00:00
# 2020-03-11 00:00:00
# 2020-03-10 00:00:00
# 2020-03-11 00:00:00
# 2020-03-10 00:00:00
# 2020-03-11 00:00:00
# 2020-03-11 00:00:00
# 2020-03-12 00:00:00
# current row=510
# 2020-03-11 00:00:00
# 2020-03-12 00:00:00
# 2020-03-11 00:00:00
# 2020-03-12 00:00:00
# 2020-03-11 00:00:00
# 2020-03-12 00:00:00
# 2020-03-11 00:00:00
# 2020-03-12 00:00:00
# 2020-03-12 00:00:00
# 2020-03-13 00:00:00
# 2020-03-12 00:00:00
# 2020-03-13 00:00:00
# 2020-03-12 00:00:00
# 2020-03-13 00:00:00
# 2020-03-12 00:00:00
# 2020-03-13 00:00:00
# 2020-03-12 00:00:00
# 2020-03-13 00:00:00
# 2020-03-12 00:00:00
# 2020-03-13 00:00:00
# current row=520
# 2020-03-12 00:00:00
# 2020-03-13 00:00:00
# 2020-03-13 00:00:00
# 2020-03-14 00:00:00
# 2020-03-13 00:00:00
# 2020-03-14 00:00:00
# 2020-03-13 00:00:00
# 2020-03-14 00:00:00
# 2020-03-13 00:00:00
# 2020-03-14 00:00:00
# 2020-03-13 00:00:00
# 2020-03-14 00:00:00
# 2020-03-13 00:00:00
# 2020-03-14 00:00:00
# 2020-03-13 00:00:00
# 2020-03-14 00:00:00
# 2020-03-13 00:00:00
# 2020-03-14 00:00:00
# 2020-03-13 00:00:00
# 2020-03-14 00:00:00
# current row=530
# 2020-03-14 00:00:00
# 2020-03-15 00:00:00
# 2020-03-14 00:00:00
# 2020-03-15 00:00:00
# 2020-03-14 00:00:00
# 2020-03-15 00:00:00
# 2020-03-14 00:00:00
# 2020-03-15 00:00:00
# 2020-03-14 00:00:00
# 2020-03-15 00:00:00
# 2020-03-14 00:00:00
# 2020-03-15 00:00:00
# 2020-03-14 00:00:00
# 2020-03-15 00:00:00
# 2020-03-14 00:00:00
# 2020-03-15 00:00:00
# 2020-03-14 00:00:00
# 2020-03-15 00:00:00
# 2020-03-14 00:00:00
# 2020-03-15 00:00:00
# current row=540
# 2020-03-14 00:00:00
# 2020-03-15 00:00:00
# 2020-03-14 00:00:00
# 2020-03-15 00:00:00
# 2020-03-15 00:00:00
# 2020-03-16 00:00:00
# 2020-03-15 00:00:00
# 2020-03-16 00:00:00
# 2020-03-15 00:00:00
# 2020-03-16 00:00:00
# 2020-03-15 00:00:00
# 2020-03-16 00:00:00
# 2020-03-15 00:00:00
# 2020-03-16 00:00:00
# 2020-03-15 00:00:00
# 2020-03-16 00:00:00
# 2020-03-15 00:00:00
# 2020-03-16 00:00:00
# 2020-03-15 00:00:00
# 2020-03-16 00:00:00
# current row=550
# 2020-03-15 00:00:00
# 2020-03-16 00:00:00
# 2020-03-15 00:00:00
# 2020-03-16 00:00:00
# 2020-03-15 00:00:00
# 2020-03-16 00:00:00
# 2020-03-16 00:00:00
# 2020-03-17 00:00:00
# 2020-03-16 00:00:00
# 2020-03-17 00:00:00
# 2020-03-16 00:00:00
# 2020-03-17 00:00:00
# 2020-03-16 00:00:00
# 2020-03-17 00:00:00
# 2020-03-16 00:00:00
# 2020-03-17 00:00:00
# 2020-03-16 00:00:00
# 2020-03-17 00:00:00
# 2020-03-16 00:00:00
# 2020-03-17 00:00:00
# current row=560
# 2020-03-16 00:00:00
# 2020-03-17 00:00:00
# 2020-03-17 00:00:00
# 2020-03-18 00:00:00
# 2020-03-17 00:00:00
# 2020-03-18 00:00:00
# 2020-03-17 00:00:00
# 2020-03-18 00:00:00
# 2020-03-18 00:00:00
# 2020-03-19 00:00:00
# 2020-03-18 00:00:00
# 2020-03-19 00:00:00
# 2020-03-18 00:00:00
# 2020-03-19 00:00:00
# 2020-03-18 00:00:00
# 2020-03-19 00:00:00
# 2020-03-18 00:00:00
# 2020-03-19 00:00:00
# 2020-03-18 00:00:00
# 2020-03-19 00:00:00
# current row=570
# 2020-03-18 00:00:00
# 2020-03-19 00:00:00
# 2020-03-19 00:00:00
# 2020-03-20 00:00:00
# 2020-03-19 00:00:00
# 2020-03-20 00:00:00
# 2020-03-19 00:00:00
# 2020-03-20 00:00:00
# 2020-03-19 00:00:00
# 2020-03-20 00:00:00
# 2020-03-19 00:00:00
# 2020-03-20 00:00:00
# 2020-03-19 00:00:00
# 2020-03-20 00:00:00
# 2020-03-19 00:00:00
# 2020-03-20 00:00:00
# 2020-03-20 00:00:00
# 2020-03-21 00:00:00
# 2020-03-20 00:00:00
# 2020-03-21 00:00:00
# current row=580
# 2020-03-21 00:00:00
# 2020-03-22 00:00:00
# 2020-03-21 00:00:00
# 2020-03-22 00:00:00
# 2020-03-21 00:00:00
# 2020-03-22 00:00:00
# 2020-03-21 00:00:00
# 2020-03-22 00:00:00
# 2020-03-21 00:00:00
# 2020-03-22 00:00:00
# 2020-03-21 00:00:00
# 2020-03-22 00:00:00
# 2020-03-21 00:00:00
# 2020-03-22 00:00:00
# 2020-03-21 00:00:00
# 2020-03-22 00:00:00
# 2020-03-21 00:00:00
# 2020-03-22 00:00:00
# 2020-03-21 00:00:00
# 2020-03-22 00:00:00
# current row=590
# 2020-03-21 00:00:00
# 2020-03-22 00:00:00
# 2020-03-21 00:00:00
# 2020-03-22 00:00:00
# 2020-03-22 00:00:00
# 2020-03-23 00:00:00
# 2020-03-22 00:00:00
# 2020-03-23 00:00:00
# 2020-03-22 00:00:00
# 2020-03-23 00:00:00
# 2020-03-22 00:00:00
# 2020-03-23 00:00:00
# 2020-03-22 00:00:00
# 2020-03-23 00:00:00
# 2020-03-22 00:00:00
# 2020-03-23 00:00:00
# 2020-03-22 00:00:00
# 2020-03-23 00:00:00
# 2020-03-23 00:00:00
# 2020-03-24 00:00:00
# current row=600
# 2020-03-23 00:00:00
# 2020-03-24 00:00:00
# 2020-03-23 00:00:00
# 2020-03-24 00:00:00
# 2020-03-23 00:00:00
# 2020-03-24 00:00:00
# 2020-03-24 00:00:00
# 2020-03-25 00:00:00
# 2020-03-24 00:00:00
# 2020-03-25 00:00:00
# 2020-03-24 00:00:00
# 2020-03-25 00:00:00
# 2020-03-24 00:00:00
# 2020-03-25 00:00:00
# 2020-03-25 00:00:00
# 2020-03-26 00:00:00
# 2020-03-25 00:00:00
# 2020-03-26 00:00:00
# 2020-03-25 00:00:00
# 2020-03-26 00:00:00
# current row=610
# 2020-03-25 00:00:00
# 2020-03-26 00:00:00
# 2020-03-25 00:00:00
# 2020-03-26 00:00:00
# 2020-03-25 00:00:00
# 2020-03-26 00:00:00
# 2020-03-25 00:00:00
# 2020-03-26 00:00:00
# 2020-03-25 00:00:00
# 2020-03-26 00:00:00
# 2020-03-25 00:00:00
# 2020-03-26 00:00:00
# 2020-03-25 00:00:00
# 2020-03-26 00:00:00
# 2020-03-25 00:00:00
# 2020-03-26 00:00:00
# 2020-03-25 00:00:00
# 2020-03-26 00:00:00
# 2020-03-26 00:00:00
# 2020-03-27 00:00:00
# current row=620
# 2020-03-26 00:00:00
# 2020-03-27 00:00:00
# 2020-03-26 00:00:00
# 2020-03-27 00:00:00
# 2020-03-26 00:00:00
# 2020-03-27 00:00:00
# 2020-03-26 00:00:00
# 2020-03-27 00:00:00
# 2020-03-26 00:00:00
# 2020-03-27 00:00:00
# 2020-03-26 00:00:00
# 2020-03-27 00:00:00
# 2020-03-27 00:00:00
# 2020-03-28 00:00:00
# 2020-03-27 00:00:00
# 2020-03-28 00:00:00
# 2020-03-27 00:00:00
# 2020-03-28 00:00:00
# 2020-03-27 00:00:00
# 2020-03-28 00:00:00
# current row=630
# 2020-03-27 00:00:00
# 2020-03-28 00:00:00
# 2020-03-27 00:00:00
# 2020-03-28 00:00:00
# 2020-03-27 00:00:00
# 2020-03-28 00:00:00
# 2020-03-27 00:00:00
# 2020-03-28 00:00:00
# 2020-03-27 00:00:00
# 2020-03-28 00:00:00
# 2020-03-27 00:00:00
# 2020-03-28 00:00:00
# 2020-03-27 00:00:00
# 2020-03-28 00:00:00
# 2020-03-27 00:00:00
# 2020-03-28 00:00:00
# 2020-03-27 00:00:00
# 2020-03-28 00:00:00
# 2020-03-27 00:00:00
# 2020-03-28 00:00:00
# current row=640
# 2020-03-28 00:00:00
# 2020-03-29 00:00:00
# 2020-03-28 00:00:00
# 2020-03-29 00:00:00
# 2020-03-28 00:00:00
# 2020-03-29 00:00:00
# 2020-03-28 00:00:00
# 2020-03-29 00:00:00
# 2020-03-29 00:00:00
# 2020-03-30 00:00:00
# 2020-03-29 00:00:00
# 2020-03-30 00:00:00
# 2020-03-29 00:00:00
# 2020-03-30 00:00:00
# 2020-03-29 00:00:00
# 2020-03-30 00:00:00
# 2020-03-29 00:00:00
# 2020-03-30 00:00:00
# 2020-03-29 00:00:00
# 2020-03-30 00:00:00
# current row=650
# 2020-03-29 00:00:00
# 2020-03-30 00:00:00
# 2020-03-29 00:00:00
# 2020-03-30 00:00:00
# 2020-03-29 00:00:00
# 2020-03-30 00:00:00
# 2020-03-29 00:00:00
# 2020-03-30 00:00:00
# 2020-03-29 00:00:00
# 2020-03-30 00:00:00
# 2020-03-29 00:00:00
# 2020-03-30 00:00:00
# 2020-03-30 00:00:00
# 2020-03-31 00:00:00
# 2020-03-30 00:00:00
# 2020-03-31 00:00:00
# 2020-03-30 00:00:00
# 2020-03-31 00:00:00
# 2020-03-31 00:00:00
# 2020-04-01 00:00:00
# current row=660
# 2020-03-31 00:00:00
# 2020-04-01 00:00:00
# 2020-03-31 00:00:00
# 2020-04-01 00:00:00
# 2020-03-31 00:00:00
# 2020-04-01 00:00:00
# 2020-03-31 00:00:00
# 2020-04-01 00:00:00
# 2020-03-31 00:00:00
# 2020-04-01 00:00:00
# 2020-03-31 00:00:00
# 2020-04-01 00:00:00
# 2020-03-31 00:00:00
# 2020-04-01 00:00:00
# 2020-03-31 00:00:00
# 2020-04-01 00:00:00
# 2020-03-31 00:00:00
# 2020-04-01 00:00:00
# 2020-04-01 00:00:00
# 2020-04-02 00:00:00
# current row=670
# 2020-04-01 00:00:00
# 2020-04-02 00:00:00
# 2020-04-01 00:00:00
# 2020-04-02 00:00:00
# 2020-04-01 00:00:00
# 2020-04-02 00:00:00
# 2020-04-01 00:00:00
# 2020-04-02 00:00:00
# 2020-04-01 00:00:00
# 2020-04-02 00:00:00
# 2020-04-02 00:00:00
# 2020-04-03 00:00:00
# 2020-04-02 00:00:00
# 2020-04-03 00:00:00
# 2020-04-02 00:00:00
# 2020-04-03 00:00:00
# 2020-04-02 00:00:00
# 2020-04-03 00:00:00
# 2020-04-02 00:00:00
# 2020-04-03 00:00:00
# current row=680
# 2020-04-02 00:00:00
# 2020-04-03 00:00:00
# 2020-04-02 00:00:00
# 2020-04-03 00:00:00
# 2020-04-02 00:00:00
# 2020-04-03 00:00:00
# 2020-04-02 00:00:00
# 2020-04-03 00:00:00
# 2020-04-03 00:00:00
# 2020-04-04 00:00:00
# 2020-04-03 00:00:00
# 2020-04-04 00:00:00
# 2020-04-03 00:00:00
# 2020-04-04 00:00:00
# 2020-04-03 00:00:00
# 2020-04-04 00:00:00
# 2020-04-03 00:00:00
# 2020-04-04 00:00:00
# 2020-04-03 00:00:00
# 2020-04-04 00:00:00
# current row=690
# 2020-04-03 00:00:00
# 2020-04-04 00:00:00
# 2020-04-03 00:00:00
# 2020-04-04 00:00:00
# 2020-04-04 00:00:00
# 2020-04-05 00:00:00
# 2020-04-04 00:00:00
# 2020-04-05 00:00:00
# 2020-04-04 00:00:00
# 2020-04-05 00:00:00
# 2020-04-04 00:00:00
# 2020-04-05 00:00:00
# 2020-04-04 00:00:00
# 2020-04-05 00:00:00
# 2020-04-04 00:00:00
# 2020-04-05 00:00:00
# 2020-04-04 00:00:00
# 2020-04-05 00:00:00
# 2020-04-04 00:00:00
# 2020-04-05 00:00:00
# current row=700
# 2020-04-04 00:00:00
# 2020-04-05 00:00:00
# 2020-04-04 00:00:00
# 2020-04-05 00:00:00
# 2020-04-04 00:00:00
# 2020-04-05 00:00:00
# 2020-04-04 00:00:00
# 2020-04-05 00:00:00
# 2020-04-04 00:00:00
# 2020-04-05 00:00:00
# 2020-04-04 00:00:00
# 2020-04-05 00:00:00
# 2020-04-04 00:00:00
# 2020-04-05 00:00:00
# 2020-04-04 00:00:00
# 2020-04-05 00:00:00
# 2020-04-04 00:00:00
# 2020-04-05 00:00:00
# 2020-04-05 00:00:00
# 2020-04-06 00:00:00
# current row=710
# 2020-04-05 00:00:00
# 2020-04-06 00:00:00
# 2020-04-05 00:00:00
# 2020-04-06 00:00:00
# 2020-04-05 00:00:00
# 2020-04-06 00:00:00
# 2020-04-05 00:00:00
# 2020-04-06 00:00:00
# 2020-04-05 00:00:00
# 2020-04-06 00:00:00
# 2020-04-06 00:00:00
# 2020-04-07 00:00:00
# 2020-04-06 00:00:00
# 2020-04-07 00:00:00
# 2020-04-06 00:00:00
# 2020-04-07 00:00:00
# 2020-04-06 00:00:00
# 2020-04-07 00:00:00
# 2020-04-06 00:00:00
# 2020-04-07 00:00:00
# current row=720
# 2020-04-06 00:00:00
# 2020-04-07 00:00:00
# 2020-04-06 00:00:00
# 2020-04-07 00:00:00
# 2020-04-06 00:00:00
# 2020-04-07 00:00:00
# 2020-04-06 00:00:00
# 2020-04-07 00:00:00
# 2020-04-07 00:00:00
# 2020-04-08 00:00:00
# 2020-04-07 00:00:00
# 2020-04-08 00:00:00
# 2020-04-07 00:00:00
# 2020-04-08 00:00:00
# 2020-04-07 00:00:00
# 2020-04-08 00:00:00
# 2020-04-07 00:00:00
# 2020-04-08 00:00:00
# 2020-04-07 00:00:00
# 2020-04-08 00:00:00
# current row=730
# 2020-04-07 00:00:00
# 2020-04-08 00:00:00
# 2020-04-07 00:00:00
# 2020-04-08 00:00:00
# 2020-04-07 00:00:00
# 2020-04-08 00:00:00
# 2020-04-08 00:00:00
# 2020-04-09 00:00:00
# 2020-04-08 00:00:00
# 2020-04-09 00:00:00
# 2020-04-08 00:00:00
# 2020-04-09 00:00:00
# 2020-04-08 00:00:00
# 2020-04-09 00:00:00
# 2020-04-08 00:00:00
# 2020-04-09 00:00:00
# 2020-04-08 00:00:00
# 2020-04-09 00:00:00
# 2020-04-08 00:00:00
# 2020-04-09 00:00:00
# current row=740
# 2020-04-08 00:00:00
# 2020-04-09 00:00:00
# 2020-04-08 00:00:00
# 2020-04-09 00:00:00
# 2020-04-08 00:00:00
# 2020-04-09 00:00:00
# 2020-04-08 00:00:00
# 2020-04-09 00:00:00
# 2020-04-08 00:00:00
# 2020-04-09 00:00:00
# 2020-04-09 00:00:00
# 2020-04-10 00:00:00
# 2020-04-09 00:00:00
# 2020-04-10 00:00:00
# 2020-04-09 00:00:00
# 2020-04-10 00:00:00
# 2020-04-09 00:00:00
# 2020-04-10 00:00:00
# 2020-04-09 00:00:00
# 2020-04-10 00:00:00
# current row=750
# 2020-04-09 00:00:00
# 2020-04-10 00:00:00
# 2020-04-10 00:00:00
# 2020-04-11 00:00:00
# 2020-04-10 00:00:00
# 2020-04-11 00:00:00
# 2020-04-10 00:00:00
# 2020-04-11 00:00:00
# 2020-04-10 00:00:00
# 2020-04-11 00:00:00
# 2020-04-10 00:00:00
# 2020-04-11 00:00:00
# 2020-04-10 00:00:00
# 2020-04-11 00:00:00
# 2020-04-10 00:00:00
# 2020-04-11 00:00:00
# 2020-04-10 00:00:00
# 2020-04-11 00:00:00
# 2020-04-10 00:00:00
# 2020-04-11 00:00:00
# current row=760
# 2020-04-10 00:00:00
# 2020-04-11 00:00:00
# 2020-04-11 00:00:00
# 2020-04-12 00:00:00
# 2020-04-11 00:00:00
# 2020-04-12 00:00:00
# 2020-04-11 00:00:00
# 2020-04-12 00:00:00
# 2020-04-11 00:00:00
# 2020-04-12 00:00:00
# 2020-04-11 00:00:00
# 2020-04-12 00:00:00
# 2020-04-11 00:00:00
# 2020-04-12 00:00:00
# 2020-04-11 00:00:00
# 2020-04-12 00:00:00
# 2020-04-11 00:00:00
# 2020-04-12 00:00:00
# 2020-04-11 00:00:00
# 2020-04-12 00:00:00
# current row=770
# 2020-04-11 00:00:00
# 2020-04-12 00:00:00
# 2020-04-12 00:00:00
# 2020-04-13 00:00:00
# 2020-04-12 00:00:00
# 2020-04-13 00:00:00
# 2020-04-12 00:00:00
# 2020-04-13 00:00:00
# 2020-04-12 00:00:00
# 2020-04-13 00:00:00
# 2020-04-12 00:00:00
# 2020-04-13 00:00:00
# 2020-04-12 00:00:00
# 2020-04-13 00:00:00
# 2020-04-12 00:00:00
# 2020-04-13 00:00:00
# 2020-04-12 00:00:00
# 2020-04-13 00:00:00
# 2020-04-12 00:00:00
# 2020-04-13 00:00:00
# current row=780
# 2020-04-13 00:00:00
# 2020-04-14 00:00:00
# 2020-04-13 00:00:00
# 2020-04-14 00:00:00
# 2020-04-13 00:00:00
# 2020-04-14 00:00:00
# 2020-04-13 00:00:00
# 2020-04-14 00:00:00
# 2020-04-13 00:00:00
# 2020-04-14 00:00:00
# 2020-04-13 00:00:00
# 2020-04-14 00:00:00
# 2020-04-14 00:00:00
# 2020-04-15 00:00:00
# 2020-04-14 00:00:00
# 2020-04-15 00:00:00
# 2020-04-14 00:00:00
# 2020-04-15 00:00:00
# 2020-04-15 00:00:00
# 2020-04-16 00:00:00
# current row=790
# 2020-04-15 00:00:00
# 2020-04-16 00:00:00
# 2020-04-15 00:00:00
# 2020-04-16 00:00:00
# 2020-04-15 00:00:00
# 2020-04-16 00:00:00
# 2020-04-15 00:00:00
# 2020-04-16 00:00:00
# 2020-04-16 00:00:00
# 2020-04-17 00:00:00
# 2020-04-16 00:00:00
# 2020-04-17 00:00:00
# 2020-04-16 00:00:00
# 2020-04-17 00:00:00
# 2020-04-16 00:00:00
# 2020-04-17 00:00:00
# 2020-04-17 00:00:00
# 2020-04-18 00:00:00
# 2020-04-17 00:00:00
# 2020-04-18 00:00:00
# current row=800
# 2020-04-17 00:00:00
# 2020-04-18 00:00:00
# 2020-04-17 00:00:00
# 2020-04-18 00:00:00
# 2020-04-17 00:00:00
# 2020-04-18 00:00:00
# 2020-04-17 00:00:00
# 2020-04-18 00:00:00
# 2020-04-17 00:00:00
# 2020-04-18 00:00:00
# 2020-04-18 00:00:00
# 2020-04-19 00:00:00
# 2020-04-18 00:00:00
# 2020-04-19 00:00:00
# 2020-04-18 00:00:00
# 2020-04-19 00:00:00
# 2020-04-18 00:00:00
# 2020-04-19 00:00:00
# 2020-04-18 00:00:00
# 2020-04-19 00:00:00
# current row=810
# 2020-04-18 00:00:00
# 2020-04-19 00:00:00
# 2020-04-18 00:00:00
# 2020-04-19 00:00:00
# 2020-04-18 00:00:00
# 2020-04-19 00:00:00
# 2020-04-18 00:00:00
# 2020-04-19 00:00:00
# 2020-04-18 00:00:00
# 2020-04-19 00:00:00
# 2020-04-19 00:00:00
# 2020-04-20 00:00:00
# 2020-04-19 00:00:00
# 2020-04-20 00:00:00
# 2020-04-19 00:00:00
# 2020-04-20 00:00:00
# 2020-04-19 00:00:00
# 2020-04-20 00:00:00
# 2020-04-19 00:00:00
# 2020-04-20 00:00:00
# current row=820
# 2020-04-19 00:00:00
# 2020-04-20 00:00:00
# 2020-04-19 00:00:00
# 2020-04-20 00:00:00
# 2020-04-19 00:00:00
# 2020-04-20 00:00:00
# 2020-04-19 00:00:00
# 2020-04-20 00:00:00
# 2020-04-19 00:00:00
# 2020-04-20 00:00:00
# 2020-04-19 00:00:00
# 2020-04-20 00:00:00
# 2020-04-19 00:00:00
# 2020-04-20 00:00:00
# 2020-04-19 00:00:00
# 2020-04-20 00:00:00
# 2020-04-19 00:00:00
# 2020-04-20 00:00:00
# 2020-04-20 00:00:00
# 2020-04-21 00:00:00
# current row=830
# 2020-04-20 00:00:00
# 2020-04-21 00:00:00
# 2020-04-20 00:00:00
# 2020-04-21 00:00:00
# 2020-04-20 00:00:00
# 2020-04-21 00:00:00
# 2020-04-20 00:00:00
# 2020-04-21 00:00:00
# 2020-04-21 00:00:00
# 2020-04-22 00:00:00
# 2020-04-21 00:00:00
# 2020-04-22 00:00:00
# 2020-04-21 00:00:00
# 2020-04-22 00:00:00
# 2020-04-21 00:00:00
# 2020-04-22 00:00:00
# 2020-04-21 00:00:00
# 2020-04-22 00:00:00
# 2020-04-21 00:00:00
# 2020-04-22 00:00:00
# current row=840
# 2020-04-21 00:00:00
# 2020-04-22 00:00:00
# 2020-04-21 00:00:00
# 2020-04-22 00:00:00
# 2020-04-22 00:00:00
# 2020-04-23 00:00:00
# 2020-04-22 00:00:00
# 2020-04-23 00:00:00
# 2020-04-22 00:00:00
# 2020-04-23 00:00:00
# 2020-04-22 00:00:00
# 2020-04-23 00:00:00
# 2020-04-23 00:00:00
# 2020-04-24 00:00:00
# 2020-04-23 00:00:00
# 2020-04-24 00:00:00
# 2020-04-23 00:00:00
# 2020-04-24 00:00:00
# 2020-04-23 00:00:00
# 2020-04-24 00:00:00
# current row=850
# 2020-04-23 00:00:00
# 2020-04-24 00:00:00
# 2020-04-23 00:00:00
# 2020-04-24 00:00:00
# 2020-04-23 00:00:00
# 2020-04-24 00:00:00
# 2020-04-23 00:00:00
# 2020-04-24 00:00:00
# 2020-04-24 00:00:00
# 2020-04-25 00:00:00
# 2020-04-24 00:00:00
# 2020-04-25 00:00:00
# 2020-04-24 00:00:00
# 2020-04-25 00:00:00
# 2020-04-24 00:00:00
# 2020-04-25 00:00:00
# 2020-04-24 00:00:00
# 2020-04-25 00:00:00
# 2020-04-24 00:00:00
# 2020-04-25 00:00:00
# current row=860
# 2020-04-24 00:00:00
# 2020-04-25 00:00:00
# 2020-04-24 00:00:00
# 2020-04-25 00:00:00
# 2020-04-24 00:00:00
# 2020-04-25 00:00:00
# 2020-04-25 00:00:00
# 2020-04-26 00:00:00
# 2020-04-25 00:00:00
# 2020-04-26 00:00:00
# 2020-04-25 00:00:00
# 2020-04-26 00:00:00
# 2020-04-25 00:00:00
# 2020-04-26 00:00:00
# 2020-04-25 00:00:00
# 2020-04-26 00:00:00
# 2020-04-25 00:00:00
# 2020-04-26 00:00:00
# 2020-04-25 00:00:00
# 2020-04-26 00:00:00
# current row=870
# 2020-04-25 00:00:00
# 2020-04-26 00:00:00
# 2020-04-25 00:00:00
# 2020-04-26 00:00:00
# 2020-04-25 00:00:00
# 2020-04-26 00:00:00
# 2020-04-25 00:00:00
# 2020-04-26 00:00:00
# 2020-04-25 00:00:00
# 2020-04-26 00:00:00
# 2020-04-26 00:00:00
# 2020-04-27 00:00:00
# 2020-04-26 00:00:00
# 2020-04-27 00:00:00
# 2020-04-26 00:00:00
# 2020-04-27 00:00:00
# 2020-04-26 00:00:00
# 2020-04-27 00:00:00
# 2020-04-26 00:00:00
# 2020-04-27 00:00:00
# current row=880
# 2020-04-26 00:00:00
# 2020-04-27 00:00:00
# 2020-04-26 00:00:00
# 2020-04-27 00:00:00
# 2020-04-26 00:00:00
# 2020-04-27 00:00:00
# 2020-04-26 00:00:00
# 2020-04-27 00:00:00
# 2020-04-26 00:00:00
# 2020-04-27 00:00:00
# 2020-04-26 00:00:00
# 2020-04-27 00:00:00
# 2020-04-26 00:00:00
# 2020-04-27 00:00:00
# 2020-04-27 00:00:00
# 2020-04-28 00:00:00
# 2020-04-27 00:00:00
# 2020-04-28 00:00:00
# 2020-04-27 00:00:00
# 2020-04-28 00:00:00
# current row=890
# 2020-04-27 00:00:00
# 2020-04-28 00:00:00
# 2020-04-28 00:00:00
# 2020-04-29 00:00:00
# 2020-04-28 00:00:00
# 2020-04-29 00:00:00
# 2020-04-28 00:00:00
# 2020-04-29 00:00:00
# 2020-04-28 00:00:00
# 2020-04-29 00:00:00
# 2020-04-28 00:00:00
# 2020-04-29 00:00:00
# 2020-04-28 00:00:00
# 2020-04-29 00:00:00
# 2020-04-28 00:00:00
# 2020-04-29 00:00:00
# 2020-04-28 00:00:00
# 2020-04-29 00:00:00
# 2020-04-28 00:00:00
# 2020-04-29 00:00:00
# current row=900
# 2020-04-29 00:00:00
# 2020-04-30 00:00:00
# 2020-04-29 00:00:00
# 2020-04-30 00:00:00
# 2020-04-30 00:00:00
# 2020-05-01 00:00:00
# 2020-04-30 00:00:00
# 2020-05-01 00:00:00
# 2020-04-30 00:00:00
# 2020-05-01 00:00:00
# 2020-04-30 00:00:00
# 2020-05-01 00:00:00
# 2020-04-30 00:00:00
# 2020-05-01 00:00:00
# 2020-04-30 00:00:00
# 2020-05-01 00:00:00
# 2020-04-30 00:00:00
# 2020-05-01 00:00:00
# 2020-04-30 00:00:00
# 2020-05-01 00:00:00
# current row=910
# 2020-04-30 00:00:00
# 2020-05-01 00:00:00
# 2020-04-30 00:00:00
# 2020-05-01 00:00:00
# 2020-04-30 00:00:00
# 2020-05-01 00:00:00
# 2020-04-30 00:00:00
# 2020-05-01 00:00:00
# 2020-04-30 00:00:00
# 2020-05-01 00:00:00
# 2020-04-30 00:00:00
# 2020-05-01 00:00:00
# 2020-04-30 00:00:00
# 2020-05-01 00:00:00
# 2020-04-30 00:00:00
# 2020-05-01 00:00:00
# 2020-04-30 00:00:00
# 2020-05-01 00:00:00
# 2020-04-30 00:00:00
# 2020-05-01 00:00:00
# current row=920
# 2020-04-30 00:00:00
# 2020-05-01 00:00:00
# 2020-04-30 00:00:00
# 2020-05-01 00:00:00
# 2020-04-30 00:00:00
# 2020-05-01 00:00:00
# 2020-04-30 00:00:00
# 2020-05-01 00:00:00
# 2020-05-01 00:00:00
# 2020-05-02 00:00:00
# 2020-05-01 00:00:00
# 2020-05-02 00:00:00
# 2020-05-01 00:00:00
# 2020-05-02 00:00:00
# 2020-05-01 00:00:00
# 2020-05-02 00:00:00
# 2020-05-01 00:00:00
# 2020-05-02 00:00:00
# 2020-05-01 00:00:00
# 2020-05-02 00:00:00
# current row=930
# 2020-05-01 00:00:00
# 2020-05-02 00:00:00
# 2020-05-02 00:00:00
# 2020-05-03 00:00:00
# 2020-05-02 00:00:00
# 2020-05-03 00:00:00
# 2020-05-02 00:00:00
# 2020-05-03 00:00:00
# 2020-05-02 00:00:00
# 2020-05-03 00:00:00
# 2020-05-02 00:00:00
# 2020-05-03 00:00:00
# 2020-05-02 00:00:00
# 2020-05-03 00:00:00
# 2020-05-02 00:00:00
# 2020-05-03 00:00:00
# 2020-05-02 00:00:00
# 2020-05-03 00:00:00
# 2020-05-02 00:00:00
# 2020-05-03 00:00:00
# current row=940
# 2020-05-02 00:00:00
# 2020-05-03 00:00:00
# 2020-05-02 00:00:00
# 2020-05-03 00:00:00
# 2020-05-02 00:00:00
# 2020-05-03 00:00:00
# 2020-05-02 00:00:00
# 2020-05-03 00:00:00
# 2020-05-02 00:00:00
# 2020-05-03 00:00:00
# 2020-05-02 00:00:00
# 2020-05-03 00:00:00
# 2020-05-02 00:00:00
# 2020-05-03 00:00:00
# 2020-05-03 00:00:00
# 2020-05-04 00:00:00
# 2020-05-03 00:00:00
# 2020-05-04 00:00:00
# 2020-05-03 00:00:00
# 2020-05-04 00:00:00
# current row=950
# 2020-05-03 00:00:00
# 2020-05-04 00:00:00
# 2020-05-03 00:00:00
# 2020-05-04 00:00:00
# 2020-05-03 00:00:00
# 2020-05-04 00:00:00
# 2020-05-04 00:00:00
# 2020-05-05 00:00:00
# 2020-05-04 00:00:00
# 2020-05-05 00:00:00
# 2020-05-04 00:00:00
# 2020-05-05 00:00:00
# 2020-05-04 00:00:00
# 2020-05-05 00:00:00
# 2020-05-04 00:00:00
# 2020-05-05 00:00:00
# 2020-05-04 00:00:00
# 2020-05-05 00:00:00
# 2020-05-04 00:00:00
# 2020-05-05 00:00:00
# current row=960
# 2020-05-04 00:00:00
# 2020-05-05 00:00:00
# 2020-05-04 00:00:00
# 2020-05-05 00:00:00
# 2020-05-04 00:00:00
# 2020-05-05 00:00:00
# 2020-05-04 00:00:00
# 2020-05-05 00:00:00
# 2020-05-04 00:00:00
# 2020-05-05 00:00:00
# 2020-05-04 00:00:00
# 2020-05-05 00:00:00
# 2020-05-04 00:00:00
# 2020-05-05 00:00:00
# 2020-05-04 00:00:00
# 2020-05-05 00:00:00
# 2020-05-04 00:00:00
# 2020-05-05 00:00:00
# 2020-05-05 00:00:00
# 2020-05-06 00:00:00
# current row=970
# 2020-05-05 00:00:00
# 2020-05-06 00:00:00
# 2020-05-05 00:00:00
# 2020-05-06 00:00:00
# 2020-05-05 00:00:00
# 2020-05-06 00:00:00
# 2020-05-05 00:00:00
# 2020-05-06 00:00:00
# 2020-05-05 00:00:00
# 2020-05-06 00:00:00
# 2020-05-05 00:00:00
# 2020-05-06 00:00:00
# 2020-05-05 00:00:00
# 2020-05-06 00:00:00
# 2020-05-06 00:00:00
# 2020-05-07 00:00:00
# 2020-05-06 00:00:00
# 2020-05-07 00:00:00
# 2020-05-06 00:00:00
# 2020-05-07 00:00:00
# current row=980
# 2020-05-06 00:00:00
# 2020-05-07 00:00:00
# 2020-05-06 00:00:00
# 2020-05-07 00:00:00
# 2020-05-06 00:00:00
# 2020-05-07 00:00:00
# 2020-05-06 00:00:00
# 2020-05-07 00:00:00
# 2020-05-06 00:00:00
# 2020-05-07 00:00:00
# 2020-05-06 00:00:00
# 2020-05-07 00:00:00
# 2020-05-06 00:00:00
# 2020-05-07 00:00:00
# 2020-05-06 00:00:00
# 2020-05-07 00:00:00
# 2020-05-06 00:00:00
# 2020-05-07 00:00:00
# 2020-05-06 00:00:00
# 2020-05-07 00:00:00
# current row=990
# 2020-05-06 00:00:00
# 2020-05-07 00:00:00
# 2020-05-06 00:00:00
# 2020-05-07 00:00:00
# 2020-05-06 00:00:00
# 2020-05-07 00:00:00
# 2020-05-06 00:00:00
# 2020-05-07 00:00:00
# 2020-05-07 00:00:00
# 2020-05-08 00:00:00
# 2020-05-07 00:00:00
# 2020-05-08 00:00:00
# 2020-05-07 00:00:00
# 2020-05-08 00:00:00
# 2020-05-07 00:00:00
# 2020-05-08 00:00:00
# 2020-05-07 00:00:00
# 2020-05-08 00:00:00
# 2020-05-07 00:00:00
# 2020-05-08 00:00:00
# current row=1000
# 2020-05-07 00:00:00
# 2020-05-08 00:00:00
# 2020-05-07 00:00:00
# 2020-05-08 00:00:00
# 2020-05-07 00:00:00
# 2020-05-08 00:00:00
# 2020-05-07 00:00:00
# 2020-05-08 00:00:00
# 2020-05-07 00:00:00
# 2020-05-08 00:00:00
# 2020-05-08 00:00:00
# 2020-05-09 00:00:00
# 2020-05-08 00:00:00
# 2020-05-09 00:00:00
# 2020-05-08 00:00:00
# 2020-05-09 00:00:00
# 2020-05-08 00:00:00
# 2020-05-09 00:00:00
# 2020-05-08 00:00:00
# 2020-05-09 00:00:00
# current row=1010
# 2020-05-08 00:00:00
# 2020-05-09 00:00:00
# 2020-05-09 00:00:00
# 2020-05-10 00:00:00
# 2020-05-09 00:00:00
# 2020-05-10 00:00:00
# 2020-05-09 00:00:00
# 2020-05-10 00:00:00
# 2020-05-09 00:00:00
# 2020-05-10 00:00:00
# 2020-05-09 00:00:00
# 2020-05-10 00:00:00
# 2020-05-09 00:00:00
# 2020-05-10 00:00:00
# 2020-05-09 00:00:00
# 2020-05-10 00:00:00
# 2020-05-09 00:00:00
# 2020-05-10 00:00:00
# 2020-05-09 00:00:00
# 2020-05-10 00:00:00
# current row=1020
# 2020-05-09 00:00:00
# 2020-05-10 00:00:00
# 2020-05-09 00:00:00
# 2020-05-10 00:00:00
# 2020-05-09 00:00:00
# 2020-05-10 00:00:00
# 2020-05-09 00:00:00
# 2020-05-10 00:00:00
# 2020-05-09 00:00:00
# 2020-05-10 00:00:00
# 2020-05-09 00:00:00
# 2020-05-10 00:00:00
# 2020-05-10 00:00:00
# 2020-05-11 00:00:00
# 2020-05-10 00:00:00
# 2020-05-11 00:00:00
# 2020-05-10 00:00:00
# 2020-05-11 00:00:00
# 2020-05-10 00:00:00
# 2020-05-11 00:00:00
# current row=1030
# 2020-05-10 00:00:00
# 2020-05-11 00:00:00
# 2020-05-10 00:00:00
# 2020-05-11 00:00:00
# 2020-05-10 00:00:00
# 2020-05-11 00:00:00
# 2020-05-10 00:00:00
# 2020-05-11 00:00:00
# 2020-05-10 00:00:00
# 2020-05-11 00:00:00
# 2020-05-10 00:00:00
# 2020-05-11 00:00:00
# 2020-05-10 00:00:00
# 2020-05-11 00:00:00
# 2020-05-10 00:00:00
# 2020-05-11 00:00:00
# 2020-05-10 00:00:00
# 2020-05-11 00:00:00
# 2020-05-10 00:00:00
# 2020-05-11 00:00:00
# current row=1040
# 2020-05-10 00:00:00
# 2020-05-11 00:00:00
# 2020-05-10 00:00:00
# 2020-05-11 00:00:00
# 2020-05-10 00:00:00
# 2020-05-11 00:00:00
# 2020-05-10 00:00:00
# 2020-05-11 00:00:00
# 2020-05-10 00:00:00
# 2020-05-11 00:00:00
# 2020-05-10 00:00:00
# 2020-05-11 00:00:00
# 2020-05-10 00:00:00
# 2020-05-11 00:00:00
# 2020-05-10 00:00:00
# 2020-05-11 00:00:00
# 2020-05-10 00:00:00
# 2020-05-11 00:00:00
# 2020-05-11 00:00:00
# 2020-05-12 00:00:00
# current row=1050
# 2020-05-11 00:00:00
# 2020-05-12 00:00:00
# 2020-05-11 00:00:00
# 2020-05-12 00:00:00
# 2020-05-11 00:00:00
# 2020-05-12 00:00:00
# 2020-05-11 00:00:00
# 2020-05-12 00:00:00
# 2020-05-11 00:00:00
# 2020-05-12 00:00:00
# 2020-05-11 00:00:00
# 2020-05-12 00:00:00
# 2020-05-12 00:00:00
# 2020-05-13 00:00:00
# 2020-05-12 00:00:00
# 2020-05-13 00:00:00
# 2020-05-12 00:00:00
# 2020-05-13 00:00:00
# 2020-05-12 00:00:00
# 2020-05-13 00:00:00
# current row=1060
# 2020-05-12 00:00:00
# 2020-05-13 00:00:00
# 2020-05-12 00:00:00
# 2020-05-13 00:00:00
# 2020-05-12 00:00:00
# 2020-05-13 00:00:00
# 2020-05-12 00:00:00
# 2020-05-13 00:00:00
# 2020-05-12 00:00:00
# 2020-05-13 00:00:00
# 2020-05-12 00:00:00
# 2020-05-13 00:00:00
# 2020-05-12 00:00:00
# 2020-05-13 00:00:00
# 2020-05-12 00:00:00
# 2020-05-13 00:00:00
# 2020-05-12 00:00:00
# 2020-05-13 00:00:00
# 2020-05-12 00:00:00
# 2020-05-13 00:00:00
# current row=1070
# 2020-05-12 00:00:00
# 2020-05-13 00:00:00
# 2020-05-13 00:00:00
# 2020-05-14 00:00:00
# 2020-05-13 00:00:00
# 2020-05-14 00:00:00
# 2020-05-13 00:00:00
# 2020-05-14 00:00:00
# 2020-05-13 00:00:00
# 2020-05-14 00:00:00
# 2020-05-13 00:00:00
# 2020-05-14 00:00:00
# 2020-05-13 00:00:00
# 2020-05-14 00:00:00
# 2020-05-13 00:00:00
# 2020-05-14 00:00:00
# 2020-05-13 00:00:00
# 2020-05-14 00:00:00
# 2020-05-13 00:00:00
# 2020-05-14 00:00:00
# current row=1080
# 2020-05-13 00:00:00
# 2020-05-14 00:00:00
# 2020-05-13 00:00:00
# 2020-05-14 00:00:00
# 2020-05-13 00:00:00
# 2020-05-14 00:00:00
# 2020-05-13 00:00:00
# 2020-05-14 00:00:00
# 2020-05-13 00:00:00
# 2020-05-14 00:00:00
# 2020-05-13 00:00:00
# 2020-05-14 00:00:00
# 2020-05-14 00:00:00
# 2020-05-15 00:00:00
# 2020-05-14 00:00:00
# 2020-05-15 00:00:00
# 2020-05-14 00:00:00
# 2020-05-15 00:00:00
# 2020-05-14 00:00:00
# 2020-05-15 00:00:00
# current row=1090
# 2020-05-14 00:00:00
# 2020-05-15 00:00:00
# 2020-05-14 00:00:00
# 2020-05-15 00:00:00
# 2020-05-14 00:00:00
# 2020-05-15 00:00:00
# 2020-05-14 00:00:00
# 2020-05-15 00:00:00
# 2020-05-14 00:00:00
# 2020-05-15 00:00:00
# 2020-05-14 00:00:00
# 2020-05-15 00:00:00
# 2020-05-14 00:00:00
# 2020-05-15 00:00:00
# 2020-05-14 00:00:00
# 2020-05-15 00:00:00
# 2020-05-14 00:00:00
# 2020-05-15 00:00:00
# 2020-05-14 00:00:00
# 2020-05-15 00:00:00
# current row=1100
# 2020-05-14 00:00:00
# 2020-05-15 00:00:00
# 2020-05-14 00:00:00
# 2020-05-15 00:00:00
# 2020-05-15 00:00:00
# 2020-05-16 00:00:00
# 2020-05-15 00:00:00
# 2020-05-16 00:00:00
# 2020-05-15 00:00:00
# 2020-05-16 00:00:00
# 2020-05-15 00:00:00
# 2020-05-16 00:00:00
# 2020-05-15 00:00:00
# 2020-05-16 00:00:00
# 2020-05-15 00:00:00
# 2020-05-16 00:00:00
# 2020-05-15 00:00:00
# 2020-05-16 00:00:00
# 2020-05-15 00:00:00
# 2020-05-16 00:00:00
# current row=1110
# 2020-05-15 00:00:00
# 2020-05-16 00:00:00
# 2020-05-15 00:00:00
# 2020-05-16 00:00:00
# 2020-05-15 00:00:00
# 2020-05-16 00:00:00
# 2020-05-16 00:00:00
# 2020-05-17 00:00:00
# 2020-05-16 00:00:00
# 2020-05-17 00:00:00
# 2020-05-16 00:00:00
# 2020-05-17 00:00:00
# 2020-05-16 00:00:00
# 2020-05-17 00:00:00
# 2020-05-16 00:00:00
# 2020-05-17 00:00:00
# 2020-05-16 00:00:00
# 2020-05-17 00:00:00
# 2020-05-16 00:00:00
# 2020-05-17 00:00:00
# current row=1120
# 2020-05-16 00:00:00
# 2020-05-17 00:00:00
# 2020-05-16 00:00:00
# 2020-05-17 00:00:00
# 2020-05-16 00:00:00
# 2020-05-17 00:00:00
# 2020-05-17 00:00:00
# 2020-05-18 00:00:00
# 2020-05-17 00:00:00
# 2020-05-18 00:00:00
# 2020-05-17 00:00:00
# 2020-05-18 00:00:00
# 2020-05-17 00:00:00
# 2020-05-18 00:00:00
# 2020-05-17 00:00:00
# 2020-05-18 00:00:00
# 2020-05-17 00:00:00
# 2020-05-18 00:00:00
# 2020-05-17 00:00:00
# 2020-05-18 00:00:00
# current row=1130
# 2020-05-17 00:00:00
# 2020-05-18 00:00:00
# 2020-05-17 00:00:00
# 2020-05-18 00:00:00
# 2020-05-18 00:00:00
# 2020-05-19 00:00:00
# 2020-05-18 00:00:00
# 2020-05-19 00:00:00
# 2020-05-18 00:00:00
# 2020-05-19 00:00:00
# 2020-05-18 00:00:00
# 2020-05-19 00:00:00
# 2020-05-18 00:00:00
# 2020-05-19 00:00:00
# 2020-05-18 00:00:00
# 2020-05-19 00:00:00
# 2020-05-18 00:00:00
# 2020-05-19 00:00:00
# 2020-05-18 00:00:00
# 2020-05-19 00:00:00
# current row=1140
# 2020-05-18 00:00:00
# 2020-05-19 00:00:00
# 2020-05-18 00:00:00
# 2020-05-19 00:00:00
# 2020-05-18 00:00:00
# 2020-05-19 00:00:00
# 2020-05-18 00:00:00
# 2020-05-19 00:00:00
# 2020-05-19 00:00:00
# 2020-05-20 00:00:00
# 2020-05-19 00:00:00
# 2020-05-20 00:00:00
# 2020-05-19 00:00:00
# 2020-05-20 00:00:00
# 2020-05-19 00:00:00
# 2020-05-20 00:00:00
# 2020-05-19 00:00:00
# 2020-05-20 00:00:00
# 2020-05-19 00:00:00
# 2020-05-20 00:00:00
# current row=1150
# 2020-05-19 00:00:00
# 2020-05-20 00:00:00
# 2020-05-19 00:00:00
# 2020-05-20 00:00:00
# ...
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# current row=5340
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# current row=5350
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# current row=5360
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# current row=5370
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# current row=5380
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-22 00:00:00
# 2020-08-23 00:00:00
# 2020-08-23 00:00:00
# 2020-08-24 00:00:00
# current row=5390
# 2020-08-23 00:00:00
# 2020-08-24 00:00:00
# 2020-08-23 00:00:00
# 2020-08-24 00:00:00
# 2020-08-23 00:00:00
# 2020-08-24 00:00:00
# 2020-08-23 00:00:00
# 2020-08-24 00:00:00
# 2020-08-23 00:00:00
# 2020-08-24 00:00:00
# 2020-08-23 00:00:00
# 2020-08-24 00:00:00
# 2020-08-23 00:00:00
# 2020-08-24 00:00:00
# 2020-08-23 00:00:00
# 2020-08-24 00:00:00
# 2020-08-23 00:00:00
# 2020-08-24 00:00:00
# 2020-08-23 00:00:00
# 2020-08-24 00:00:00
# current row=5400
# 2020-08-23 00:00:00
# 2020-08-24 00:00:00
# 2020-08-23 00:00:00
# 2020-08-24 00:00:00
# 2020-08-23 00:00:00
# 2020-08-24 00:00:00
# 2020-08-23 00:00:00
# 2020-08-24 00:00:00
# 2020-08-23 00:00:00
# 2020-08-24 00:00:00
# 2020-08-23 00:00:00
# 2020-08-24 00:00:00
# 2020-08-23 00:00:00
# 2020-08-24 00:00:00
# 2020-08-23 00:00:00
# 2020-08-24 00:00:00
# 2020-08-23 00:00:00
# 2020-08-24 00:00:00
# 2020-08-23 00:00:00
# 2020-08-24 00:00:00
# current row=5410
# 2020-08-23 00:00:00
# 2020-08-24 00:00:00
# 2020-08-23 00:00:00
# 2020-08-24 00:00:00
# 2020-08-23 00:00:00
# 2020-08-24 00:00:00
# 2020-08-23 00:00:00
# 2020-08-24 00:00:00
# 2020-08-23 00:00:00
# 2020-08-24 00:00:00
# 2020-08-23 00:00:00
# 2020-08-24 00:00:00
# 2020-08-23 00:00:00
# 2020-08-24 00:00:00
# 2020-08-23 00:00:00
# 2020-08-24 00:00:00
# 2020-08-23 00:00:00
# 2020-08-24 00:00:00
# 2020-08-23 00:00:00
# 2020-08-24 00:00:00
# current row=5420
# 2020-08-23 00:00:00
# 2020-08-24 00:00:00
# 2020-08-23 00:00:00
# 2020-08-24 00:00:00
# 2020-08-24 00:00:00
# 2020-08-25 00:00:00
# 2020-08-24 00:00:00
# 2020-08-25 00:00:00
# 2020-08-24 00:00:00
# 2020-08-25 00:00:00
# 2020-08-24 00:00:00
# 2020-08-25 00:00:00
# 2020-08-24 00:00:00
# 2020-08-25 00:00:00
# 2020-08-24 00:00:00
# 2020-08-25 00:00:00
# 2020-08-24 00:00:00
# 2020-08-25 00:00:00
# 2020-08-24 00:00:00
# 2020-08-25 00:00:00
# current row=5430
# 2020-08-24 00:00:00
# 2020-08-25 00:00:00
# 2020-08-24 00:00:00
# 2020-08-25 00:00:00
# 2020-08-24 00:00:00
# 2020-08-25 00:00:00
# 2020-08-24 00:00:00
# 2020-08-25 00:00:00
# 2020-08-24 00:00:00
# 2020-08-25 00:00:00
# 2020-08-24 00:00:00
# 2020-08-25 00:00:00
# 2020-08-24 00:00:00
# 2020-08-25 00:00:00
# 2020-08-24 00:00:00
# 2020-08-25 00:00:00
# 2020-08-24 00:00:00
# 2020-08-25 00:00:00
# 2020-08-24 00:00:00
# 2020-08-25 00:00:00
# current row=5440
# 2020-08-24 00:00:00
# 2020-08-25 00:00:00
# 2020-08-24 00:00:00
# 2020-08-25 00:00:00
# 2020-08-24 00:00:00
# 2020-08-25 00:00:00
# 2020-08-24 00:00:00
# 2020-08-25 00:00:00
# 2020-08-24 00:00:00
# 2020-08-25 00:00:00
# 2020-08-24 00:00:00
# 2020-08-25 00:00:00
# 2020-08-24 00:00:00
# 2020-08-25 00:00:00
# 2020-08-24 00:00:00
# 2020-08-25 00:00:00
# 2020-08-25 00:00:00
# 2020-08-26 00:00:00
# 2020-08-25 00:00:00
# 2020-08-26 00:00:00
# current row=5450
# 2020-08-25 00:00:00
# 2020-08-26 00:00:00
# 2020-08-25 00:00:00
# 2020-08-26 00:00:00
# 2020-08-25 00:00:00
# 2020-08-26 00:00:00
# 2020-08-25 00:00:00
# 2020-08-26 00:00:00
# 2020-08-25 00:00:00
# 2020-08-26 00:00:00
# 2020-08-25 00:00:00
# 2020-08-26 00:00:00
# 2020-08-25 00:00:00
# 2020-08-26 00:00:00
# 2020-08-25 00:00:00
# 2020-08-26 00:00:00
# 2020-08-25 00:00:00
# 2020-08-26 00:00:00
# 2020-08-25 00:00:00
# 2020-08-26 00:00:00
# current row=5460
# 2020-08-25 00:00:00
# 2020-08-26 00:00:00
# 2020-08-25 00:00:00
# 2020-08-26 00:00:00
# 2020-08-25 00:00:00
# 2020-08-26 00:00:00
# 2020-08-25 00:00:00
# 2020-08-26 00:00:00
# 2020-08-25 00:00:00
# 2020-08-26 00:00:00
# 2020-08-25 00:00:00
# 2020-08-26 00:00:00
# 2020-08-25 00:00:00
# 2020-08-26 00:00:00
# 2020-08-25 00:00:00
# 2020-08-26 00:00:00
# 2020-08-25 00:00:00
# 2020-08-26 00:00:00
# 2020-08-26 00:00:00
# 2020-08-27 00:00:00
# current row=5470
# 2020-08-26 00:00:00
# 2020-08-27 00:00:00
# 2020-08-26 00:00:00
# 2020-08-27 00:00:00
# 2020-08-26 00:00:00
# 2020-08-27 00:00:00
# 2020-08-26 00:00:00
# 2020-08-27 00:00:00
# 2020-08-26 00:00:00
# 2020-08-27 00:00:00
# 2020-08-26 00:00:00
# 2020-08-27 00:00:00
# 2020-08-26 00:00:00
# 2020-08-27 00:00:00
# 2020-08-26 00:00:00
# 2020-08-27 00:00:00
# 2020-08-26 00:00:00
# 2020-08-27 00:00:00
# 2020-08-26 00:00:00
# 2020-08-27 00:00:00
# current row=5480
# 2020-08-26 00:00:00
# 2020-08-27 00:00:00
# 2020-08-26 00:00:00
# 2020-08-27 00:00:00
# 2020-08-26 00:00:00
# 2020-08-27 00:00:00
# 2020-08-26 00:00:00
# 2020-08-27 00:00:00
# 2020-08-26 00:00:00
# 2020-08-27 00:00:00
# 2020-08-26 00:00:00
# 2020-08-27 00:00:00
# 2020-08-26 00:00:00
# 2020-08-27 00:00:00
# 2020-08-26 00:00:00
# 2020-08-27 00:00:00
# 2020-08-26 00:00:00
# 2020-08-27 00:00:00
# 2020-08-26 00:00:00
# 2020-08-27 00:00:00
# current row=5490
# 2020-08-26 00:00:00
# 2020-08-27 00:00:00
# 2020-08-26 00:00:00
# 2020-08-27 00:00:00
# 2020-08-26 00:00:00
# 2020-08-27 00:00:00
# 2020-08-26 00:00:00
# 2020-08-27 00:00:00
# 2020-08-26 00:00:00
# 2020-08-27 00:00:00
# 2020-08-27 00:00:00
# 2020-08-28 00:00:00
# 2020-08-27 00:00:00
# 2020-08-28 00:00:00
# 2020-08-27 00:00:00
# 2020-08-28 00:00:00
# 2020-08-27 00:00:00
# 2020-08-28 00:00:00
# 2020-08-27 00:00:00
# 2020-08-28 00:00:00
# current row=5500
# 2020-08-27 00:00:00
# 2020-08-28 00:00:00
# 2020-08-27 00:00:00
# 2020-08-28 00:00:00
# 2020-08-27 00:00:00
# 2020-08-28 00:00:00
# 2020-08-27 00:00:00
# 2020-08-28 00:00:00
# 2020-08-27 00:00:00
# 2020-08-28 00:00:00
# 2020-08-27 00:00:00
# 2020-08-28 00:00:00
# 2020-08-27 00:00:00
# 2020-08-28 00:00:00
# 2020-08-27 00:00:00
# 2020-08-28 00:00:00
# 2020-08-27 00:00:00
# 2020-08-28 00:00:00
# 2020-08-27 00:00:00
# 2020-08-28 00:00:00
# current row=5510
# 2020-08-27 00:00:00
# 2020-08-28 00:00:00
# 2020-08-27 00:00:00
# 2020-08-28 00:00:00
# 2020-08-27 00:00:00
# 2020-08-28 00:00:00
# 2020-08-27 00:00:00
# 2020-08-28 00:00:00
# 2020-08-27 00:00:00
# 2020-08-28 00:00:00
# 2020-08-27 00:00:00
# 2020-08-28 00:00:00
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# current row=5520
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# current row=5530
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# current row=5540
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# current row=5550
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# 2020-08-28 00:00:00
# 2020-08-29 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# current row=5560
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# current row=5570
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# current row=5580
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# current row=5590
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# current row=5600
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-29 00:00:00
# 2020-08-30 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# current row=5610
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# current row=5620
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# current row=5630
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# current row=5640
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# current row=5650
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-30 00:00:00
# 2020-08-31 00:00:00
# 2020-08-31 00:00:00
# 2020-09-01 00:00:00
# current row=5660
# 2020-08-31 00:00:00
# 2020-09-01 00:00:00
# 2020-08-31 00:00:00
# 2020-09-01 00:00:00
# 2020-08-31 00:00:00
# 2020-09-01 00:00:00
# 2020-08-31 00:00:00
# 2020-09-01 00:00:00
# 2020-08-31 00:00:00
# 2020-09-01 00:00:00
# 2020-08-31 00:00:00
# 2020-09-01 00:00:00
# 2020-08-31 00:00:00
# 2020-09-01 00:00:00
# 2020-08-31 00:00:00
# 2020-09-01 00:00:00
# 2020-08-31 00:00:00
# 2020-09-01 00:00:00
# 2020-08-31 00:00:00
# 2020-09-01 00:00:00
# current row=5670
# 2020-08-31 00:00:00
# 2020-09-01 00:00:00
# 2020-08-31 00:00:00
# 2020-09-01 00:00:00
# 2020-08-31 00:00:00
# 2020-09-01 00:00:00
# 2020-08-31 00:00:00
# 2020-09-01 00:00:00
# 2020-08-31 00:00:00
# 2020-09-01 00:00:00
# 2020-08-31 00:00:00
# 2020-09-01 00:00:00
# 2020-08-31 00:00:00
# 2020-09-01 00:00:00
# 2020-08-31 00:00:00
# 2020-09-01 00:00:00
# 2020-08-31 00:00:00
# 2020-09-01 00:00:00
# 2020-08-31 00:00:00
# 2020-09-01 00:00:00
# current row=5680
# 2020-08-31 00:00:00
# 2020-09-01 00:00:00
# 2020-08-31 00:00:00
# 2020-09-01 00:00:00
# 2020-08-31 00:00:00
# 2020-09-01 00:00:00
# 2020-08-31 00:00:00
# 2020-09-01 00:00:00
# 2020-08-31 00:00:00
# 2020-09-01 00:00:00
# 2020-08-31 00:00:00
# 2020-09-01 00:00:00
# 2020-08-31 00:00:00
# 2020-09-01 00:00:00
# 2020-08-31 00:00:00
# 2020-09-01 00:00:00
# 2020-08-31 00:00:00
# 2020-09-01 00:00:00
# 2020-08-31 00:00:00
# 2020-09-01 00:00:00
# current row=5690
# 2020-08-31 00:00:00
# 2020-09-01 00:00:00
# 2020-09-01 00:00:00
# 2020-09-02 00:00:00
# 2020-09-01 00:00:00
# 2020-09-02 00:00:00
# 2020-09-01 00:00:00
# 2020-09-02 00:00:00
# 2020-09-01 00:00:00
# 2020-09-02 00:00:00
# 2020-09-01 00:00:00
# 2020-09-02 00:00:00
# 2020-09-01 00:00:00
# 2020-09-02 00:00:00
# 2020-09-01 00:00:00
# 2020-09-02 00:00:00
# 2020-09-01 00:00:00
# 2020-09-02 00:00:00
# 2020-09-01 00:00:00
# 2020-09-02 00:00:00
# current row=5700
# 2020-09-01 00:00:00
# 2020-09-02 00:00:00
# 2020-09-01 00:00:00
# 2020-09-02 00:00:00
# 2020-09-01 00:00:00
# 2020-09-02 00:00:00
# 2020-09-01 00:00:00
# 2020-09-02 00:00:00
# 2020-09-01 00:00:00
# 2020-09-02 00:00:00
# 2020-09-01 00:00:00
# 2020-09-02 00:00:00
# 2020-09-01 00:00:00
# 2020-09-02 00:00:00
# 2020-09-01 00:00:00
# 2020-09-02 00:00:00
# 2020-09-01 00:00:00
# 2020-09-02 00:00:00
# 2020-09-01 00:00:00
# 2020-09-02 00:00:00
# current row=5710
# 2020-09-01 00:00:00
# 2020-09-02 00:00:00
# 2020-09-01 00:00:00
# 2020-09-02 00:00:00
# 2020-09-01 00:00:00
# 2020-09-02 00:00:00
# 2020-09-01 00:00:00
# 2020-09-02 00:00:00
# 2020-09-01 00:00:00
# 2020-09-02 00:00:00
# 2020-09-01 00:00:00
# 2020-09-02 00:00:00
# 2020-09-02 00:00:00
# 2020-09-03 00:00:00

# %%
# Out:
# {'url': 'https://twitter.com/PIS_PlayinStock/status/1568055715792814081', 'date': datetime.datetime(2022, 9, 9, 1, 56, 30, tzinfo=datetime.timezone.utc), 'content': "힌남노: 6일 오전 상륙 예정…’이미 전국이 태풍 영향권' https://t.co/F7B0QqHc4w 28", 'renderedContent': "힌남노: 6일 오전 상륙 예정…’이미 전국이 태풍 영향권' m.newspic.kr/view.html?nid=… 28", 'id': 1568055715792814081, 'user': User(username='PIS_PlayinStock', id=1347859217684656133, displayname='PIS', description='주식 차트 분석', rawDescription='주식 차트 분석', descriptionUrls=None, verified=False, created=datetime.datetime(2021, 1, 9, 10, 54, 19, tzinfo=datetime.timezone.utc), followersCount=225, friendsCount=391, statusesCount=22466, favouritesCount=170, listedCount=0, mediaCount=15424, location='KOREA', protected=False, linkUrl='https://play-in-stock.tistory.com/', linkTcourl='https://t.co/MV0NIrhaYV', profileImageUrl='https://pbs.twimg.com/profile_images/1538813859511017472/Ro3mo4QV_normal.jpg', profileBannerUrl=None, label=None), 'replyCount': 0, 'retweetCount': 0, 'likeCount': 0, 'quoteCount': 0, 'conversationId': 1568055715792814081, 'lang': 'ko', 'source': '<a href="https://twitter.com/PIS_PlayinStock" rel="nofollow">coupang_bot2</a>', 'sourceUrl': 'https://twitter.com/PIS_PlayinStock', 'sourceLabel': 'coupang_bot2', 'outlinks': ['http://m.newspic.kr/view.html?nid=2022090516465131236&pn=457&cp=S3HeM39B&utm_medium=affiliate&utm_campaign=2022090516465131236&utm_source=np210622S3HeM39B'], 'tcooutlinks': ['https://t.co/F7B0QqHc4w'], 'media': None, 'retweetedTweet': None, 'quotedTweet': None, 'inReplyToTweetId': None, 'inReplyToUser': None, 'mentionedUsers': None, 'coordinates': None, 'place': None, 'hashtags': None, 'cashtags': None}

# %%
! pip install mxnet
# Out:
# Collecting mxnet
#   Downloading mxnet-1.7.0.post2-py2.py3-none-win_amd64.whl (33.1 MB)
# Collecting requests<2.19.0,>=2.18.4
#   Downloading requests-2.18.4-py2.py3-none-any.whl (88 kB)
# Collecting numpy<1.17.0,>=1.8.2
#   Downloading numpy-1.16.6.zip (5.1 MB)
# Collecting graphviz<0.9.0,>=0.8.1
#   Downloading graphviz-0.8.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\seoye\anaconda3\lib\site-packages (from requests<2.19.0,>=2.18.4->mxnet) (2021.10.8)
# Collecting idna<2.7,>=2.5
#   Downloading idna-2.6-py2.py3-none-any.whl (56 kB)
# Collecting urllib3<1.23,>=1.21.1
#   Downloading urllib3-1.22-py2.py3-none-any.whl (132 kB)
# Collecting chardet<3.1.0,>=3.0.2
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Building wheels for collected packages: numpy
#   Building wheel for numpy (setup.py): started
#   Building wheel for numpy (setup.py): finished with status 'error'
#   Running setup.py clean for numpy
# Failed to build numpy
# Installing collected packages: urllib3, idna, chardet, requests, numpy, graphviz, mxnet
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.9
#     Uninstalling urllib3-1.26.9:
#       Successfully uninstalled urllib3-1.26.9
#   Attempting uninstall: idna
#     Found existing installation: idna 3.3
#     Uninstalling idna-3.3:
#       Successfully uninstalled idna-3.3
#   Attempting uninstall: chardet
#     Found existing installation: chardet 4.0.0
#     Uninstalling chardet-4.0.0:
#       Successfully uninstalled chardet-4.0.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.27.1
#     Uninstalling requests-2.27.1:
#       Successfully uninstalled requests-2.27.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.5
#     Uninstalling numpy-1.21.5:
#       Successfully uninstalled numpy-1.21.5
#     Running setup.py install for numpy: started
#     Running setup.py install for numpy: finished with status 'error'
#   Rolling back uninstall of numpy
#   Moving to c:\users\seoye\anaconda3\lib\site-packages\numpy-1.21.5.dist-info\
#    from C:\Users\seoye\anaconda3\Lib\site-packages\~umpy-1.21.5.dist-info
#   Moving to c:\users\seoye\anaconda3\lib\site-packages\numpy\
#    from C:\Users\seoye\anaconda3\Lib\site-packages\~umpy
#   Moving to c:\users\seoye\anaconda3\scripts\f2py-script.py
#    from C:\Users\seoye\AppData\Local\Temp\pip-uninstall-55310vmy\f2py-script.py
#   Moving to c:\users\seoye\anaconda3\scripts\f2py.exe
#    from C:\Users\seoye\AppData\Local\Temp\pip-uninstall-55310vmy\f2py.exe
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\seoye\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\seoye\\AppData\\Local\\Temp\\pip-install-2qm72zxu\\numpy_e956bd9dd07a4632aa95b5b81aaa107b\\setup.py'"'"'; __file__='"'"'C:\\Users\\seoye\\AppData\\Local\\Temp\\pip-install-2qm72zxu\\numpy_e956bd9dd07a4632aa95b5b81aaa107b\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\seoye\AppData\Local\Temp\pip-wheel-28m2du56'
#        cwd: C:\Users\seoye\AppData\Local\Temp\pip-install-2qm72zxu\numpy_e956bd9dd07a4632aa95b5b81aaa107b\
#   Complete output (264 lines):
#   Running from numpy source directory.
#   C:\Users\seoye\AppData\Local\Temp\pip-install-2qm72zxu\numpy_e956bd9dd07a4632aa95b5b81aaa107b\numpy\distutils\misc_util.py:476: SyntaxWarning: "is" with a literal. Did you mean "=="?
#     return is_string(s) and ('*' in s or '?' is s)
#   blas_opt_info:
#   blas_mkl_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries mkl_rt not found in ['C:\\Users\\seoye\\anaconda3\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   blis_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries blis not found in ['C:\\Users\\seoye\\anaconda3\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   openblas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries openblas not found in ['C:\\Users\\seoye\\anaconda3\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\libs']
#   get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#   customize GnuFCompiler
#   Could not locate executable g77
#   Could not locate executable f77
#   customize IntelVisualFCompiler
#   Could not locate executable ifort
#   Could not locate executable ifl
#   customize AbsoftFCompiler
#   Could not locate executable f90
#   customize CompaqVisualFCompiler
#   Could not locate executable DF
#   customize IntelItaniumVisualFCompiler
#   Could not locate executable efl
#   customize Gnu95FCompiler
#   Could not locate executable gfortran
#   Could not locate executable f95
#   customize G95FCompiler
#   Could not locate executable g95
#   customize IntelEM64VisualFCompiler
#   customize IntelEM64TFCompiler
#   Could not locate executable efort
#   Could not locate executable efc
#   customize PGroupFlangCompiler
#   Could not locate executable flang
#   don't know how to compile Fortran code on platform 'nt'
#     NOT AVAILABLE
#
#   atlas_3_10_blas_threads_info:
#   Setting PTATLAS=ATLAS
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries tatlas not found in ['C:\\Users\\seoye\\anaconda3\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   atlas_3_10_blas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries satlas not found in ['C:\\Users\\seoye\\anaconda3\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   atlas_blas_threads_info:
#   Setting PTATLAS=ATLAS
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in ['C:\\Users\\seoye\\anaconda3\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   atlas_blas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries f77blas,cblas,atlas not found in ['C:\\Users\\seoye\\anaconda3\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   accelerate_info:
#     NOT AVAILABLE
#
#   C:\Users\seoye\AppData\Local\Temp\pip-install-2qm72zxu\numpy_e956bd9dd07a4632aa95b5b81aaa107b\numpy\distutils\system_info.py:639: UserWarning:
#       Atlas (http://math-atlas.sourceforge.net/) libraries not found.
#       Directories to search for the libraries can be specified in the
#       numpy/distutils/site.cfg file (section [atlas]) or by setting
#       the ATLAS environment variable.
#     self.calc_info()
#   blas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries blas not found in ['C:\\Users\\seoye\\anaconda3\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   C:\Users\seoye\AppData\Local\Temp\pip-install-2qm72zxu\numpy_e956bd9dd07a4632aa95b5b81aaa107b\numpy\distutils\system_info.py:639: UserWarning:
#       Blas (http://www.netlib.org/blas/) libraries not found.
#       Directories to search for the libraries can be specified in the
#       numpy/distutils/site.cfg file (section [blas]) or by setting
#       the BLAS environment variable.
#     self.calc_info()
#   blas_src_info:
#     NOT AVAILABLE
#
#   C:\Users\seoye\AppData\Local\Temp\pip-install-2qm72zxu\numpy_e956bd9dd07a4632aa95b5b81aaa107b\numpy\distutils\system_info.py:639: UserWarning:
#       Blas (http://www.netlib.org/blas/) sources not found.
#       Directories to search for the sources can be specified in the
#       numpy/distutils/site.cfg file (section [blas_src]) or by setting
#       the BLAS_SRC environment variable.
#     self.calc_info()
#     NOT AVAILABLE
#
#   'svnversion'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
#   배치 파일이 아닙니다.
#   non-existing path in 'numpy\\distutils': 'site.cfg'
#   lapack_opt_info:
#   lapack_mkl_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries mkl_rt not found in ['C:\\Users\\seoye\\anaconda3\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   openblas_lapack_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries openblas not found in ['C:\\Users\\seoye\\anaconda3\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   openblas_clapack_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries openblas,lapack not found in ['C:\\Users\\seoye\\anaconda3\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   atlas_3_10_threads_info:
#   Setting PTATLAS=ATLAS
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\seoye\anaconda3\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries tatlas,tatlas not found in C:\Users\seoye\anaconda3\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries tatlas,tatlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\seoye\anaconda3\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries tatlas,tatlas not found in C:\Users\seoye\anaconda3\libs
#   <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#     NOT AVAILABLE
#
#   atlas_3_10_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\seoye\anaconda3\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries satlas,satlas not found in C:\Users\seoye\anaconda3\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries satlas,satlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\seoye\anaconda3\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries satlas,satlas not found in C:\Users\seoye\anaconda3\libs
#   <class 'numpy.distutils.system_info.atlas_3_10_info'>
#     NOT AVAILABLE
#
#   atlas_threads_info:
#   Setting PTATLAS=ATLAS
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\seoye\anaconda3\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in C:\Users\seoye\anaconda3\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\seoye\anaconda3\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in C:\Users\seoye\anaconda3\libs
#   <class 'numpy.distutils.system_info.atlas_threads_info'>
#     NOT AVAILABLE
#
#   atlas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\seoye\anaconda3\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries f77blas,cblas,atlas not found in C:\Users\seoye\anaconda3\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries f77blas,cblas,atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\seoye\anaconda3\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries f77blas,cblas,atlas not found in C:\Users\seoye\anaconda3\libs
#   <class 'numpy.distutils.system_info.atlas_info'>
#     NOT AVAILABLE
#
#   lapack_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack not found in ['C:\\Users\\seoye\\anaconda3\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\libs']
#     NOT AVAILABLE
#
#   C:\Users\seoye\AppData\Local\Temp\pip-install-2qm72zxu\numpy_e956bd9dd07a4632aa95b5b81aaa107b\numpy\distutils\system_info.py:639: UserWarning:
#       Lapack (http://www.netlib.org/lapack/) libraries not found.
#       Directories to search for the libraries can be specified in the
#       numpy/distutils/site.cfg file (section [lapack]) or by setting
#       the LAPACK environment variable.
#     self.calc_info()
#   lapack_src_info:
#     NOT AVAILABLE
#
#   C:\Users\seoye\AppData\Local\Temp\pip-install-2qm72zxu\numpy_e956bd9dd07a4632aa95b5b81aaa107b\numpy\distutils\system_info.py:639: UserWarning:
#       Lapack (http://www.netlib.org/lapack/) sources not found.
#       Directories to search for the sources can be specified in the
#       numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#       the LAPACK_SRC environment variable.
#     self.calc_info()
#     NOT AVAILABLE
#
#   C:\Users\seoye\anaconda3\lib\site-packages\setuptools\_distutils\dist.py:275: UserWarning: Unknown distribution option: 'define_macros'
#     warnings.warn(msg)
#   running bdist_wheel
#   running build
#   running config_cc
#   unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#   running config_fc
#   unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#   running build_src
#   build_src
#   building py_modules sources
#   creating build
#   creating build\src.win-amd64-3.9
#   creating build\src.win-amd64-3.9\numpy
#   creating build\src.win-amd64-3.9\numpy\distutils
#   building library "npymath" sources
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for numpy
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\seoye\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\seoye\\AppData\\Local\\Temp\\pip-install-2qm72zxu\\numpy_e956bd9dd07a4632aa95b5b81aaa107b\\setup.py'"'"'; __file__='"'"'C:\\Users\\seoye\\AppData\\Local\\Temp\\pip-install-2qm72zxu\\numpy_e956bd9dd07a4632aa95b5b81aaa107b\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' clean --all
#        cwd: C:\Users\seoye\AppData\Local\Temp\pip-install-2qm72zxu\numpy_e956bd9dd07a4632aa95b5b81aaa107b
#   Complete output (10 lines):
#   Running from numpy source directory.
#
#   `setup.py clean` is not supported, use one of the following instead:
#
#     - `git clean -xdf` (cleans all files)
#     - `git clean -Xdf` (cleans all versioned files, doesn't touch
#                         files that aren't checked into the git repo)
#
#   Add `--force` to your command to use it anyway if you must (unsupported).
#
#   ----------------------------------------
#   ERROR: Failed cleaning build dir for numpy
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\seoye\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\seoye\\AppData\\Local\\Temp\\pip-install-2qm72zxu\\numpy_e956bd9dd07a4632aa95b5b81aaa107b\\setup.py'"'"'; __file__='"'"'C:\\Users\\seoye\\AppData\\Local\\Temp\\pip-install-2qm72zxu\\numpy_e956bd9dd07a4632aa95b5b81aaa107b\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\seoye\AppData\Local\Temp\pip-record-hm5vdro0\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\seoye\anaconda3\Include\numpy'
#          cwd: C:\Users\seoye\AppData\Local\Temp\pip-install-2qm72zxu\numpy_e956bd9dd07a4632aa95b5b81aaa107b\
#     Complete output (269 lines):
#     Running from numpy source directory.
#
#     Note: if you need reliable uninstall behavior, then install
#     with pip instead of using `setup.py install`:
#
#       - `pip install .`       (from a git repo or downloaded source
#                                release)
#       - `pip install numpy`   (last NumPy release on PyPi)
#
#
#     blas_opt_info:
#     blas_mkl_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries mkl_rt not found in ['C:\\Users\\seoye\\anaconda3\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     blis_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries blis not found in ['C:\\Users\\seoye\\anaconda3\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     openblas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas not found in ['C:\\Users\\seoye\\anaconda3\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\libs']
#     get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#     customize GnuFCompiler
#     Could not locate executable g77
#     Could not locate executable f77
#     customize IntelVisualFCompiler
#     Could not locate executable ifort
#     Could not locate executable ifl
#     customize AbsoftFCompiler
#     Could not locate executable f90
#     customize CompaqVisualFCompiler
#     Could not locate executable DF
#     customize IntelItaniumVisualFCompiler
#     Could not locate executable efl
#     customize Gnu95FCompiler
#     Could not locate executable gfortran
#     Could not locate executable f95
#     customize G95FCompiler
#     Could not locate executable g95
#     customize IntelEM64VisualFCompiler
#     customize IntelEM64TFCompiler
#     Could not locate executable efort
#     Could not locate executable efc
#     customize PGroupFlangCompiler
#     Could not locate executable flang
#     don't know how to compile Fortran code on platform 'nt'
#       NOT AVAILABLE
#
#     atlas_3_10_blas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas not found in ['C:\\Users\\seoye\\anaconda3\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_3_10_blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas not found in ['C:\\Users\\seoye\\anaconda3\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_blas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in ['C:\\Users\\seoye\\anaconda3\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in ['C:\\Users\\seoye\\anaconda3\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     accelerate_info:
#       NOT AVAILABLE
#
#     C:\Users\seoye\AppData\Local\Temp\pip-install-2qm72zxu\numpy_e956bd9dd07a4632aa95b5b81aaa107b\numpy\distutils\system_info.py:639: UserWarning:
#         Atlas (http://math-atlas.sourceforge.net/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [atlas]) or by setting
#         the ATLAS environment variable.
#       self.calc_info()
#     blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries blas not found in ['C:\\Users\\seoye\\anaconda3\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     C:\Users\seoye\AppData\Local\Temp\pip-install-2qm72zxu\numpy_e956bd9dd07a4632aa95b5b81aaa107b\numpy\distutils\system_info.py:639: UserWarning:
#         Blas (http://www.netlib.org/blas/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [blas]) or by setting
#         the BLAS environment variable.
#       self.calc_info()
#     blas_src_info:
#       NOT AVAILABLE
#
#     C:\Users\seoye\AppData\Local\Temp\pip-install-2qm72zxu\numpy_e956bd9dd07a4632aa95b5b81aaa107b\numpy\distutils\system_info.py:639: UserWarning:
#         Blas (http://www.netlib.org/blas/) sources not found.
#         Directories to search for the sources can be specified in the
#         numpy/distutils/site.cfg file (section [blas_src]) or by setting
#         the BLAS_SRC environment variable.
#       self.calc_info()
#       NOT AVAILABLE
#
#     'svnversion'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
#     배치 파일이 아닙니다.
#     non-existing path in 'numpy\\distutils': 'site.cfg'
#     lapack_opt_info:
#     lapack_mkl_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries mkl_rt not found in ['C:\\Users\\seoye\\anaconda3\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     openblas_lapack_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas not found in ['C:\\Users\\seoye\\anaconda3\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     openblas_clapack_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas,lapack not found in ['C:\\Users\\seoye\\anaconda3\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_3_10_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\seoye\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in C:\Users\seoye\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\seoye\anaconda3\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in C:\Users\seoye\anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#       NOT AVAILABLE
#
#     atlas_3_10_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\seoye\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in C:\Users\seoye\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\seoye\anaconda3\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in C:\Users\seoye\anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_3_10_info'>
#       NOT AVAILABLE
#
#     atlas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\seoye\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in C:\Users\seoye\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\seoye\anaconda3\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in C:\Users\seoye\anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_threads_info'>
#       NOT AVAILABLE
#
#     atlas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\seoye\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in C:\Users\seoye\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\seoye\anaconda3\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in C:\Users\seoye\anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_info'>
#       NOT AVAILABLE
#
#     lapack_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack not found in ['C:\\Users\\seoye\\anaconda3\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     C:\Users\seoye\AppData\Local\Temp\pip-install-2qm72zxu\numpy_e956bd9dd07a4632aa95b5b81aaa107b\numpy\distutils\system_info.py:639: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [lapack]) or by setting
#         the LAPACK environment variable.
#       self.calc_info()
#     lapack_src_info:
#       NOT AVAILABLE
#
#     C:\Users\seoye\AppData\Local\Temp\pip-install-2qm72zxu\numpy_e956bd9dd07a4632aa95b5b81aaa107b\numpy\distutils\system_info.py:639: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) sources not found.
#         Directories to search for the sources can be specified in the
#         numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#         the LAPACK_SRC environment variable.
#       self.calc_info()
#       NOT AVAILABLE
#
#     C:\Users\seoye\anaconda3\lib\site-packages\setuptools\_distutils\dist.py:275: UserWarning: Unknown distribution option: 'define_macros'
#       warnings.warn(msg)
#     running install
#     C:\Users\seoye\anaconda3\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#       warnings.warn(
#     running build
#     running config_cc
#     unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#     running config_fc
#     unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#     running build_src
#     build_src
#     building py_modules sources
#     building library "npymath" sources
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Users\seoye\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\seoye\\AppData\\Local\\Temp\\pip-install-2qm72zxu\\numpy_e956bd9dd07a4632aa95b5b81aaa107b\\setup.py'"'"'; __file__='"'"'C:\\Users\\seoye\\AppData\\Local\\Temp\\pip-install-2qm72zxu\\numpy_e956bd9dd07a4632aa95b5b81aaa107b\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\seoye\AppData\Local\Temp\pip-record-hm5vdro0\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\seoye\anaconda3\Include\numpy' Check the logs for full command output.

# %%
! pip install gluonnlp pandas tqdm
# Out:
# Collecting gluonnlp
#   Using cached gluonnlp-0.10.0.tar.gz (344 kB)
# Requirement already satisfied: pandas in c:\users\seoye\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: tqdm in c:\users\seoye\anaconda3\lib\site-packages (4.64.0)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\seoye\anaconda3\lib\site-packages (from gluonnlp) (1.21.5)
# Requirement already satisfied: cython in c:\users\seoye\anaconda3\lib\site-packages (from gluonnlp) (0.29.28)
# Requirement already satisfied: packaging in c:\users\seoye\anaconda3\lib\site-packages (from gluonnlp) (21.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\seoye\anaconda3\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\seoye\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: colorama in c:\users\seoye\anaconda3\lib\site-packages (from tqdm) (0.4.4)
# Requirement already satisfied: six>=1.5 in c:\users\seoye\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\seoye\anaconda3\lib\site-packages (from packaging->gluonnlp) (3.0.4)
# Building wheels for collected packages: gluonnlp
#   Building wheel for gluonnlp (setup.py): started
#   Building wheel for gluonnlp (setup.py): finished with status 'error'
#   Running setup.py clean for gluonnlp
# Failed to build gluonnlp
# Installing collected packages: gluonnlp
#     Running setup.py install for gluonnlp: started
#     Running setup.py install for gluonnlp: finished with status 'error'
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\seoye\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\seoye\\AppData\\Local\\Temp\\pip-install-hi15xpld\\gluonnlp_54302d344c634f1f8b06255a84f7bf5f\\setup.py'"'"'; __file__='"'"'C:\\Users\\seoye\\AppData\\Local\\Temp\\pip-install-hi15xpld\\gluonnlp_54302d344c634f1f8b06255a84f7bf5f\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\seoye\AppData\Local\Temp\pip-wheel-861nv6b_'
#        cwd: C:\Users\seoye\AppData\Local\Temp\pip-install-hi15xpld\gluonnlp_54302d344c634f1f8b06255a84f7bf5f\
#   Complete output (124 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.9
#   creating build\lib.win-amd64-3.9\gluonnlp
#   copying src\gluonnlp\base.py -> build\lib.win-amd64-3.9\gluonnlp
#   copying src\gluonnlp\_constants.py -> build\lib.win-amd64-3.9\gluonnlp
#   copying src\gluonnlp\__init__.py -> build\lib.win-amd64-3.9\gluonnlp
#   creating build\lib.win-amd64-3.9\gluonnlp\calibration
#   copying src\gluonnlp\calibration\collector.py -> build\lib.win-amd64-3.9\gluonnlp\calibration
#   copying src\gluonnlp\calibration\__init__.py -> build\lib.win-amd64-3.9\gluonnlp\calibration
#   creating build\lib.win-amd64-3.9\gluonnlp\data
#   copying src\gluonnlp\data\baidu_ernie_data.py -> build\lib.win-amd64-3.9\gluonnlp\data
#   copying src\gluonnlp\data\candidate_sampler.py -> build\lib.win-amd64-3.9\gluonnlp\data
#   copying src\gluonnlp\data\classification.py -> build\lib.win-amd64-3.9\gluonnlp\data
#   copying src\gluonnlp\data\conll.py -> build\lib.win-amd64-3.9\gluonnlp\data
#   copying src\gluonnlp\data\dataloader.py -> build\lib.win-amd64-3.9\gluonnlp\data
#   copying src\gluonnlp\data\dataset.py -> build\lib.win-amd64-3.9\gluonnlp\data
#   copying src\gluonnlp\data\datasetloader.py -> build\lib.win-amd64-3.9\gluonnlp\data
#   copying src\gluonnlp\data\glue.py -> build\lib.win-amd64-3.9\gluonnlp\data
#   copying src\gluonnlp\data\intent_slot.py -> build\lib.win-amd64-3.9\gluonnlp\data
#   copying src\gluonnlp\data\question_answering.py -> build\lib.win-amd64-3.9\gluonnlp\data
#   copying src\gluonnlp\data\registry.py -> build\lib.win-amd64-3.9\gluonnlp\data
#   copying src\gluonnlp\data\sampler.py -> build\lib.win-amd64-3.9\gluonnlp\data
#   copying src\gluonnlp\data\sentiment.py -> build\lib.win-amd64-3.9\gluonnlp\data
#   copying src\gluonnlp\data\stream.py -> build\lib.win-amd64-3.9\gluonnlp\data
#   copying src\gluonnlp\data\super_glue.py -> build\lib.win-amd64-3.9\gluonnlp\data
#   copying src\gluonnlp\data\transforms.py -> build\lib.win-amd64-3.9\gluonnlp\data
#   copying src\gluonnlp\data\translation.py -> build\lib.win-amd64-3.9\gluonnlp\data
#   copying src\gluonnlp\data\utils.py -> build\lib.win-amd64-3.9\gluonnlp\data
#   copying src\gluonnlp\data\word_embedding_evaluation.py -> build\lib.win-amd64-3.9\gluonnlp\data
#   copying src\gluonnlp\data\__init__.py -> build\lib.win-amd64-3.9\gluonnlp\data
#   creating build\lib.win-amd64-3.9\gluonnlp\embedding
#   copying src\gluonnlp\embedding\evaluation.py -> build\lib.win-amd64-3.9\gluonnlp\embedding
#   copying src\gluonnlp\embedding\token_embedding.py -> build\lib.win-amd64-3.9\gluonnlp\embedding
#   copying src\gluonnlp\embedding\__init__.py -> build\lib.win-amd64-3.9\gluonnlp\embedding
#   creating build\lib.win-amd64-3.9\gluonnlp\initializer
#   copying src\gluonnlp\initializer\initializer.py -> build\lib.win-amd64-3.9\gluonnlp\initializer
#   copying src\gluonnlp\initializer\__init__.py -> build\lib.win-amd64-3.9\gluonnlp\initializer
#   creating build\lib.win-amd64-3.9\gluonnlp\loss
#   copying src\gluonnlp\loss\activation_regularizer.py -> build\lib.win-amd64-3.9\gluonnlp\loss
#   copying src\gluonnlp\loss\label_smoothing.py -> build\lib.win-amd64-3.9\gluonnlp\loss
#   copying src\gluonnlp\loss\loss.py -> build\lib.win-amd64-3.9\gluonnlp\loss
#   copying src\gluonnlp\loss\__init__.py -> build\lib.win-amd64-3.9\gluonnlp\loss
#   creating build\lib.win-amd64-3.9\gluonnlp\metric
#   copying src\gluonnlp\metric\length_normalized_loss.py -> build\lib.win-amd64-3.9\gluonnlp\metric
#   copying src\gluonnlp\metric\masked_accuracy.py -> build\lib.win-amd64-3.9\gluonnlp\metric
#   copying src\gluonnlp\metric\__init__.py -> build\lib.win-amd64-3.9\gluonnlp\metric
#   creating build\lib.win-amd64-3.9\gluonnlp\model
#   copying src\gluonnlp\model\attention_cell.py -> build\lib.win-amd64-3.9\gluonnlp\model
#   copying src\gluonnlp\model\bert.py -> build\lib.win-amd64-3.9\gluonnlp\model
#   copying src\gluonnlp\model\bilm_encoder.py -> build\lib.win-amd64-3.9\gluonnlp\model
#   copying src\gluonnlp\model\block.py -> build\lib.win-amd64-3.9\gluonnlp\model
#   copying src\gluonnlp\model\convolutional_encoder.py -> build\lib.win-amd64-3.9\gluonnlp\model
#   copying src\gluonnlp\model\elmo.py -> build\lib.win-amd64-3.9\gluonnlp\model
#   copying src\gluonnlp\model\highway.py -> build\lib.win-amd64-3.9\gluonnlp\model
#   copying src\gluonnlp\model\info.py -> build\lib.win-amd64-3.9\gluonnlp\model
#   copying src\gluonnlp\model\language_model.py -> build\lib.win-amd64-3.9\gluonnlp\model
#   copying src\gluonnlp\model\lstmpcellwithclip.py -> build\lib.win-amd64-3.9\gluonnlp\model
#   copying src\gluonnlp\model\parameter.py -> build\lib.win-amd64-3.9\gluonnlp\model
#   copying src\gluonnlp\model\sampled_block.py -> build\lib.win-amd64-3.9\gluonnlp\model
#   copying src\gluonnlp\model\seq2seq_encoder_decoder.py -> build\lib.win-amd64-3.9\gluonnlp\model
#   copying src\gluonnlp\model\sequence_sampler.py -> build\lib.win-amd64-3.9\gluonnlp\model
#   copying src\gluonnlp\model\transformer.py -> build\lib.win-amd64-3.9\gluonnlp\model
#   copying src\gluonnlp\model\translation.py -> build\lib.win-amd64-3.9\gluonnlp\model
#   copying src\gluonnlp\model\utils.py -> build\lib.win-amd64-3.9\gluonnlp\model
#   copying src\gluonnlp\model\__init__.py -> build\lib.win-amd64-3.9\gluonnlp\model
#   creating build\lib.win-amd64-3.9\gluonnlp\optimizer
#   copying src\gluonnlp\optimizer\bert_adam.py -> build\lib.win-amd64-3.9\gluonnlp\optimizer
#   copying src\gluonnlp\optimizer\__init__.py -> build\lib.win-amd64-3.9\gluonnlp\optimizer
#   creating build\lib.win-amd64-3.9\gluonnlp\utils
#   copying src\gluonnlp\utils\files.py -> build\lib.win-amd64-3.9\gluonnlp\utils
#   copying src\gluonnlp\utils\parallel.py -> build\lib.win-amd64-3.9\gluonnlp\utils
#   copying src\gluonnlp\utils\parameter.py -> build\lib.win-amd64-3.9\gluonnlp\utils
#   copying src\gluonnlp\utils\seed.py -> build\lib.win-amd64-3.9\gluonnlp\utils
#   copying src\gluonnlp\utils\version.py -> build\lib.win-amd64-3.9\gluonnlp\utils
#   copying src\gluonnlp\utils\__init__.py -> build\lib.win-amd64-3.9\gluonnlp\utils
#   creating build\lib.win-amd64-3.9\gluonnlp\vocab
#   copying src\gluonnlp\vocab\bert.py -> build\lib.win-amd64-3.9\gluonnlp\vocab
#   copying src\gluonnlp\vocab\elmo.py -> build\lib.win-amd64-3.9\gluonnlp\vocab
#   copying src\gluonnlp\vocab\subwords.py -> build\lib.win-amd64-3.9\gluonnlp\vocab
#   copying src\gluonnlp\vocab\vocab.py -> build\lib.win-amd64-3.9\gluonnlp\vocab
#   copying src\gluonnlp\vocab\__init__.py -> build\lib.win-amd64-3.9\gluonnlp\vocab
#   creating build\lib.win-amd64-3.9\gluonnlp\data\batchify
#   copying src\gluonnlp\data\batchify\batchify.py -> build\lib.win-amd64-3.9\gluonnlp\data\batchify
#   copying src\gluonnlp\data\batchify\embedding.py -> build\lib.win-amd64-3.9\gluonnlp\data\batchify
#   copying src\gluonnlp\data\batchify\language_model.py -> build\lib.win-amd64-3.9\gluonnlp\data\batchify
#   copying src\gluonnlp\data\batchify\__init__.py -> build\lib.win-amd64-3.9\gluonnlp\data\batchify
#   creating build\lib.win-amd64-3.9\gluonnlp\data\bert
#   copying src\gluonnlp\data\bert\glue.py -> build\lib.win-amd64-3.9\gluonnlp\data\bert
#   copying src\gluonnlp\data\bert\squad.py -> build\lib.win-amd64-3.9\gluonnlp\data\bert
#   copying src\gluonnlp\data\bert\__init__.py -> build\lib.win-amd64-3.9\gluonnlp\data\bert
#   creating build\lib.win-amd64-3.9\gluonnlp\data\corpora
#   copying src\gluonnlp\data\corpora\google_billion_word.py -> build\lib.win-amd64-3.9\gluonnlp\data\corpora
#   copying src\gluonnlp\data\corpora\large_text_compression_benchmark.py -> build\lib.win-amd64-3.9\gluonnlp\data\corpora
#   copying src\gluonnlp\data\corpora\wikitext.py -> build\lib.win-amd64-3.9\gluonnlp\data\corpora
#   copying src\gluonnlp\data\corpora\__init__.py -> build\lib.win-amd64-3.9\gluonnlp\data\corpora
#   creating build\lib.win-amd64-3.9\gluonnlp\data\xlnet
#   copying src\gluonnlp\data\xlnet\squad.py -> build\lib.win-amd64-3.9\gluonnlp\data\xlnet
#   copying src\gluonnlp\data\xlnet\__init__.py -> build\lib.win-amd64-3.9\gluonnlp\data\xlnet
#   creating build\lib.win-amd64-3.9\gluonnlp\model\train
#   copying src\gluonnlp\model\train\cache.py -> build\lib.win-amd64-3.9\gluonnlp\model\train
#   copying src\gluonnlp\model\train\embedding.py -> build\lib.win-amd64-3.9\gluonnlp\model\train
#   copying src\gluonnlp\model\train\language_model.py -> build\lib.win-amd64-3.9\gluonnlp\model\train
#   copying src\gluonnlp\model\train\__init__.py -> build\lib.win-amd64-3.9\gluonnlp\model\train
#   running egg_info
#   writing src\gluonnlp.egg-info\PKG-INFO
#   writing dependency_links to src\gluonnlp.egg-info\dependency_links.txt
#   writing requirements to src\gluonnlp.egg-info\requires.txt
#   writing top-level names to src\gluonnlp.egg-info\top_level.txt
#   reading manifest file 'src\gluonnlp.egg-info\SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no files found matching '*.py' under directory 'gluonnlp'
#   warning: no previously-included files matching '*' found under directory 'tests'
#   warning: no previously-included files matching '*' found under directory 'scripts'
#   adding license file 'LICENSE'
#   writing manifest file 'src\gluonnlp.egg-info\SOURCES.txt'
#   copying src\gluonnlp\data\fast_bert_tokenizer.c -> build\lib.win-amd64-3.9\gluonnlp\data
#   copying src\gluonnlp\data\fast_bert_tokenizer.pyx -> build\lib.win-amd64-3.9\gluonnlp\data
#   running build_ext
#   skipping 'src/gluonnlp/data\fast_bert_tokenizer.c' Cython extension (up-to-date)
#   building 'gluonnlp.data.fast_bert_tokenizer' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for gluonnlp
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\seoye\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\seoye\\AppData\\Local\\Temp\\pip-install-hi15xpld\\gluonnlp_54302d344c634f1f8b06255a84f7bf5f\\setup.py'"'"'; __file__='"'"'C:\\Users\\seoye\\AppData\\Local\\Temp\\pip-install-hi15xpld\\gluonnlp_54302d344c634f1f8b06255a84f7bf5f\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\seoye\AppData\Local\Temp\pip-record-ytafiul6\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\seoye\anaconda3\Include\gluonnlp'
#          cwd: C:\Users\seoye\AppData\Local\Temp\pip-install-hi15xpld\gluonnlp_54302d344c634f1f8b06255a84f7bf5f\
#     Complete output (126 lines):
#     running install
#     C:\Users\seoye\anaconda3\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#       warnings.warn(
#     running build
#     running build_py
#     creating build
#     creating build\lib.win-amd64-3.9
#     creating build\lib.win-amd64-3.9\gluonnlp
#     copying src\gluonnlp\base.py -> build\lib.win-amd64-3.9\gluonnlp
#     copying src\gluonnlp\_constants.py -> build\lib.win-amd64-3.9\gluonnlp
#     copying src\gluonnlp\__init__.py -> build\lib.win-amd64-3.9\gluonnlp
#     creating build\lib.win-amd64-3.9\gluonnlp\calibration
#     copying src\gluonnlp\calibration\collector.py -> build\lib.win-amd64-3.9\gluonnlp\calibration
#     copying src\gluonnlp\calibration\__init__.py -> build\lib.win-amd64-3.9\gluonnlp\calibration
#     creating build\lib.win-amd64-3.9\gluonnlp\data
#     copying src\gluonnlp\data\baidu_ernie_data.py -> build\lib.win-amd64-3.9\gluonnlp\data
#     copying src\gluonnlp\data\candidate_sampler.py -> build\lib.win-amd64-3.9\gluonnlp\data
#     copying src\gluonnlp\data\classification.py -> build\lib.win-amd64-3.9\gluonnlp\data
#     copying src\gluonnlp\data\conll.py -> build\lib.win-amd64-3.9\gluonnlp\data
#     copying src\gluonnlp\data\dataloader.py -> build\lib.win-amd64-3.9\gluonnlp\data
#     copying src\gluonnlp\data\dataset.py -> build\lib.win-amd64-3.9\gluonnlp\data
#     copying src\gluonnlp\data\datasetloader.py -> build\lib.win-amd64-3.9\gluonnlp\data
#     copying src\gluonnlp\data\glue.py -> build\lib.win-amd64-3.9\gluonnlp\data
#     copying src\gluonnlp\data\intent_slot.py -> build\lib.win-amd64-3.9\gluonnlp\data
#     copying src\gluonnlp\data\question_answering.py -> build\lib.win-amd64-3.9\gluonnlp\data
#     copying src\gluonnlp\data\registry.py -> build\lib.win-amd64-3.9\gluonnlp\data
#     copying src\gluonnlp\data\sampler.py -> build\lib.win-amd64-3.9\gluonnlp\data
#     copying src\gluonnlp\data\sentiment.py -> build\lib.win-amd64-3.9\gluonnlp\data
#     copying src\gluonnlp\data\stream.py -> build\lib.win-amd64-3.9\gluonnlp\data
#     copying src\gluonnlp\data\super_glue.py -> build\lib.win-amd64-3.9\gluonnlp\data
#     copying src\gluonnlp\data\transforms.py -> build\lib.win-amd64-3.9\gluonnlp\data
#     copying src\gluonnlp\data\translation.py -> build\lib.win-amd64-3.9\gluonnlp\data
#     copying src\gluonnlp\data\utils.py -> build\lib.win-amd64-3.9\gluonnlp\data
#     copying src\gluonnlp\data\word_embedding_evaluation.py -> build\lib.win-amd64-3.9\gluonnlp\data
#     copying src\gluonnlp\data\__init__.py -> build\lib.win-amd64-3.9\gluonnlp\data
#     creating build\lib.win-amd64-3.9\gluonnlp\embedding
#     copying src\gluonnlp\embedding\evaluation.py -> build\lib.win-amd64-3.9\gluonnlp\embedding
#     copying src\gluonnlp\embedding\token_embedding.py -> build\lib.win-amd64-3.9\gluonnlp\embedding
#     copying src\gluonnlp\embedding\__init__.py -> build\lib.win-amd64-3.9\gluonnlp\embedding
#     creating build\lib.win-amd64-3.9\gluonnlp\initializer
#     copying src\gluonnlp\initializer\initializer.py -> build\lib.win-amd64-3.9\gluonnlp\initializer
#     copying src\gluonnlp\initializer\__init__.py -> build\lib.win-amd64-3.9\gluonnlp\initializer
#     creating build\lib.win-amd64-3.9\gluonnlp\loss
#     copying src\gluonnlp\loss\activation_regularizer.py -> build\lib.win-amd64-3.9\gluonnlp\loss
#     copying src\gluonnlp\loss\label_smoothing.py -> build\lib.win-amd64-3.9\gluonnlp\loss
#     copying src\gluonnlp\loss\loss.py -> build\lib.win-amd64-3.9\gluonnlp\loss
#     copying src\gluonnlp\loss\__init__.py -> build\lib.win-amd64-3.9\gluonnlp\loss
#     creating build\lib.win-amd64-3.9\gluonnlp\metric
#     copying src\gluonnlp\metric\length_normalized_loss.py -> build\lib.win-amd64-3.9\gluonnlp\metric
#     copying src\gluonnlp\metric\masked_accuracy.py -> build\lib.win-amd64-3.9\gluonnlp\metric
#     copying src\gluonnlp\metric\__init__.py -> build\lib.win-amd64-3.9\gluonnlp\metric
#     creating build\lib.win-amd64-3.9\gluonnlp\model
#     copying src\gluonnlp\model\attention_cell.py -> build\lib.win-amd64-3.9\gluonnlp\model
#     copying src\gluonnlp\model\bert.py -> build\lib.win-amd64-3.9\gluonnlp\model
#     copying src\gluonnlp\model\bilm_encoder.py -> build\lib.win-amd64-3.9\gluonnlp\model
#     copying src\gluonnlp\model\block.py -> build\lib.win-amd64-3.9\gluonnlp\model
#     copying src\gluonnlp\model\convolutional_encoder.py -> build\lib.win-amd64-3.9\gluonnlp\model
#     copying src\gluonnlp\model\elmo.py -> build\lib.win-amd64-3.9\gluonnlp\model
#     copying src\gluonnlp\model\highway.py -> build\lib.win-amd64-3.9\gluonnlp\model
#     copying src\gluonnlp\model\info.py -> build\lib.win-amd64-3.9\gluonnlp\model
#     copying src\gluonnlp\model\language_model.py -> build\lib.win-amd64-3.9\gluonnlp\model
#     copying src\gluonnlp\model\lstmpcellwithclip.py -> build\lib.win-amd64-3.9\gluonnlp\model
#     copying src\gluonnlp\model\parameter.py -> build\lib.win-amd64-3.9\gluonnlp\model
#     copying src\gluonnlp\model\sampled_block.py -> build\lib.win-amd64-3.9\gluonnlp\model
#     copying src\gluonnlp\model\seq2seq_encoder_decoder.py -> build\lib.win-amd64-3.9\gluonnlp\model
#     copying src\gluonnlp\model\sequence_sampler.py -> build\lib.win-amd64-3.9\gluonnlp\model
#     copying src\gluonnlp\model\transformer.py -> build\lib.win-amd64-3.9\gluonnlp\model
#     copying src\gluonnlp\model\translation.py -> build\lib.win-amd64-3.9\gluonnlp\model
#     copying src\gluonnlp\model\utils.py -> build\lib.win-amd64-3.9\gluonnlp\model
#     copying src\gluonnlp\model\__init__.py -> build\lib.win-amd64-3.9\gluonnlp\model
#     creating build\lib.win-amd64-3.9\gluonnlp\optimizer
#     copying src\gluonnlp\optimizer\bert_adam.py -> build\lib.win-amd64-3.9\gluonnlp\optimizer
#     copying src\gluonnlp\optimizer\__init__.py -> build\lib.win-amd64-3.9\gluonnlp\optimizer
#     creating build\lib.win-amd64-3.9\gluonnlp\utils
#     copying src\gluonnlp\utils\files.py -> build\lib.win-amd64-3.9\gluonnlp\utils
#     copying src\gluonnlp\utils\parallel.py -> build\lib.win-amd64-3.9\gluonnlp\utils
#     copying src\gluonnlp\utils\parameter.py -> build\lib.win-amd64-3.9\gluonnlp\utils
#     copying src\gluonnlp\utils\seed.py -> build\lib.win-amd64-3.9\gluonnlp\utils
#     copying src\gluonnlp\utils\version.py -> build\lib.win-amd64-3.9\gluonnlp\utils
#     copying src\gluonnlp\utils\__init__.py -> build\lib.win-amd64-3.9\gluonnlp\utils
#     creating build\lib.win-amd64-3.9\gluonnlp\vocab
#     copying src\gluonnlp\vocab\bert.py -> build\lib.win-amd64-3.9\gluonnlp\vocab
#     copying src\gluonnlp\vocab\elmo.py -> build\lib.win-amd64-3.9\gluonnlp\vocab
#     copying src\gluonnlp\vocab\subwords.py -> build\lib.win-amd64-3.9\gluonnlp\vocab
#     copying src\gluonnlp\vocab\vocab.py -> build\lib.win-amd64-3.9\gluonnlp\vocab
#     copying src\gluonnlp\vocab\__init__.py -> build\lib.win-amd64-3.9\gluonnlp\vocab
#     creating build\lib.win-amd64-3.9\gluonnlp\data\batchify
#     copying src\gluonnlp\data\batchify\batchify.py -> build\lib.win-amd64-3.9\gluonnlp\data\batchify
#     copying src\gluonnlp\data\batchify\embedding.py -> build\lib.win-amd64-3.9\gluonnlp\data\batchify
#     copying src\gluonnlp\data\batchify\language_model.py -> build\lib.win-amd64-3.9\gluonnlp\data\batchify
#     copying src\gluonnlp\data\batchify\__init__.py -> build\lib.win-amd64-3.9\gluonnlp\data\batchify
#     creating build\lib.win-amd64-3.9\gluonnlp\data\bert
#     copying src\gluonnlp\data\bert\glue.py -> build\lib.win-amd64-3.9\gluonnlp\data\bert
#     copying src\gluonnlp\data\bert\squad.py -> build\lib.win-amd64-3.9\gluonnlp\data\bert
#     copying src\gluonnlp\data\bert\__init__.py -> build\lib.win-amd64-3.9\gluonnlp\data\bert
#     creating build\lib.win-amd64-3.9\gluonnlp\data\corpora
#     copying src\gluonnlp\data\corpora\google_billion_word.py -> build\lib.win-amd64-3.9\gluonnlp\data\corpora
#     copying src\gluonnlp\data\corpora\large_text_compression_benchmark.py -> build\lib.win-amd64-3.9\gluonnlp\data\corpora
#     copying src\gluonnlp\data\corpora\wikitext.py -> build\lib.win-amd64-3.9\gluonnlp\data\corpora
#     copying src\gluonnlp\data\corpora\__init__.py -> build\lib.win-amd64-3.9\gluonnlp\data\corpora
#     creating build\lib.win-amd64-3.9\gluonnlp\data\xlnet
#     copying src\gluonnlp\data\xlnet\squad.py -> build\lib.win-amd64-3.9\gluonnlp\data\xlnet
#     copying src\gluonnlp\data\xlnet\__init__.py -> build\lib.win-amd64-3.9\gluonnlp\data\xlnet
#     creating build\lib.win-amd64-3.9\gluonnlp\model\train
#     copying src\gluonnlp\model\train\cache.py -> build\lib.win-amd64-3.9\gluonnlp\model\train
#     copying src\gluonnlp\model\train\embedding.py -> build\lib.win-amd64-3.9\gluonnlp\model\train
#     copying src\gluonnlp\model\train\language_model.py -> build\lib.win-amd64-3.9\gluonnlp\model\train
#     copying src\gluonnlp\model\train\__init__.py -> build\lib.win-amd64-3.9\gluonnlp\model\train
#     running egg_info
#     writing src\gluonnlp.egg-info\PKG-INFO
#     writing dependency_links to src\gluonnlp.egg-info\dependency_links.txt
#     writing requirements to src\gluonnlp.egg-info\requires.txt
#     writing top-level names to src\gluonnlp.egg-info\top_level.txt
#     reading manifest file 'src\gluonnlp.egg-info\SOURCES.txt'
#     reading manifest template 'MANIFEST.in'
#     warning: no files found matching '*.py' under directory 'gluonnlp'
#     warning: no previously-included files matching '*' found under directory 'tests'
#     warning: no previously-included files matching '*' found under directory 'scripts'
#     adding license file 'LICENSE'
#     writing manifest file 'src\gluonnlp.egg-info\SOURCES.txt'
#     copying src\gluonnlp\data\fast_bert_tokenizer.c -> build\lib.win-amd64-3.9\gluonnlp\data
#     copying src\gluonnlp\data\fast_bert_tokenizer.pyx -> build\lib.win-amd64-3.9\gluonnlp\data
#     running build_ext
#     skipping 'src/gluonnlp/data\fast_bert_tokenizer.c' Cython extension (up-to-date)
#     building 'gluonnlp.data.fast_bert_tokenizer' extension
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Users\seoye\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\seoye\\AppData\\Local\\Temp\\pip-install-hi15xpld\\gluonnlp_54302d344c634f1f8b06255a84f7bf5f\\setup.py'"'"'; __file__='"'"'C:\\Users\\seoye\\AppData\\Local\\Temp\\pip-install-hi15xpld\\gluonnlp_54302d344c634f1f8b06255a84f7bf5f\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\seoye\AppData\Local\Temp\pip-record-ytafiul6\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\seoye\anaconda3\Include\gluonnlp' Check the logs for full command output.

# %%
! pip install sentencepiece
# Out:
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp39-cp39-win_amd64.whl (1.1 MB)
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.97

# %%
! python --version
# Out:
# Python 3.9.12

# %%
! pip install snscrape
# Out:
# Collecting snscrape
#   Downloading snscrape-0.3.4-py3-none-any.whl (35 kB)
# Collecting requests[socks]
#   Using cached requests-2.28.1-py3-none-any.whl (62 kB)
# Collecting lxml
#   Downloading lxml-4.9.1-cp37-cp37m-win_amd64.whl (3.6 MB)
#      ---------------------------------------- 3.6/3.6 MB 7.9 MB/s eta 0:00:00
# Collecting beautifulsoup4
#   Using cached beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
# Collecting soupsieve>1.2
#   Using cached soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# Collecting charset-normalizer<3,>=2
#   Using cached charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.3-py3-none-any.whl (61 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Using cached urllib3-1.26.12-py2.py3-none-any.whl (140 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from requests[socks]->snscrape) (2022.6.15)
# Collecting PySocks!=1.5.7,>=1.5.6
#   Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Installing collected packages: urllib3, soupsieve, PySocks, lxml, idna, charset-normalizer, requests, beautifulsoup4, snscrape
# Successfully installed PySocks-1.7.1 beautifulsoup4-4.11.1 charset-normalizer-2.1.1 idna-3.3 lxml-4.9.1 requests-2.28.1 snscrape-0.3.4 soupsieve-2.3.2.post1 urllib3-1.26.12

# %%
! pip install pandas numpy
# Out:
# Collecting pandas
#   Downloading pandas-1.3.5-cp37-cp37m-win_amd64.whl (10.0 MB)
#      ---------------------------------------- 10.0/10.0 MB 8.9 MB/s eta 0:00:00
# Collecting numpy
#   Downloading numpy-1.21.6-cp37-cp37m-win_amd64.whl (14.0 MB)
#      ---------------------------------------- 14.0/14.0 MB 9.3 MB/s eta 0:00:00
# Collecting pytz>=2017.3
#   Using cached pytz-2022.2.1-py2.py3-none-any.whl (500 kB)
# Collecting python-dateutil>=2.7.3
#   Using cached python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Collecting six>=1.5
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: pytz, six, numpy, python-dateutil, pandas
# Successfully installed numpy-1.21.6 pandas-1.3.5 python-dateutil-2.8.2 pytz-2022.2.1 six-1.16.0

# %%
! pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.10.0-cp37-cp37m-win_amd64.whl (455.9 MB)
#      -------------------------------------- 455.9/455.9 MB 3.3 MB/s eta 0:00:00
# Collecting tensorboard<2.11,>=2.10
#   Using cached tensorboard-2.10.0-py3-none-any.whl (5.9 MB)
# Collecting typing-extensions>=3.6.6
#   Downloading typing_extensions-4.3.0-py3-none-any.whl (25 kB)
# Collecting absl-py>=1.0.0
#   Using cached absl_py-1.2.0-py3-none-any.whl (123 kB)
# Collecting flatbuffers>=2.0
#   Using cached flatbuffers-2.0.7-py2.py3-none-any.whl (26 kB)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-2.0.0-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: setuptools in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from tensorflow) (63.4.1)
# Collecting h5py>=2.9.0
#   Downloading h5py-3.7.0-cp37-cp37m-win_amd64.whl (2.6 MB)
#      ---------------------------------------- 2.6/2.6 MB 9.3 MB/s eta 0:00:00
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.48.1-cp37-cp37m-win_amd64.whl (3.6 MB)
#      ---------------------------------------- 3.6/3.6 MB 6.1 MB/s eta 0:00:00
# Collecting libclang>=13.0.0
#   Using cached libclang-14.0.6-py2.py3-none-win_amd64.whl (14.2 MB)
# Collecting wrapt>=1.11.0
#   Downloading wrapt-1.14.1-cp37-cp37m-win_amd64.whl (35 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.27.0-cp37-cp37m-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.12.0 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from tensorflow) (1.16.0)
# Collecting keras<2.11,>=2.10.0
#   Using cached keras-2.10.0-py2.py3-none-any.whl (1.7 MB)
# Collecting packaging
#   Downloading packaging-21.3-py3-none-any.whl (40 kB)
#      -------------------------------------- 40.8/40.8 kB 177.4 kB/s eta 0:00:00
# Collecting gast<=0.4.0,>=0.2.1
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting protobuf<3.20,>=3.9.2
#   Downloading protobuf-3.19.4-cp37-cp37m-win_amd64.whl (896 kB)
#      -------------------------------------- 896.4/896.4 kB 8.1 MB/s eta 0:00:00
# Collecting keras-preprocessing>=1.1.1
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting tensorflow-estimator<2.11,>=2.10.0
#   Using cached tensorflow_estimator-2.10.0-py2.py3-none-any.whl (438 kB)
# Requirement already satisfied: numpy>=1.20 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from tensorflow) (1.21.6)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.11.0-py2.py3-none-any.whl (167 kB)
#      -------------------------------------- 167.2/167.2 kB 5.1 MB/s eta 0:00:00
# Collecting tensorboard-plugin-wit>=1.6.0
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.28.1)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.4.1-py3-none-any.whl (93 kB)
#      ---------------------------------------- 93.3/93.3 kB 5.5 MB/s eta 0:00:00
# Collecting werkzeug>=1.0.1
#   Downloading Werkzeug-2.2.2-py3-none-any.whl (232 kB)
#      -------------------------------------- 232.7/232.7 kB 7.0 MB/s eta 0:00:00
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Collecting pyparsing!=3.0.5,>=2.0.2
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      ---------------------------------------- 98.3/98.3 kB 5.9 MB/s eta 0:00:00
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      -------------------------------------- 155.3/155.3 kB 9.7 MB/s eta 0:00:00
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting importlib-metadata>=4.4
#   Downloading importlib_metadata-4.12.0-py3-none-any.whl (21 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.1.1)
# Collecting MarkupSafe>=2.1.1
#   Downloading MarkupSafe-2.1.1-cp37-cp37m-win_amd64.whl (17 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.8.1-py3-none-any.whl (5.6 kB)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      ---------------------------------------- 77.1/77.1 kB 4.2 MB/s eta 0:00:00
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.1-py3-none-any.whl (151 kB)
# Installing collected packages: tensorboard-plugin-wit, pyasn1, libclang, keras, flatbuffers, zipp, wrapt, typing-extensions, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, rsa, pyparsing, pyasn1-modules, protobuf, opt-einsum, oauthlib, MarkupSafe, keras-preprocessing, h5py, grpcio, google-pasta, gast, cachetools, astunparse, absl-py, werkzeug, requests-oauthlib, packaging, importlib-metadata, google-auth, markdown, google-auth-oauthlib, tensorboard, tensorflow
# Successfully installed MarkupSafe-2.1.1 absl-py-1.2.0 astunparse-1.6.3 cachetools-5.2.0 flatbuffers-2.0.7 gast-0.4.0 google-auth-2.11.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.48.1 h5py-3.7.0 importlib-metadata-4.12.0 keras-2.10.0 keras-preprocessing-1.1.2 libclang-14.0.6 markdown-3.4.1 oauthlib-3.2.1 opt-einsum-3.3.0 packaging-21.3 protobuf-3.19.4 pyasn1-0.4.8 pyasn1-modules-0.2.8 pyparsing-3.0.9 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.10.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.10.0 tensorflow-estimator-2.10.0 tensorflow-io-gcs-filesystem-0.27.0 termcolor-2.0.0 typing-extensions-4.3.0 werkzeug-2.2.2 wrapt-1.14.1 zipp-3.8.1

# %%
# !pip install mxnet
# !pip install gluonnlp pandas tqdm
# !pip install sentencepiece
# !pip install transformers==3.0.2
# !pip install torch
# Out:
# Collecting mxnet
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.10.0 requires numpy>=1.20, but you have numpy 1.16.6 which is incompatible.
# tensorboard 2.10.0 requires requests<3,>=2.21.0, but you have requests 2.18.4 which is incompatible.
# pandas 1.3.5 requires numpy>=1.17.3; platform_machine != "aarch64" and platform_machine != "arm64" and python_version < "3.10", but you have numpy 1.16.6 which is incompatible.
#   Using cached mxnet-1.7.0.post2-py2.py3-none-win_amd64.whl (33.1 MB)
# Collecting graphviz<0.9.0,>=0.8.1
#   Using cached graphviz-0.8.4-py2.py3-none-any.whl (16 kB)
# Collecting requests<2.19.0,>=2.18.4
#   Using cached requests-2.18.4-py2.py3-none-any.whl (88 kB)
# Collecting numpy<1.17.0,>=1.8.2
#   Downloading numpy-1.16.6-cp37-cp37m-win_amd64.whl (11.9 MB)
#      ---------------------------------------- 11.9/11.9 MB 6.2 MB/s eta 0:00:00
# Collecting chardet<3.1.0,>=3.0.2
#   Using cached chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting urllib3<1.23,>=1.21.1
#   Using cached urllib3-1.22-py2.py3-none-any.whl (132 kB)
# Collecting idna<2.7,>=2.5
#   Using cached idna-2.6-py2.py3-none-any.whl (56 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from requests<2.19.0,>=2.18.4->mxnet) (2022.6.15)
# Installing collected packages: urllib3, idna, chardet, requests, numpy, graphviz, mxnet
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.12
#     Uninstalling urllib3-1.26.12:
#       Successfully uninstalled urllib3-1.26.12
#   Attempting uninstall: idna
#     Found existing installation: idna 3.3
#     Uninstalling idna-3.3:
#       Successfully uninstalled idna-3.3
#   Attempting uninstall: requests
#     Found existing installation: requests 2.28.1
#     Uninstalling requests-2.28.1:
#       Successfully uninstalled requests-2.28.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
# Successfully installed chardet-3.0.4 graphviz-0.8.4 idna-2.6 mxnet-1.7.0.post2 numpy-1.16.6 requests-2.18.4 urllib3-1.22
# Collecting gluonnlp
#   Using cached gluonnlp-0.10.0.tar.gz (344 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pandas in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (1.3.5)
# Collecting tqdm
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.5/78.5 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.16.0 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from gluonnlp) (1.16.6)
# Collecting cython
#   Using cached Cython-0.29.32-py2.py3-none-any.whl (986 kB)
# Requirement already satisfied: packaging in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from gluonnlp) (21.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from pandas) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from pandas) (2.8.2)
# Collecting numpy>=1.16.0
#   Using cached numpy-1.21.6-cp37-cp37m-win_amd64.whl (14.0 MB)
# Collecting colorama
#   Downloading colorama-0.4.5-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: six>=1.5 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from packaging->gluonnlp) (3.0.9)
# Building wheels for collected packages: gluonnlp
#   Building wheel for gluonnlp (setup.py): started
#   Building wheel for gluonnlp (setup.py): finished with status 'error'
#   Running setup.py clean for gluonnlp
# Failed to build gluonnlp
# Installing collected packages: numpy, cython, colorama, tqdm, gluonnlp
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.16.6
#     Uninstalling numpy-1.16.6:
#       Successfully uninstalled numpy-1.16.6
#   Running setup.py install for gluonnlp: started
#   Running setup.py install for gluonnlp: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [126 lines of output]
#   C:\Users\seoye\anaconda3\envs\python3.7\lib\site-packages\setuptools\installer.py:30: SetuptoolsDeprecationWarning: setuptools.installer is deprecated. Requirements should be satisfied by a PEP 517 installer.
#     SetuptoolsDeprecationWarning,
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-37
#   creating build\lib.win-amd64-cpython-37\gluonnlp
#   copying src\gluonnlp\base.py -> build\lib.win-amd64-cpython-37\gluonnlp
#   copying src\gluonnlp\_constants.py -> build\lib.win-amd64-cpython-37\gluonnlp
#   copying src\gluonnlp\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp
#   creating build\lib.win-amd64-cpython-37\gluonnlp\calibration
#   copying src\gluonnlp\calibration\collector.py -> build\lib.win-amd64-cpython-37\gluonnlp\calibration
#   copying src\gluonnlp\calibration\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\calibration
#   creating build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\baidu_ernie_data.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\candidate_sampler.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\classification.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\conll.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\dataloader.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\dataset.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\datasetloader.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\glue.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\intent_slot.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\question_answering.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\registry.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\sampler.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\sentiment.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\stream.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\super_glue.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\transforms.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\translation.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\utils.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\word_embedding_evaluation.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   creating build\lib.win-amd64-cpython-37\gluonnlp\embedding
#   copying src\gluonnlp\embedding\evaluation.py -> build\lib.win-amd64-cpython-37\gluonnlp\embedding
#   copying src\gluonnlp\embedding\token_embedding.py -> build\lib.win-amd64-cpython-37\gluonnlp\embedding
#   copying src\gluonnlp\embedding\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\embedding
#   creating build\lib.win-amd64-cpython-37\gluonnlp\initializer
#   copying src\gluonnlp\initializer\initializer.py -> build\lib.win-amd64-cpython-37\gluonnlp\initializer
#   copying src\gluonnlp\initializer\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\initializer
#   creating build\lib.win-amd64-cpython-37\gluonnlp\loss
#   copying src\gluonnlp\loss\activation_regularizer.py -> build\lib.win-amd64-cpython-37\gluonnlp\loss
#   copying src\gluonnlp\loss\label_smoothing.py -> build\lib.win-amd64-cpython-37\gluonnlp\loss
#   copying src\gluonnlp\loss\loss.py -> build\lib.win-amd64-cpython-37\gluonnlp\loss
#   copying src\gluonnlp\loss\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\loss
#   creating build\lib.win-amd64-cpython-37\gluonnlp\metric
#   copying src\gluonnlp\metric\length_normalized_loss.py -> build\lib.win-amd64-cpython-37\gluonnlp\metric
#   copying src\gluonnlp\metric\masked_accuracy.py -> build\lib.win-amd64-cpython-37\gluonnlp\metric
#   copying src\gluonnlp\metric\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\metric
#   creating build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\attention_cell.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\bert.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\bilm_encoder.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\block.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\convolutional_encoder.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\elmo.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\highway.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\info.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\language_model.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\lstmpcellwithclip.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\parameter.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\sampled_block.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\seq2seq_encoder_decoder.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\sequence_sampler.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\transformer.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\translation.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\utils.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   creating build\lib.win-amd64-cpython-37\gluonnlp\optimizer
#   copying src\gluonnlp\optimizer\bert_adam.py -> build\lib.win-amd64-cpython-37\gluonnlp\optimizer
#   copying src\gluonnlp\optimizer\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\optimizer
#   creating build\lib.win-amd64-cpython-37\gluonnlp\utils
#   copying src\gluonnlp\utils\files.py -> build\lib.win-amd64-cpython-37\gluonnlp\utils
#   copying src\gluonnlp\utils\parallel.py -> build\lib.win-amd64-cpython-37\gluonnlp\utils
#   copying src\gluonnlp\utils\parameter.py -> build\lib.win-amd64-cpython-37\gluonnlp\utils
#   copying src\gluonnlp\utils\seed.py -> build\lib.win-amd64-cpython-37\gluonnlp\utils
#   copying src\gluonnlp\utils\version.py -> build\lib.win-amd64-cpython-37\gluonnlp\utils
#   copying src\gluonnlp\utils\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\utils
#   creating build\lib.win-amd64-cpython-37\gluonnlp\vocab
#   copying src\gluonnlp\vocab\bert.py -> build\lib.win-amd64-cpython-37\gluonnlp\vocab
#   copying src\gluonnlp\vocab\elmo.py -> build\lib.win-amd64-cpython-37\gluonnlp\vocab
#   copying src\gluonnlp\vocab\subwords.py -> build\lib.win-amd64-cpython-37\gluonnlp\vocab
#   copying src\gluonnlp\vocab\vocab.py -> build\lib.win-amd64-cpython-37\gluonnlp\vocab
#   copying src\gluonnlp\vocab\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\vocab
#   creating build\lib.win-amd64-cpython-37\gluonnlp\data\batchify
#   copying src\gluonnlp\data\batchify\batchify.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\batchify
#   copying src\gluonnlp\data\batchify\embedding.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\batchify
#   copying src\gluonnlp\data\batchify\language_model.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\batchify
#   copying src\gluonnlp\data\batchify\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\batchify
#   creating build\lib.win-amd64-cpython-37\gluonnlp\data\bert
#   copying src\gluonnlp\data\bert\glue.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\bert
#   copying src\gluonnlp\data\bert\squad.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\bert
#   copying src\gluonnlp\data\bert\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\bert
#   creating build\lib.win-amd64-cpython-37\gluonnlp\data\corpora
#   copying src\gluonnlp\data\corpora\google_billion_word.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\corpora
#   copying src\gluonnlp\data\corpora\large_text_compression_benchmark.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\corpora
#   copying src\gluonnlp\data\corpora\wikitext.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\corpora
#   copying src\gluonnlp\data\corpora\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\corpora
#   creating build\lib.win-amd64-cpython-37\gluonnlp\data\xlnet
#   copying src\gluonnlp\data\xlnet\squad.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\xlnet
#   copying src\gluonnlp\data\xlnet\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\xlnet
#   creating build\lib.win-amd64-cpython-37\gluonnlp\model\train
#   copying src\gluonnlp\model\train\cache.py -> build\lib.win-amd64-cpython-37\gluonnlp\model\train
#   copying src\gluonnlp\model\train\embedding.py -> build\lib.win-amd64-cpython-37\gluonnlp\model\train
#   copying src\gluonnlp\model\train\language_model.py -> build\lib.win-amd64-cpython-37\gluonnlp\model\train
#   copying src\gluonnlp\model\train\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\model\train
#   running egg_info
#   writing src\gluonnlp.egg-info\PKG-INFO
#   writing dependency_links to src\gluonnlp.egg-info\dependency_links.txt
#   writing requirements to src\gluonnlp.egg-info\requires.txt
#   writing top-level names to src\gluonnlp.egg-info\top_level.txt
#   reading manifest file 'src\gluonnlp.egg-info\SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no files found matching '*.py' under directory 'gluonnlp'
#   warning: no previously-included files matching '*' found under directory 'tests'
#   warning: no previously-included files matching '*' found under directory 'scripts'
#   adding license file 'LICENSE'
#   writing manifest file 'src\gluonnlp.egg-info\SOURCES.txt'
#   copying src\gluonnlp\data\fast_bert_tokenizer.c -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\fast_bert_tokenizer.pyx -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   running build_ext
#   skipping 'src/gluonnlp/data\fast_bert_tokenizer.c' Cython extension (up-to-date)
#   building 'gluonnlp.data.fast_bert_tokenizer' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for gluonnlp
#   error: subprocess-exited-with-error
#
#   Running setup.py install for gluonnlp did not run successfully.
#   exit code: 1
#
#   [126 lines of output]
#   running install
#   C:\Users\seoye\anaconda3\envs\python3.7\lib\site-packages\setuptools\command\install.py:37: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#     setuptools.SetuptoolsDeprecationWarning,
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-37
#   creating build\lib.win-amd64-cpython-37\gluonnlp
#   copying src\gluonnlp\base.py -> build\lib.win-amd64-cpython-37\gluonnlp
#   copying src\gluonnlp\_constants.py -> build\lib.win-amd64-cpython-37\gluonnlp
#   copying src\gluonnlp\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp
#   creating build\lib.win-amd64-cpython-37\gluonnlp\calibration
#   copying src\gluonnlp\calibration\collector.py -> build\lib.win-amd64-cpython-37\gluonnlp\calibration
#   copying src\gluonnlp\calibration\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\calibration
#   creating build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\baidu_ernie_data.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\candidate_sampler.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\classification.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\conll.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\dataloader.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\dataset.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\datasetloader.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\glue.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\intent_slot.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\question_answering.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\registry.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\sampler.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\sentiment.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\stream.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\super_glue.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\transforms.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\translation.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\utils.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\word_embedding_evaluation.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   creating build\lib.win-amd64-cpython-37\gluonnlp\embedding
#   copying src\gluonnlp\embedding\evaluation.py -> build\lib.win-amd64-cpython-37\gluonnlp\embedding
#   copying src\gluonnlp\embedding\token_embedding.py -> build\lib.win-amd64-cpython-37\gluonnlp\embedding
#   copying src\gluonnlp\embedding\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\embedding
#   creating build\lib.win-amd64-cpython-37\gluonnlp\initializer
#   copying src\gluonnlp\initializer\initializer.py -> build\lib.win-amd64-cpython-37\gluonnlp\initializer
#   copying src\gluonnlp\initializer\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\initializer
#   creating build\lib.win-amd64-cpython-37\gluonnlp\loss
#   copying src\gluonnlp\loss\activation_regularizer.py -> build\lib.win-amd64-cpython-37\gluonnlp\loss
#   copying src\gluonnlp\loss\label_smoothing.py -> build\lib.win-amd64-cpython-37\gluonnlp\loss
#   copying src\gluonnlp\loss\loss.py -> build\lib.win-amd64-cpython-37\gluonnlp\loss
#   copying src\gluonnlp\loss\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\loss
#   creating build\lib.win-amd64-cpython-37\gluonnlp\metric
#   copying src\gluonnlp\metric\length_normalized_loss.py -> build\lib.win-amd64-cpython-37\gluonnlp\metric
#   copying src\gluonnlp\metric\masked_accuracy.py -> build\lib.win-amd64-cpython-37\gluonnlp\metric
#   copying src\gluonnlp\metric\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\metric
#   creating build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\attention_cell.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\bert.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\bilm_encoder.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\block.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\convolutional_encoder.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\elmo.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\highway.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\info.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\language_model.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\lstmpcellwithclip.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\parameter.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\sampled_block.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\seq2seq_encoder_decoder.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\sequence_sampler.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\transformer.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\translation.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\utils.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   creating build\lib.win-amd64-cpython-37\gluonnlp\optimizer
#   copying src\gluonnlp\optimizer\bert_adam.py -> build\lib.win-amd64-cpython-37\gluonnlp\optimizer
#   copying src\gluonnlp\optimizer\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\optimizer
#   creating build\lib.win-amd64-cpython-37\gluonnlp\utils
#   copying src\gluonnlp\utils\files.py -> build\lib.win-amd64-cpython-37\gluonnlp\utils
#   copying src\gluonnlp\utils\parallel.py -> build\lib.win-amd64-cpython-37\gluonnlp\utils
#   copying src\gluonnlp\utils\parameter.py -> build\lib.win-amd64-cpython-37\gluonnlp\utils
#   copying src\gluonnlp\utils\seed.py -> build\lib.win-amd64-cpython-37\gluonnlp\utils
#   copying src\gluonnlp\utils\version.py -> build\lib.win-amd64-cpython-37\gluonnlp\utils
#   copying src\gluonnlp\utils\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\utils
#   creating build\lib.win-amd64-cpython-37\gluonnlp\vocab
#   copying src\gluonnlp\vocab\bert.py -> build\lib.win-amd64-cpython-37\gluonnlp\vocab
#   copying src\gluonnlp\vocab\elmo.py -> build\lib.win-amd64-cpython-37\gluonnlp\vocab
#   copying src\gluonnlp\vocab\subwords.py -> build\lib.win-amd64-cpython-37\gluonnlp\vocab
#   copying src\gluonnlp\vocab\vocab.py -> build\lib.win-amd64-cpython-37\gluonnlp\vocab
#   copying src\gluonnlp\vocab\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\vocab
#   creating build\lib.win-amd64-cpython-37\gluonnlp\data\batchify
#   copying src\gluonnlp\data\batchify\batchify.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\batchify
#   copying src\gluonnlp\data\batchify\embedding.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\batchify
#   copying src\gluonnlp\data\batchify\language_model.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\batchify
#   copying src\gluonnlp\data\batchify\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\batchify
#   creating build\lib.win-amd64-cpython-37\gluonnlp\data\bert
#   copying src\gluonnlp\data\bert\glue.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\bert
#   copying src\gluonnlp\data\bert\squad.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\bert
#   copying src\gluonnlp\data\bert\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\bert
#   creating build\lib.win-amd64-cpython-37\gluonnlp\data\corpora
#   copying src\gluonnlp\data\corpora\google_billion_word.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\corpora
#   copying src\gluonnlp\data\corpora\large_text_compression_benchmark.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\corpora
#   copying src\gluonnlp\data\corpora\wikitext.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\corpora
#   copying src\gluonnlp\data\corpora\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\corpora
#   creating build\lib.win-amd64-cpython-37\gluonnlp\data\xlnet
#   copying src\gluonnlp\data\xlnet\squad.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\xlnet
#   copying src\gluonnlp\data\xlnet\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\xlnet
#   creating build\lib.win-amd64-cpython-37\gluonnlp\model\train
#   copying src\gluonnlp\model\train\cache.py -> build\lib.win-amd64-cpython-37\gluonnlp\model\train
#   copying src\gluonnlp\model\train\embedding.py -> build\lib.win-amd64-cpython-37\gluonnlp\model\train
#   copying src\gluonnlp\model\train\language_model.py -> build\lib.win-amd64-cpython-37\gluonnlp\model\train
#   copying src\gluonnlp\model\train\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\model\train
#   running egg_info
#   writing src\gluonnlp.egg-info\PKG-INFO
#   writing dependency_links to src\gluonnlp.egg-info\dependency_links.txt
#   writing requirements to src\gluonnlp.egg-info\requires.txt
#   writing top-level names to src\gluonnlp.egg-info\top_level.txt
#   reading manifest file 'src\gluonnlp.egg-info\SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no files found matching '*.py' under directory 'gluonnlp'
#   warning: no previously-included files matching '*' found under directory 'tests'
#   warning: no previously-included files matching '*' found under directory 'scripts'
#   adding license file 'LICENSE'
#   writing manifest file 'src\gluonnlp.egg-info\SOURCES.txt'
#   copying src\gluonnlp\data\fast_bert_tokenizer.c -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\fast_bert_tokenizer.pyx -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   running build_ext
#   skipping 'src/gluonnlp/data\fast_bert_tokenizer.c' Cython extension (up-to-date)
#   building 'gluonnlp.data.fast_bert_tokenizer' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# Encountered error while trying to install package.
#
# gluonnlp
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp37-cp37m-win_amd64.whl (1.1 MB)
#      ---------------------------------------- 1.1/1.1 MB 6.5 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.97
# Collecting transformers==3.0.2
#   Downloading transformers-3.0.2-py3-none-any.whl (769 kB)
#      -------------------------------------- 769.0/769.0 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from transformers==3.0.2) (21.3)
# Collecting tokenizers==0.8.1.rc1
#   Downloading tokenizers-0.8.1rc1-cp37-cp37m-win_amd64.whl (1.9 MB)
#      ---------------------------------------- 1.9/1.9 MB 6.6 MB/s eta 0:00:00
# Collecting regex!=2019.12.17
#   Downloading regex-2022.9.11-cp37-cp37m-win_amd64.whl (263 kB)
#      -------------------------------------- 263.3/263.3 kB 8.2 MB/s eta 0:00:00
# Collecting filelock
#   Using cached filelock-3.8.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: requests in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from transformers==3.0.2) (2.18.4)
# Requirement already satisfied: numpy in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from transformers==3.0.2) (1.21.6)
# Requirement already satisfied: sentencepiece!=0.1.92 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from transformers==3.0.2) (0.1.97)
# Requirement already satisfied: tqdm>=4.27 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from transformers==3.0.2) (4.64.1)
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      -------------------------------------- 880.6/880.6 kB 9.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: colorama in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from tqdm>=4.27->transformers==3.0.2) (0.4.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from packaging->transformers==3.0.2) (3.0.9)
# Requirement already satisfied: idna<2.7,>=2.5 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from requests->transformers==3.0.2) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from requests->transformers==3.0.2) (1.22)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from requests->transformers==3.0.2) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from requests->transformers==3.0.2) (2022.6.15)
# Requirement already satisfied: six in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from sacremoses->transformers==3.0.2) (1.16.0)
# Collecting click
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ---------------------------------------- 96.6/96.6 kB 2.8 MB/s eta 0:00:00
# Collecting joblib
#   Downloading joblib-1.1.0-py2.py3-none-any.whl (306 kB)
#      -------------------------------------- 307.0/307.0 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from click->sacremoses->transformers==3.0.2) (4.12.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from importlib-metadata->click->sacremoses->transformers==3.0.2) (4.3.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from importlib-metadata->click->sacremoses->transformers==3.0.2) (3.8.1)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py): started
#   Building wheel for sacremoses (setup.py): finished with status 'done'
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895241 sha256=dafcc91947ca4bbe7aeeb01a8f4304b1d9e74a1ce1f54ef7b89d24dc70d6e8d7
#   Stored in directory: c:\users\seoye\appdata\local\pip\cache\wheels\87\39\dd\a83eeef36d0bf98e7a4d1933a4ad2d660295a40613079bafc9
# Successfully built sacremoses
# Installing collected packages: tokenizers, regex, joblib, filelock, click, sacremoses, transformers
# Successfully installed click-8.1.3 filelock-3.8.0 joblib-1.1.0 regex-2022.9.11 sacremoses-0.0.53 tokenizers-0.8.1rc1 transformers-3.0.2
# Collecting torch
#   Downloading torch-1.12.1-cp37-cp37m-win_amd64.whl (161.9 MB)
#      -------------------------------------- 161.9/161.9 MB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from torch) (4.3.0)
# Installing collected packages: torch
# Successfully installed torch-1.12.1

# %%
# !pip install mxnet
# Out:
# Requirement already satisfied: mxnet in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (1.7.0.post2)
# Requirement already satisfied: graphviz<0.9.0,>=0.8.1 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from mxnet) (0.8.4)
# Collecting numpy<1.17.0,>=1.8.2
#   Using cached numpy-1.16.6-cp37-cp37m-win_amd64.whl (11.9 MB)
# Requirement already satisfied: requests<2.19.0,>=2.18.4 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from mxnet) (2.18.4)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from requests<2.19.0,>=2.18.4->mxnet) (3.0.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from requests<2.19.0,>=2.18.4->mxnet) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from requests<2.19.0,>=2.18.4->mxnet) (2022.6.15)
# Requirement already satisfied: idna<2.7,>=2.5 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from requests<2.19.0,>=2.18.4->mxnet) (2.6)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
# Successfully installed numpy-1.16.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.10.0 requires numpy>=1.20, but you have numpy 1.16.6 which is incompatible.
# tensorboard 2.10.0 requires requests<3,>=2.21.0, but you have requests 2.18.4 which is incompatible.
# pandas 1.3.5 requires numpy>=1.17.3; platform_machine != "aarch64" and platform_machine != "arm64" and python_version < "3.10", but you have numpy 1.16.6 which is incompatible.

# %%
# !pip install gluonnlp pandas tqdm
# Out:
# Collecting gluonnlp
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [124 lines of output]
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-37
#   creating build\lib.win-amd64-cpython-37\gluonnlp
#   copying src\gluonnlp\base.py -> build\lib.win-amd64-cpython-37\gluonnlp
#   copying src\gluonnlp\_constants.py -> build\lib.win-amd64-cpython-37\gluonnlp
#   copying src\gluonnlp\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp
#   creating build\lib.win-amd64-cpython-37\gluonnlp\calibration
#   copying src\gluonnlp\calibration\collector.py -> build\lib.win-amd64-cpython-37\gluonnlp\calibration
#   copying src\gluonnlp\calibration\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\calibration
#   creating build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\baidu_ernie_data.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\candidate_sampler.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\classification.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\conll.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\dataloader.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\dataset.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\datasetloader.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\glue.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\intent_slot.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\question_answering.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\registry.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\sampler.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\sentiment.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\stream.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\super_glue.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\transforms.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\translation.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\utils.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\word_embedding_evaluation.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   creating build\lib.win-amd64-cpython-37\gluonnlp\embedding
#   copying src\gluonnlp\embedding\evaluation.py -> build\lib.win-amd64-cpython-37\gluonnlp\embedding
#   copying src\gluonnlp\embedding\token_embedding.py -> build\lib.win-amd64-cpython-37\gluonnlp\embedding
#   copying src\gluonnlp\embedding\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\embedding
#   creating build\lib.win-amd64-cpython-37\gluonnlp\initializer
#   copying src\gluonnlp\initializer\initializer.py -> build\lib.win-amd64-cpython-37\gluonnlp\initializer
#   copying src\gluonnlp\initializer\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\initializer
#   creating build\lib.win-amd64-cpython-37\gluonnlp\loss
#   copying src\gluonnlp\loss\activation_regularizer.py -> build\lib.win-amd64-cpython-37\gluonnlp\loss
#   copying src\gluonnlp\loss\label_smoothing.py -> build\lib.win-amd64-cpython-37\gluonnlp\loss
#   copying src\gluonnlp\loss\loss.py -> build\lib.win-amd64-cpython-37\gluonnlp\loss
#   copying src\gluonnlp\loss\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\loss
#   creating build\lib.win-amd64-cpython-37\gluonnlp\metric
#   copying src\gluonnlp\metric\length_normalized_loss.py -> build\lib.win-amd64-cpython-37\gluonnlp\metric
#   copying src\gluonnlp\metric\masked_accuracy.py -> build\lib.win-amd64-cpython-37\gluonnlp\metric
#   copying src\gluonnlp\metric\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\metric
#   creating build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\attention_cell.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\bert.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\bilm_encoder.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\block.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\convolutional_encoder.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\elmo.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\highway.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\info.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\language_model.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\lstmpcellwithclip.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\parameter.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\sampled_block.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\seq2seq_encoder_decoder.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\sequence_sampler.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\transformer.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\translation.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\utils.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   creating build\lib.win-amd64-cpython-37\gluonnlp\optimizer
#   copying src\gluonnlp\optimizer\bert_adam.py -> build\lib.win-amd64-cpython-37\gluonnlp\optimizer
#   copying src\gluonnlp\optimizer\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\optimizer
#   creating build\lib.win-amd64-cpython-37\gluonnlp\utils
#   copying src\gluonnlp\utils\files.py -> build\lib.win-amd64-cpython-37\gluonnlp\utils
#   copying src\gluonnlp\utils\parallel.py -> build\lib.win-amd64-cpython-37\gluonnlp\utils
#   copying src\gluonnlp\utils\parameter.py -> build\lib.win-amd64-cpython-37\gluonnlp\utils
#   copying src\gluonnlp\utils\seed.py -> build\lib.win-amd64-cpython-37\gluonnlp\utils
#   copying src\gluonnlp\utils\version.py -> build\lib.win-amd64-cpython-37\gluonnlp\utils
#   copying src\gluonnlp\utils\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\utils
#   creating build\lib.win-amd64-cpython-37\gluonnlp\vocab
#   copying src\gluonnlp\vocab\bert.py -> build\lib.win-amd64-cpython-37\gluonnlp\vocab
#   copying src\gluonnlp\vocab\elmo.py -> build\lib.win-amd64-cpython-37\gluonnlp\vocab
#   copying src\gluonnlp\vocab\subwords.py -> build\lib.win-amd64-cpython-37\gluonnlp\vocab
#   copying src\gluonnlp\vocab\vocab.py -> build\lib.win-amd64-cpython-37\gluonnlp\vocab
#   copying src\gluonnlp\vocab\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\vocab
#   creating build\lib.win-amd64-cpython-37\gluonnlp\data\batchify
#   copying src\gluonnlp\data\batchify\batchify.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\batchify
#   copying src\gluonnlp\data\batchify\embedding.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\batchify
#   copying src\gluonnlp\data\batchify\language_model.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\batchify
#   copying src\gluonnlp\data\batchify\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\batchify
#   creating build\lib.win-amd64-cpython-37\gluonnlp\data\bert
#   copying src\gluonnlp\data\bert\glue.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\bert
#   copying src\gluonnlp\data\bert\squad.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\bert
#   copying src\gluonnlp\data\bert\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\bert
#   creating build\lib.win-amd64-cpython-37\gluonnlp\data\corpora
#   copying src\gluonnlp\data\corpora\google_billion_word.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\corpora
#   copying src\gluonnlp\data\corpora\large_text_compression_benchmark.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\corpora
#   copying src\gluonnlp\data\corpora\wikitext.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\corpora
#   copying src\gluonnlp\data\corpora\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\corpora
#   creating build\lib.win-amd64-cpython-37\gluonnlp\data\xlnet
#   copying src\gluonnlp\data\xlnet\squad.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\xlnet
#   copying src\gluonnlp\data\xlnet\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\xlnet
#   creating build\lib.win-amd64-cpython-37\gluonnlp\model\train
#   copying src\gluonnlp\model\train\cache.py -> build\lib.win-amd64-cpython-37\gluonnlp\model\train
#   copying src\gluonnlp\model\train\embedding.py -> build\lib.win-amd64-cpython-37\gluonnlp\model\train
#   copying src\gluonnlp\model\train\language_model.py -> build\lib.win-amd64-cpython-37\gluonnlp\model\train
#   copying src\gluonnlp\model\train\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\model\train
#   running egg_info
#   writing src\gluonnlp.egg-info\PKG-INFO
#   writing dependency_links to src\gluonnlp.egg-info\dependency_links.txt
#   writing requirements to src\gluonnlp.egg-info\requires.txt
#   writing top-level names to src\gluonnlp.egg-info\top_level.txt
#   reading manifest file 'src\gluonnlp.egg-info\SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no files found matching '*.py' under directory 'gluonnlp'
#   warning: no previously-included files matching '*' found under directory 'tests'
#   warning: no previously-included files matching '*' found under directory 'scripts'
#   adding license file 'LICENSE'
#   writing manifest file 'src\gluonnlp.egg-info\SOURCES.txt'
#   copying src\gluonnlp\data\fast_bert_tokenizer.c -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\fast_bert_tokenizer.pyx -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   running build_ext
#   Using cached gluonnlp-0.10.0.tar.gz (344 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pandas in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (1.3.5)
# Requirement already satisfied: tqdm in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (4.64.1)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from gluonnlp) (1.16.6)
# Requirement already satisfied: cython in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from gluonnlp) (0.29.32)
# Requirement already satisfied: packaging in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from gluonnlp) (21.3)
# Collecting numpy>=1.16.0
#   Using cached numpy-1.21.6-cp37-cp37m-win_amd64.whl (14.0 MB)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from pandas) (2022.2.1)
# Requirement already satisfied: colorama in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from tqdm) (0.4.5)
# Requirement already satisfied: six>=1.5 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from packaging->gluonnlp) (3.0.9)
# Building wheels for collected packages: gluonnlp
#   Building wheel for gluonnlp (setup.py): started
#   Building wheel for gluonnlp (setup.py): finished with status 'error'
#   Running setup.py clean for gluonnlp
# Failed to build gluonnlp
# Installing collected packages: numpy, gluonnlp
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.16.6
#     Uninstalling numpy-1.16.6:
#       Successfully uninstalled numpy-1.16.6
#   Running setup.py install for gluonnlp: started
#   Running setup.py install for gluonnlp: finished with status 'error'
#   skipping 'src/gluonnlp/data\fast_bert_tokenizer.c' Cython extension (up-to-date)
#   building 'gluonnlp.data.fast_bert_tokenizer' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for gluonnlp
#   error: subprocess-exited-with-error
#
#   Running setup.py install for gluonnlp did not run successfully.
#   exit code: 1
#
#   [126 lines of output]
#   running install
#   C:\Users\seoye\anaconda3\envs\python3.7\lib\site-packages\setuptools\command\install.py:37: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#     setuptools.SetuptoolsDeprecationWarning,
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-37
#   creating build\lib.win-amd64-cpython-37\gluonnlp
#   copying src\gluonnlp\base.py -> build\lib.win-amd64-cpython-37\gluonnlp
#   copying src\gluonnlp\_constants.py -> build\lib.win-amd64-cpython-37\gluonnlp
#   copying src\gluonnlp\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp
#   creating build\lib.win-amd64-cpython-37\gluonnlp\calibration
#   copying src\gluonnlp\calibration\collector.py -> build\lib.win-amd64-cpython-37\gluonnlp\calibration
#   copying src\gluonnlp\calibration\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\calibration
#   creating build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\baidu_ernie_data.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\candidate_sampler.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\classification.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\conll.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\dataloader.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\dataset.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\datasetloader.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\glue.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\intent_slot.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\question_answering.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\registry.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\sampler.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\sentiment.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\stream.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\super_glue.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\transforms.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\translation.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\utils.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\word_embedding_evaluation.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   creating build\lib.win-amd64-cpython-37\gluonnlp\embedding
#   copying src\gluonnlp\embedding\evaluation.py -> build\lib.win-amd64-cpython-37\gluonnlp\embedding
#   copying src\gluonnlp\embedding\token_embedding.py -> build\lib.win-amd64-cpython-37\gluonnlp\embedding
#   copying src\gluonnlp\embedding\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\embedding
#   creating build\lib.win-amd64-cpython-37\gluonnlp\initializer
#   copying src\gluonnlp\initializer\initializer.py -> build\lib.win-amd64-cpython-37\gluonnlp\initializer
#   copying src\gluonnlp\initializer\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\initializer
#   creating build\lib.win-amd64-cpython-37\gluonnlp\loss
#   copying src\gluonnlp\loss\activation_regularizer.py -> build\lib.win-amd64-cpython-37\gluonnlp\loss
#   copying src\gluonnlp\loss\label_smoothing.py -> build\lib.win-amd64-cpython-37\gluonnlp\loss
#   copying src\gluonnlp\loss\loss.py -> build\lib.win-amd64-cpython-37\gluonnlp\loss
#   copying src\gluonnlp\loss\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\loss
#   creating build\lib.win-amd64-cpython-37\gluonnlp\metric
#   copying src\gluonnlp\metric\length_normalized_loss.py -> build\lib.win-amd64-cpython-37\gluonnlp\metric
#   copying src\gluonnlp\metric\masked_accuracy.py -> build\lib.win-amd64-cpython-37\gluonnlp\metric
#   copying src\gluonnlp\metric\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\metric
#   creating build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\attention_cell.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\bert.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\bilm_encoder.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\block.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\convolutional_encoder.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\elmo.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\highway.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\info.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\language_model.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\lstmpcellwithclip.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\parameter.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\sampled_block.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\seq2seq_encoder_decoder.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\sequence_sampler.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\transformer.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\translation.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\utils.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   copying src\gluonnlp\model\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\model
#   creating build\lib.win-amd64-cpython-37\gluonnlp\optimizer
#   copying src\gluonnlp\optimizer\bert_adam.py -> build\lib.win-amd64-cpython-37\gluonnlp\optimizer
#   copying src\gluonnlp\optimizer\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\optimizer
#   creating build\lib.win-amd64-cpython-37\gluonnlp\utils
#   copying src\gluonnlp\utils\files.py -> build\lib.win-amd64-cpython-37\gluonnlp\utils
#   copying src\gluonnlp\utils\parallel.py -> build\lib.win-amd64-cpython-37\gluonnlp\utils
#   copying src\gluonnlp\utils\parameter.py -> build\lib.win-amd64-cpython-37\gluonnlp\utils
#   copying src\gluonnlp\utils\seed.py -> build\lib.win-amd64-cpython-37\gluonnlp\utils
#   copying src\gluonnlp\utils\version.py -> build\lib.win-amd64-cpython-37\gluonnlp\utils
#   copying src\gluonnlp\utils\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\utils
#   creating build\lib.win-amd64-cpython-37\gluonnlp\vocab
#   copying src\gluonnlp\vocab\bert.py -> build\lib.win-amd64-cpython-37\gluonnlp\vocab
#   copying src\gluonnlp\vocab\elmo.py -> build\lib.win-amd64-cpython-37\gluonnlp\vocab
#   copying src\gluonnlp\vocab\subwords.py -> build\lib.win-amd64-cpython-37\gluonnlp\vocab
#   copying src\gluonnlp\vocab\vocab.py -> build\lib.win-amd64-cpython-37\gluonnlp\vocab
#   copying src\gluonnlp\vocab\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\vocab
#   creating build\lib.win-amd64-cpython-37\gluonnlp\data\batchify
#   copying src\gluonnlp\data\batchify\batchify.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\batchify
#   copying src\gluonnlp\data\batchify\embedding.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\batchify
#   copying src\gluonnlp\data\batchify\language_model.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\batchify
#   copying src\gluonnlp\data\batchify\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\batchify
#   creating build\lib.win-amd64-cpython-37\gluonnlp\data\bert
#   copying src\gluonnlp\data\bert\glue.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\bert
#   copying src\gluonnlp\data\bert\squad.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\bert
#   copying src\gluonnlp\data\bert\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\bert
#   creating build\lib.win-amd64-cpython-37\gluonnlp\data\corpora
#   copying src\gluonnlp\data\corpora\google_billion_word.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\corpora
#   copying src\gluonnlp\data\corpora\large_text_compression_benchmark.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\corpora
#   copying src\gluonnlp\data\corpora\wikitext.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\corpora
#   copying src\gluonnlp\data\corpora\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\corpora
#   creating build\lib.win-amd64-cpython-37\gluonnlp\data\xlnet
#   copying src\gluonnlp\data\xlnet\squad.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\xlnet
#   copying src\gluonnlp\data\xlnet\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\data\xlnet
#   creating build\lib.win-amd64-cpython-37\gluonnlp\model\train
#   copying src\gluonnlp\model\train\cache.py -> build\lib.win-amd64-cpython-37\gluonnlp\model\train
#   copying src\gluonnlp\model\train\embedding.py -> build\lib.win-amd64-cpython-37\gluonnlp\model\train
#   copying src\gluonnlp\model\train\language_model.py -> build\lib.win-amd64-cpython-37\gluonnlp\model\train
#   copying src\gluonnlp\model\train\__init__.py -> build\lib.win-amd64-cpython-37\gluonnlp\model\train
#   running egg_info
#   writing src\gluonnlp.egg-info\PKG-INFO
#   writing dependency_links to src\gluonnlp.egg-info\dependency_links.txt
#   writing requirements to src\gluonnlp.egg-info\requires.txt
#   writing top-level names to src\gluonnlp.egg-info\top_level.txt
#   reading manifest file 'src\gluonnlp.egg-info\SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no files found matching '*.py' under directory 'gluonnlp'
#   warning: no previously-included files matching '*' found under directory 'tests'
#   warning: no previously-included files matching '*' found under directory 'scripts'
#   adding license file 'LICENSE'
#   writing manifest file 'src\gluonnlp.egg-info\SOURCES.txt'
#   copying src\gluonnlp\data\fast_bert_tokenizer.c -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   copying src\gluonnlp\data\fast_bert_tokenizer.pyx -> build\lib.win-amd64-cpython-37\gluonnlp\data
#   running build_ext
#   skipping 'src/gluonnlp/data\fast_bert_tokenizer.c' Cython extension (up-to-date)
#   building 'gluonnlp.data.fast_bert_tokenizer' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# Encountered error while trying to install package.
#
# gluonnlp
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.

# %%
# !pip install sentencepiece
# Out:
# Requirement already satisfied: sentencepiece in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (0.1.97)

# %%
# !pip install transformers==3.0.2
# Out:
# Requirement already satisfied: transformers==3.0.2 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (3.0.2)
# Requirement already satisfied: tokenizers==0.8.1.rc1 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from transformers==3.0.2) (0.8.1rc1)
# Requirement already satisfied: filelock in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from transformers==3.0.2) (3.8.0)
# Requirement already satisfied: sacremoses in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from transformers==3.0.2) (0.0.53)
# Requirement already satisfied: numpy in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from transformers==3.0.2) (1.21.6)
# Requirement already satisfied: requests in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from transformers==3.0.2) (2.18.4)
# Requirement already satisfied: sentencepiece!=0.1.92 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from transformers==3.0.2) (0.1.97)
# Requirement already satisfied: tqdm>=4.27 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from transformers==3.0.2) (4.64.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from transformers==3.0.2) (2022.9.11)
# Requirement already satisfied: packaging in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from transformers==3.0.2) (21.3)
# Requirement already satisfied: colorama in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from tqdm>=4.27->transformers==3.0.2) (0.4.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from packaging->transformers==3.0.2) (3.0.9)
# Requirement already satisfied: idna<2.7,>=2.5 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from requests->transformers==3.0.2) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from requests->transformers==3.0.2) (2022.6.15)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from requests->transformers==3.0.2) (3.0.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from requests->transformers==3.0.2) (1.22)
# Requirement already satisfied: click in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from sacremoses->transformers==3.0.2) (8.1.3)
# Requirement already satisfied: six in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from sacremoses->transformers==3.0.2) (1.16.0)
# Requirement already satisfied: joblib in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from sacremoses->transformers==3.0.2) (1.1.0)
# Requirement already satisfied: importlib-metadata in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from click->sacremoses->transformers==3.0.2) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from importlib-metadata->click->sacremoses->transformers==3.0.2) (3.8.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\seoye\anaconda3\envs\python3.7\lib\site-packages (from importlib-metadata->click->sacremoses->transformers==3.0.2) (4.3.0)

# %%
! pip install snscrape

# !pip install pandas numpy 

! pip install tensorflow
# Out:
# Collecting snscrape
#   Using cached snscrape-0.4.3.20220106-py3-none-any.whl (59 kB)
# Collecting requests[socks]
#   Using cached requests-2.28.1-py3-none-any.whl (62 kB)
# Collecting pytz
#   Using cached pytz-2022.2.1-py2.py3-none-any.whl (500 kB)
# Collecting filelock
#   Using cached filelock-3.8.0-py3-none-any.whl (10 kB)
# Collecting lxml
#   Downloading lxml-4.9.1-cp38-cp38-win_amd64.whl (3.6 MB)
#      ---------------------------------------- 3.6/3.6 MB 8.6 MB/s eta 0:00:00
# Collecting beautifulsoup4
#   Using cached beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
# Collecting soupsieve>1.2
#   Using cached soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Using cached urllib3-1.26.12-py2.py3-none-any.whl (140 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\seoye\anaconda3\envs\python3.8\lib\site-packages (from requests[socks]->snscrape) (2022.6.15)
# Collecting idna<4,>=2.5
#   Using cached idna-3.3-py3-none-any.whl (61 kB)
# Collecting charset-normalizer<3,>=2
#   Using cached charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Collecting PySocks!=1.5.7,>=1.5.6
#   Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Installing collected packages: pytz, urllib3, soupsieve, PySocks, lxml, idna, filelock, charset-normalizer, requests, beautifulsoup4, snscrape
# Successfully installed PySocks-1.7.1 beautifulsoup4-4.11.1 charset-normalizer-2.1.1 filelock-3.8.0 idna-3.3 lxml-4.9.1 pytz-2022.2.1 requests-2.28.1 snscrape-0.4.3.20220106 soupsieve-2.3.2.post1 urllib3-1.26.12
# Collecting pandas
#   Downloading pandas-1.4.4-cp38-cp38-win_amd64.whl (10.6 MB)
#      ---------------------------------------- 10.6/10.6 MB 8.0 MB/s eta 0:00:00
# Collecting numpy
#   Downloading numpy-1.23.3-cp38-cp38-win_amd64.whl (14.7 MB)
#      ---------------------------------------- 14.7/14.7 MB 8.2 MB/s eta 0:00:00
# Collecting python-dateutil>=2.8.1
#   Using cached python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\seoye\anaconda3\envs\python3.8\lib\site-packages (from pandas) (2022.2.1)
# Collecting six>=1.5
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: six, numpy, python-dateutil, pandas
# Successfully installed numpy-1.23.3 pandas-1.4.4 python-dateutil-2.8.2 six-1.16.0
# Collecting tensorflow
#   Downloading tensorflow-2.10.0-cp38-cp38-win_amd64.whl (455.9 MB)
#      -------------------------------------- 455.9/455.9 MB 3.8 MB/s eta 0:00:00
# Collecting packaging
#   Using cached packaging-21.3-py3-none-any.whl (40 kB)
# Collecting flatbuffers>=2.0
#   Using cached flatbuffers-2.0.7-py2.py3-none-any.whl (26 kB)
# Collecting keras<2.11,>=2.10.0
#   Using cached keras-2.10.0-py2.py3-none-any.whl (1.7 MB)
# Collecting gast<=0.4.0,>=0.2.1
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting tensorflow-estimator<2.11,>=2.10.0
#   Using cached tensorflow_estimator-2.10.0-py2.py3-none-any.whl (438 kB)
# Collecting tensorboard<2.11,>=2.10
#   Using cached tensorboard-2.10.0-py3-none-any.whl (5.9 MB)
# Collecting h5py>=2.9.0
#   Downloading h5py-3.7.0-cp38-cp38-win_amd64.whl (2.6 MB)
#      ---------------------------------------- 2.6/2.6 MB 7.0 MB/s eta 0:00:00
# Collecting absl-py>=1.0.0
#   Using cached absl_py-1.2.0-py3-none-any.whl (123 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.27.0-cp38-cp38-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 7.9 MB/s eta 0:00:00
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting keras-preprocessing>=1.1.1
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting protobuf<3.20,>=3.9.2
#   Downloading protobuf-3.19.4-cp38-cp38-win_amd64.whl (895 kB)
#      -------------------------------------- 895.9/895.9 kB 7.1 MB/s eta 0:00:00
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.48.1-cp38-cp38-win_amd64.whl (3.6 MB)
#      ---------------------------------------- 3.6/3.6 MB 6.4 MB/s eta 0:00:00
# Collecting libclang>=13.0.0
#   Using cached libclang-14.0.6-py2.py3-none-win_amd64.whl (14.2 MB)
# Collecting typing-extensions>=3.6.6
#   Using cached typing_extensions-4.3.0-py3-none-any.whl (25 kB)
# Collecting termcolor>=1.1.0
#   Using cached termcolor-2.0.0-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: six>=1.12.0 in c:\users\seoye\anaconda3\envs\python3.8\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: setuptools in c:\users\seoye\anaconda3\envs\python3.8\lib\site-packages (from tensorflow) (63.4.1)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting wrapt>=1.11.0
#   Downloading wrapt-1.14.1-cp38-cp38-win_amd64.whl (35 kB)
# Requirement already satisfied: numpy>=1.20 in c:\users\seoye\anaconda3\envs\python3.8\lib\site-packages (from tensorflow) (1.23.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\seoye\anaconda3\envs\python3.8\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Collecting google-auth<3,>=1.6.3
#   Using cached google_auth-2.11.0-py2.py3-none-any.whl (167 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Collecting werkzeug>=1.0.1
#   Using cached Werkzeug-2.2.2-py3-none-any.whl (232 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\seoye\anaconda3\envs\python3.8\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.28.1)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.4.1-py3-none-any.whl (93 kB)
# Collecting pyparsing!=3.0.5,>=2.0.2
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting importlib-metadata>=4.4
#   Using cached importlib_metadata-4.12.0-py3-none-any.whl (21 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\seoye\anaconda3\envs\python3.8\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\seoye\anaconda3\envs\python3.8\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\seoye\anaconda3\envs\python3.8\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\seoye\anaconda3\envs\python3.8\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.1.1)
# Collecting MarkupSafe>=2.1.1
#   Downloading MarkupSafe-2.1.1-cp38-cp38-win_amd64.whl (17 kB)
# Collecting zipp>=0.5
#   Using cached zipp-3.8.1-py3-none-any.whl (5.6 kB)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.1-py3-none-any.whl (151 kB)
# Installing collected packages: tensorboard-plugin-wit, pyasn1, libclang, keras, flatbuffers, zipp, wrapt, typing-extensions, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, rsa, pyparsing, pyasn1-modules, protobuf, opt-einsum, oauthlib, MarkupSafe, keras-preprocessing, h5py, grpcio, google-pasta, gast, cachetools, astunparse, absl-py, werkzeug, requests-oauthlib, packaging, importlib-metadata, google-auth, markdown, google-auth-oauthlib, tensorboard, tensorflow
# Successfully installed MarkupSafe-2.1.1 absl-py-1.2.0 astunparse-1.6.3 cachetools-5.2.0 flatbuffers-2.0.7 gast-0.4.0 google-auth-2.11.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.48.1 h5py-3.7.0 importlib-metadata-4.12.0 keras-2.10.0 keras-preprocessing-1.1.2 libclang-14.0.6 markdown-3.4.1 oauthlib-3.2.1 opt-einsum-3.3.0 packaging-21.3 protobuf-3.19.4 pyasn1-0.4.8 pyasn1-modules-0.2.8 pyparsing-3.0.9 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.10.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.10.0 tensorflow-estimator-2.10.0 tensorflow-io-gcs-filesystem-0.27.0 termcolor-2.0.0 typing-extensions-4.3.0 werkzeug-2.2.2 wrapt-1.14.1 zipp-3.8.1

# %%
# !pip install mxnet
# Out:
# Collecting mxnet
#   Using cached mxnet-1.7.0.post2-py2.py3-none-win_amd64.whl (33.1 MB)
# Collecting requests<2.19.0,>=2.18.4
#   Using cached requests-2.18.4-py2.py3-none-any.whl (88 kB)
# Collecting numpy<1.17.0,>=1.8.2
#   Using cached numpy-1.16.6.zip (5.1 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting graphviz<0.9.0,>=0.8.1
#   Using cached graphviz-0.8.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\seoye\anaconda3\envs\python3.8\lib\site-packages (from requests<2.19.0,>=2.18.4->mxnet) (2022.6.15)
# Collecting chardet<3.1.0,>=3.0.2
#   Using cached chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting idna<2.7,>=2.5
#   Using cached idna-2.6-py2.py3-none-any.whl (56 kB)
# Collecting urllib3<1.23,>=1.21.1
#   Using cached urllib3-1.22-py2.py3-none-any.whl (132 kB)
# Building wheels for collected packages: numpy
#   Building wheel for numpy (setup.py): started
#   Building wheel for numpy (setup.py): finished with status 'error'
#   Running setup.py clean for numpy
# Failed to build numpy
# Installing collected packages: urllib3, idna, chardet, requests, numpy, graphviz, mxnet
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.12
#     Uninstalling urllib3-1.26.12:
#       Successfully uninstalled urllib3-1.26.12
#   Attempting uninstall: idna
#     Found existing installation: idna 3.3
#     Uninstalling idna-3.3:
#       Successfully uninstalled idna-3.3
#   Attempting uninstall: requests
#     Found existing installation: requests 2.28.1
#     Uninstalling requests-2.28.1:
#       Successfully uninstalled requests-2.28.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.3
#     Uninstalling numpy-1.23.3:
#       Successfully uninstalled numpy-1.23.3
#   Running setup.py install for numpy: started
#   Running setup.py install for numpy: finished with status 'error'
#   Rolling back uninstall of numpy
#   Moving to c:\users\seoye\anaconda3\envs\python3.8\lib\site-packages\numpy-1.23.3.dist-info\
#    from C:\Users\seoye\anaconda3\envs\python3.8\Lib\site-packages\~umpy-1.23.3.dist-info
#   Moving to c:\users\seoye\anaconda3\envs\python3.8\lib\site-packages\numpy\
#    from C:\Users\seoye\anaconda3\envs\python3.8\Lib\site-packages\~umpy
#   Moving to c:\users\seoye\anaconda3\envs\python3.8\scripts\f2py.exe
#    from C:\Users\seoye\AppData\Local\Temp\pip-uninstall-mttx7f7e\f2py.exe
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [288 lines of output]
#   Running from numpy source directory.
#   C:\Users\seoye\AppData\Local\Temp\pip-install-w4_2kues\numpy_b07b18ecc41c45c19094999bc2bf1a75\numpy\distutils\misc_util.py:476: SyntaxWarning: "is" with a literal. Did you mean "=="?
#     return is_string(s) and ('*' in s or '?' is s)
#   blas_opt_info:
#   blas_mkl_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries mkl_rt not found in ['C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\libs', 'C:\\Users\\seoye\\anaconda3\\Library\\lib']
#     NOT AVAILABLE
#
#   blis_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries blis not found in ['C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\libs', 'C:\\Users\\seoye\\anaconda3\\Library\\lib']
#     NOT AVAILABLE
#
#   openblas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries openblas not found in ['C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\libs', 'C:\\Users\\seoye\\anaconda3\\Library\\lib']
#   get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#   customize GnuFCompiler
#   Could not locate executable g77
#   Could not locate executable f77
#   customize IntelVisualFCompiler
#   Could not locate executable ifort
#   Could not locate executable ifl
#   customize AbsoftFCompiler
#   Could not locate executable f90
#   customize CompaqVisualFCompiler
#   Could not locate executable DF
#   customize IntelItaniumVisualFCompiler
#   Could not locate executable efl
#   customize Gnu95FCompiler
#   Could not locate executable gfortran
#   Could not locate executable f95
#   customize G95FCompiler
#   Could not locate executable g95
#   customize IntelEM64VisualFCompiler
#   customize IntelEM64TFCompiler
#   Could not locate executable efort
#   Could not locate executable efc
#   customize PGroupFlangCompiler
#   Could not locate executable flang
#   don't know how to compile Fortran code on platform 'nt'
#     NOT AVAILABLE
#
#   atlas_3_10_blas_threads_info:
#   Setting PTATLAS=ATLAS
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries tatlas not found in ['C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\libs', 'C:\\Users\\seoye\\anaconda3\\Library\\lib']
#     NOT AVAILABLE
#
#   atlas_3_10_blas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries satlas not found in ['C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\libs', 'C:\\Users\\seoye\\anaconda3\\Library\\lib']
#     NOT AVAILABLE
#
#   atlas_blas_threads_info:
#   Setting PTATLAS=ATLAS
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in ['C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\libs', 'C:\\Users\\seoye\\anaconda3\\Library\\lib']
#     NOT AVAILABLE
#
#   atlas_blas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries f77blas,cblas,atlas not found in ['C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\libs', 'C:\\Users\\seoye\\anaconda3\\Library\\lib']
#     NOT AVAILABLE
#
#   accelerate_info:
#     NOT AVAILABLE
#
#   C:\Users\seoye\AppData\Local\Temp\pip-install-w4_2kues\numpy_b07b18ecc41c45c19094999bc2bf1a75\numpy\distutils\system_info.py:639: UserWarning:
#       Atlas (http://math-atlas.sourceforge.net/) libraries not found.
#       Directories to search for the libraries can be specified in the
#       numpy/distutils/site.cfg file (section [atlas]) or by setting
#       the ATLAS environment variable.
#     self.calc_info()
#   blas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries blas not found in ['C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\libs', 'C:\\Users\\seoye\\anaconda3\\Library\\lib']
#     NOT AVAILABLE
#
#   C:\Users\seoye\AppData\Local\Temp\pip-install-w4_2kues\numpy_b07b18ecc41c45c19094999bc2bf1a75\numpy\distutils\system_info.py:639: UserWarning:
#       Blas (http://www.netlib.org/blas/) libraries not found.
#       Directories to search for the libraries can be specified in the
#       numpy/distutils/site.cfg file (section [blas]) or by setting
#       the BLAS environment variable.
#     self.calc_info()
#   blas_src_info:
#     NOT AVAILABLE
#
#   C:\Users\seoye\AppData\Local\Temp\pip-install-w4_2kues\numpy_b07b18ecc41c45c19094999bc2bf1a75\numpy\distutils\system_info.py:639: UserWarning:
#       Blas (http://www.netlib.org/blas/) sources not found.
#       Directories to search for the sources can be specified in the
#       numpy/distutils/site.cfg file (section [blas_src]) or by setting
#       the BLAS_SRC environment variable.
#     self.calc_info()
#     NOT AVAILABLE
#
#   'svnversion'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
#   배치 파일이 아닙니다.
#   non-existing path in 'numpy\\distutils': 'site.cfg'
#   lapack_opt_info:
#   lapack_mkl_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries mkl_rt not found in ['C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\libs', 'C:\\Users\\seoye\\anaconda3\\Library\\lib']
#     NOT AVAILABLE
#
#   openblas_lapack_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries openblas not found in ['C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\libs', 'C:\\Users\\seoye\\anaconda3\\Library\\lib']
#     NOT AVAILABLE
#
#   openblas_clapack_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries openblas,lapack not found in ['C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\libs', 'C:\\Users\\seoye\\anaconda3\\Library\\lib']
#     NOT AVAILABLE
#
#   atlas_3_10_threads_info:
#   Setting PTATLAS=ATLAS
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\seoye\anaconda3\envs\python3.8\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries tatlas,tatlas not found in C:\Users\seoye\anaconda3\envs\python3.8\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries tatlas,tatlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\seoye\anaconda3\envs\python3.8\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries tatlas,tatlas not found in C:\Users\seoye\anaconda3\envs\python3.8\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\seoye\anaconda3\Library\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries tatlas,tatlas not found in C:\Users\seoye\anaconda3\Library\lib
#   <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#     NOT AVAILABLE
#
#   atlas_3_10_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\seoye\anaconda3\envs\python3.8\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries satlas,satlas not found in C:\Users\seoye\anaconda3\envs\python3.8\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries satlas,satlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\seoye\anaconda3\envs\python3.8\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries satlas,satlas not found in C:\Users\seoye\anaconda3\envs\python3.8\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\seoye\anaconda3\Library\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries satlas,satlas not found in C:\Users\seoye\anaconda3\Library\lib
#   <class 'numpy.distutils.system_info.atlas_3_10_info'>
#     NOT AVAILABLE
#
#   atlas_threads_info:
#   Setting PTATLAS=ATLAS
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\seoye\anaconda3\envs\python3.8\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in C:\Users\seoye\anaconda3\envs\python3.8\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\seoye\anaconda3\envs\python3.8\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in C:\Users\seoye\anaconda3\envs\python3.8\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\seoye\anaconda3\Library\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in C:\Users\seoye\anaconda3\Library\lib
#   <class 'numpy.distutils.system_info.atlas_threads_info'>
#     NOT AVAILABLE
#
#   atlas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\seoye\anaconda3\envs\python3.8\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries f77blas,cblas,atlas not found in C:\Users\seoye\anaconda3\envs\python3.8\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries f77blas,cblas,atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\seoye\anaconda3\envs\python3.8\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries f77blas,cblas,atlas not found in C:\Users\seoye\anaconda3\envs\python3.8\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\seoye\anaconda3\Library\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries f77blas,cblas,atlas not found in C:\Users\seoye\anaconda3\Library\lib
#   <class 'numpy.distutils.system_info.atlas_info'>
#     NOT AVAILABLE
#
#   lapack_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack not found in ['C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\libs', 'C:\\Users\\seoye\\anaconda3\\Library\\lib']
#     NOT AVAILABLE
#
#   C:\Users\seoye\AppData\Local\Temp\pip-install-w4_2kues\numpy_b07b18ecc41c45c19094999bc2bf1a75\numpy\distutils\system_info.py:639: UserWarning:
#       Lapack (http://www.netlib.org/lapack/) libraries not found.
#       Directories to search for the libraries can be specified in the
#       numpy/distutils/site.cfg file (section [lapack]) or by setting
#       the LAPACK environment variable.
#     self.calc_info()
#   lapack_src_info:
#     NOT AVAILABLE
#
#   C:\Users\seoye\AppData\Local\Temp\pip-install-w4_2kues\numpy_b07b18ecc41c45c19094999bc2bf1a75\numpy\distutils\system_info.py:639: UserWarning:
#       Lapack (http://www.netlib.org/lapack/) sources not found.
#       Directories to search for the sources can be specified in the
#       numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#       the LAPACK_SRC environment variable.
#     self.calc_info()
#     NOT AVAILABLE
#
#   C:\Users\seoye\anaconda3\envs\python3.8\lib\site-packages\setuptools\_distutils\dist.py:262: UserWarning: Unknown distribution option: 'define_macros'
#     warnings.warn(msg)
#   running bdist_wheel
#   running build
#   running config_cc
#   unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#   running config_fc
#   unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#   running build_src
#   build_src
#   building py_modules sources
#   creating build
#   creating build\src.win-amd64-3.8
#   creating build\src.win-amd64-3.8\numpy
#   creating build\src.win-amd64-3.8\numpy\distutils
#   building library "npymath" sources
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for numpy
#   error: subprocess-exited-with-error
#
#   python setup.py clean did not run successfully.
#   exit code: 1
#
#   [10 lines of output]
#   Running from numpy source directory.
#
#   `setup.py clean` is not supported, use one of the following instead:
#
#     - `git clean -xdf` (cleans all files)
#     - `git clean -Xdf` (cleans all versioned files, doesn't touch
#                         files that aren't checked into the git repo)
#
#   Add `--force` to your command to use it anyway if you must (unsupported).
#
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed cleaning build dir for numpy
#   error: subprocess-exited-with-error
#
#   Running setup.py install for numpy did not run successfully.
#   exit code: 1
#
#   [293 lines of output]
#   Running from numpy source directory.
#
#   Note: if you need reliable uninstall behavior, then install
#   with pip instead of using `setup.py install`:
#
#     - `pip install .`       (from a git repo or downloaded source
#                              release)
#     - `pip install numpy`   (last NumPy release on PyPi)
#
#
#   blas_opt_info:
#   blas_mkl_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries mkl_rt not found in ['C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\libs', 'C:\\Users\\seoye\\anaconda3\\Library\\lib']
#     NOT AVAILABLE
#
#   blis_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries blis not found in ['C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\libs', 'C:\\Users\\seoye\\anaconda3\\Library\\lib']
#     NOT AVAILABLE
#
#   openblas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries openblas not found in ['C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\libs', 'C:\\Users\\seoye\\anaconda3\\Library\\lib']
#   get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#   customize GnuFCompiler
#   Could not locate executable g77
#   Could not locate executable f77
#   customize IntelVisualFCompiler
#   Could not locate executable ifort
#   Could not locate executable ifl
#   customize AbsoftFCompiler
#   Could not locate executable f90
#   customize CompaqVisualFCompiler
#   Could not locate executable DF
#   customize IntelItaniumVisualFCompiler
#   Could not locate executable efl
#   customize Gnu95FCompiler
#   Could not locate executable gfortran
#   Could not locate executable f95
#   customize G95FCompiler
#   Could not locate executable g95
#   customize IntelEM64VisualFCompiler
#   customize IntelEM64TFCompiler
#   Could not locate executable efort
#   Could not locate executable efc
#   customize PGroupFlangCompiler
#   Could not locate executable flang
#   don't know how to compile Fortran code on platform 'nt'
#     NOT AVAILABLE
#
#   atlas_3_10_blas_threads_info:
#   Setting PTATLAS=ATLAS
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries tatlas not found in ['C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\libs', 'C:\\Users\\seoye\\anaconda3\\Library\\lib']
#     NOT AVAILABLE
#
#   atlas_3_10_blas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries satlas not found in ['C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\libs', 'C:\\Users\\seoye\\anaconda3\\Library\\lib']
#     NOT AVAILABLE
#
#   atlas_blas_threads_info:
#   Setting PTATLAS=ATLAS
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in ['C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\libs', 'C:\\Users\\seoye\\anaconda3\\Library\\lib']
#     NOT AVAILABLE
#
#   atlas_blas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries f77blas,cblas,atlas not found in ['C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\libs', 'C:\\Users\\seoye\\anaconda3\\Library\\lib']
#     NOT AVAILABLE
#
#   accelerate_info:
#     NOT AVAILABLE
#
#   C:\Users\seoye\AppData\Local\Temp\pip-install-w4_2kues\numpy_b07b18ecc41c45c19094999bc2bf1a75\numpy\distutils\system_info.py:639: UserWarning:
#       Atlas (http://math-atlas.sourceforge.net/) libraries not found.
#       Directories to search for the libraries can be specified in the
#       numpy/distutils/site.cfg file (section [atlas]) or by setting
#       the ATLAS environment variable.
#     self.calc_info()
#   blas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries blas not found in ['C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\libs', 'C:\\Users\\seoye\\anaconda3\\Library\\lib']
#     NOT AVAILABLE
#
#   C:\Users\seoye\AppData\Local\Temp\pip-install-w4_2kues\numpy_b07b18ecc41c45c19094999bc2bf1a75\numpy\distutils\system_info.py:639: UserWarning:
#       Blas (http://www.netlib.org/blas/) libraries not found.
#       Directories to search for the libraries can be specified in the
#       numpy/distutils/site.cfg file (section [blas]) or by setting
#       the BLAS environment variable.
#     self.calc_info()
#   blas_src_info:
#     NOT AVAILABLE
#
#   C:\Users\seoye\AppData\Local\Temp\pip-install-w4_2kues\numpy_b07b18ecc41c45c19094999bc2bf1a75\numpy\distutils\system_info.py:639: UserWarning:
#       Blas (http://www.netlib.org/blas/) sources not found.
#       Directories to search for the sources can be specified in the
#       numpy/distutils/site.cfg file (section [blas_src]) or by setting
#       the BLAS_SRC environment variable.
#     self.calc_info()
#     NOT AVAILABLE
#
#   'svnversion'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
#   배치 파일이 아닙니다.
#   non-existing path in 'numpy\\distutils': 'site.cfg'
#   lapack_opt_info:
#   lapack_mkl_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries mkl_rt not found in ['C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\libs', 'C:\\Users\\seoye\\anaconda3\\Library\\lib']
#     NOT AVAILABLE
#
#   openblas_lapack_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries openblas not found in ['C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\libs', 'C:\\Users\\seoye\\anaconda3\\Library\\lib']
#     NOT AVAILABLE
#
#   openblas_clapack_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries openblas,lapack not found in ['C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\libs', 'C:\\Users\\seoye\\anaconda3\\Library\\lib']
#     NOT AVAILABLE
#
#   atlas_3_10_threads_info:
#   Setting PTATLAS=ATLAS
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\seoye\anaconda3\envs\python3.8\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries tatlas,tatlas not found in C:\Users\seoye\anaconda3\envs\python3.8\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries tatlas,tatlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\seoye\anaconda3\envs\python3.8\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries tatlas,tatlas not found in C:\Users\seoye\anaconda3\envs\python3.8\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\seoye\anaconda3\Library\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries tatlas,tatlas not found in C:\Users\seoye\anaconda3\Library\lib
#   <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#     NOT AVAILABLE
#
#   atlas_3_10_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\seoye\anaconda3\envs\python3.8\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries satlas,satlas not found in C:\Users\seoye\anaconda3\envs\python3.8\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries satlas,satlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\seoye\anaconda3\envs\python3.8\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries satlas,satlas not found in C:\Users\seoye\anaconda3\envs\python3.8\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\seoye\anaconda3\Library\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries satlas,satlas not found in C:\Users\seoye\anaconda3\Library\lib
#   <class 'numpy.distutils.system_info.atlas_3_10_info'>
#     NOT AVAILABLE
#
#   atlas_threads_info:
#   Setting PTATLAS=ATLAS
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\seoye\anaconda3\envs\python3.8\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in C:\Users\seoye\anaconda3\envs\python3.8\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\seoye\anaconda3\envs\python3.8\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in C:\Users\seoye\anaconda3\envs\python3.8\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\seoye\anaconda3\Library\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in C:\Users\seoye\anaconda3\Library\lib
#   <class 'numpy.distutils.system_info.atlas_threads_info'>
#     NOT AVAILABLE
#
#   atlas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\seoye\anaconda3\envs\python3.8\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries f77blas,cblas,atlas not found in C:\Users\seoye\anaconda3\envs\python3.8\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries f77blas,cblas,atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\seoye\anaconda3\envs\python3.8\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries f77blas,cblas,atlas not found in C:\Users\seoye\anaconda3\envs\python3.8\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\seoye\anaconda3\Library\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries f77blas,cblas,atlas not found in C:\Users\seoye\anaconda3\Library\lib
#   <class 'numpy.distutils.system_info.atlas_info'>
#     NOT AVAILABLE
#
#   lapack_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack not found in ['C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\lib', 'C:\\', 'C:\\Users\\seoye\\anaconda3\\envs\\python3.8\\libs', 'C:\\Users\\seoye\\anaconda3\\Library\\lib']
#     NOT AVAILABLE
#
#   C:\Users\seoye\AppData\Local\Temp\pip-install-w4_2kues\numpy_b07b18ecc41c45c19094999bc2bf1a75\numpy\distutils\system_info.py:639: UserWarning:
#       Lapack (http://www.netlib.org/lapack/) libraries not found.
#       Directories to search for the libraries can be specified in the
#       numpy/distutils/site.cfg file (section [lapack]) or by setting
#       the LAPACK environment variable.
#     self.calc_info()
#   lapack_src_info:
#     NOT AVAILABLE
#
#   C:\Users\seoye\AppData\Local\Temp\pip-install-w4_2kues\numpy_b07b18ecc41c45c19094999bc2bf1a75\numpy\distutils\system_info.py:639: UserWarning:
#       Lapack (http://www.netlib.org/lapack/) sources not found.
#       Directories to search for the sources can be specified in the
#       numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#       the LAPACK_SRC environment variable.
#     self.calc_info()
#     NOT AVAILABLE
#
#   C:\Users\seoye\anaconda3\envs\python3.8\lib\site-packages\setuptools\_distutils\dist.py:262: UserWarning: Unknown distribution option: 'define_macros'
#     warnings.warn(msg)
#   running install
#   C:\Users\seoye\anaconda3\envs\python3.8\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#     warnings.warn(
#   running build
#   running config_cc
#   unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#   running config_fc
#   unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#   running build_src
#   build_src
#   building py_modules sources
#   building library "npymath" sources
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   WARNING: No metadata found in c:\users\seoye\anaconda3\envs\python3.8\lib\site-packages
# error: legacy-install-failure
#
# Encountered error while trying to install package.
#
# numpy
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.

# %%
# !pip install gluonnlp pandas tqdm
# !pip install sentencepiece
# !pip install transformers==3.0.2
# !pip install torch
# Out:
# Collecting gluonnlp
#   Using cached gluonnlp-0.10.0.tar.gz (344 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pandas in c:\users\seoye\anaconda3\envs\python3.8\lib\site-packages (1.4.4)
# Collecting tqdm
#   Using cached tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\seoye\anaconda3\envs\python3.8\lib\site-packages (from gluonnlp) (1.23.3)
# Collecting cython
#   Using cached Cython-0.29.32-py2.py3-none-any.whl (986 kB)
# Requirement already satisfied: packaging in c:\users\seoye\anaconda3\envs\python3.8\lib\site-packages (from gluonnlp) (21.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\seoye\anaconda3\envs\python3.8\lib\site-packages (from pandas) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\seoye\anaconda3\envs\python3.8\lib\site-packages (from pandas) (2.8.2)
# Collecting colorama
#   Using cached colorama-0.4.5-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: six>=1.5 in c:\users\seoye\anaconda3\envs\python3.8\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\seoye\anaconda3\envs\python3.8\lib\site-packages (from packaging->gluonnlp) (3.0.9)
# Building wheels for collected packages: gluonnlp
#   Building wheel for gluonnlp (setup.py): started
#   Building wheel for gluonnlp (setup.py): finished with status 'error'
#   Running setup.py clean for gluonnlp
# Failed to build gluonnlp
# Installing collected packages: cython, colorama, tqdm, gluonnlp
#   Running setup.py install for gluonnlp: started
#   Running setup.py install for gluonnlp: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [126 lines of output]
#   C:\Users\seoye\anaconda3\envs\python3.8\lib\site-packages\setuptools\installer.py:27: SetuptoolsDeprecationWarning: setuptools.installer is deprecated. Requirements should be satisfied by a PEP 517 installer.
#     warnings.warn(
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-38
#   creating build\lib.win-amd64-cpython-38\gluonnlp
#   copying src\gluonnlp\base.py -> build\lib.win-amd64-cpython-38\gluonnlp
#   copying src\gluonnlp\_constants.py -> build\lib.win-amd64-cpython-38\gluonnlp
#   copying src\gluonnlp\__init__.py -> build\lib.win-amd64-cpython-38\gluonnlp
#   creating build\lib.win-amd64-cpython-38\gluonnlp\calibration
#   copying src\gluonnlp\calibration\collector.py -> build\lib.win-amd64-cpython-38\gluonnlp\calibration
#   copying src\gluonnlp\calibration\__init__.py -> build\lib.win-amd64-cpython-38\gluonnlp\calibration
#   creating build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\baidu_ernie_data.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\candidate_sampler.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\classification.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\conll.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\dataloader.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\dataset.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\datasetloader.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\glue.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\intent_slot.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\question_answering.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\registry.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\sampler.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\sentiment.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\stream.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\super_glue.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\transforms.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\translation.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\utils.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\word_embedding_evaluation.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\__init__.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   creating build\lib.win-amd64-cpython-38\gluonnlp\embedding
#   copying src\gluonnlp\embedding\evaluation.py -> build\lib.win-amd64-cpython-38\gluonnlp\embedding
#   copying src\gluonnlp\embedding\token_embedding.py -> build\lib.win-amd64-cpython-38\gluonnlp\embedding
#   copying src\gluonnlp\embedding\__init__.py -> build\lib.win-amd64-cpython-38\gluonnlp\embedding
#   creating build\lib.win-amd64-cpython-38\gluonnlp\initializer
#   copying src\gluonnlp\initializer\initializer.py -> build\lib.win-amd64-cpython-38\gluonnlp\initializer
#   copying src\gluonnlp\initializer\__init__.py -> build\lib.win-amd64-cpython-38\gluonnlp\initializer
#   creating build\lib.win-amd64-cpython-38\gluonnlp\loss
#   copying src\gluonnlp\loss\activation_regularizer.py -> build\lib.win-amd64-cpython-38\gluonnlp\loss
#   copying src\gluonnlp\loss\label_smoothing.py -> build\lib.win-amd64-cpython-38\gluonnlp\loss
#   copying src\gluonnlp\loss\loss.py -> build\lib.win-amd64-cpython-38\gluonnlp\loss
#   copying src\gluonnlp\loss\__init__.py -> build\lib.win-amd64-cpython-38\gluonnlp\loss
#   creating build\lib.win-amd64-cpython-38\gluonnlp\metric
#   copying src\gluonnlp\metric\length_normalized_loss.py -> build\lib.win-amd64-cpython-38\gluonnlp\metric
#   copying src\gluonnlp\metric\masked_accuracy.py -> build\lib.win-amd64-cpython-38\gluonnlp\metric
#   copying src\gluonnlp\metric\__init__.py -> build\lib.win-amd64-cpython-38\gluonnlp\metric
#   creating build\lib.win-amd64-cpython-38\gluonnlp\model
#   copying src\gluonnlp\model\attention_cell.py -> build\lib.win-amd64-cpython-38\gluonnlp\model
#   copying src\gluonnlp\model\bert.py -> build\lib.win-amd64-cpython-38\gluonnlp\model
#   copying src\gluonnlp\model\bilm_encoder.py -> build\lib.win-amd64-cpython-38\gluonnlp\model
#   copying src\gluonnlp\model\block.py -> build\lib.win-amd64-cpython-38\gluonnlp\model
#   copying src\gluonnlp\model\convolutional_encoder.py -> build\lib.win-amd64-cpython-38\gluonnlp\model
#   copying src\gluonnlp\model\elmo.py -> build\lib.win-amd64-cpython-38\gluonnlp\model
#   copying src\gluonnlp\model\highway.py -> build\lib.win-amd64-cpython-38\gluonnlp\model
#   copying src\gluonnlp\model\info.py -> build\lib.win-amd64-cpython-38\gluonnlp\model
#   copying src\gluonnlp\model\language_model.py -> build\lib.win-amd64-cpython-38\gluonnlp\model
#   copying src\gluonnlp\model\lstmpcellwithclip.py -> build\lib.win-amd64-cpython-38\gluonnlp\model
#   copying src\gluonnlp\model\parameter.py -> build\lib.win-amd64-cpython-38\gluonnlp\model
#   copying src\gluonnlp\model\sampled_block.py -> build\lib.win-amd64-cpython-38\gluonnlp\model
#   copying src\gluonnlp\model\seq2seq_encoder_decoder.py -> build\lib.win-amd64-cpython-38\gluonnlp\model
#   copying src\gluonnlp\model\sequence_sampler.py -> build\lib.win-amd64-cpython-38\gluonnlp\model
#   copying src\gluonnlp\model\transformer.py -> build\lib.win-amd64-cpython-38\gluonnlp\model
#   copying src\gluonnlp\model\translation.py -> build\lib.win-amd64-cpython-38\gluonnlp\model
#   copying src\gluonnlp\model\utils.py -> build\lib.win-amd64-cpython-38\gluonnlp\model
#   copying src\gluonnlp\model\__init__.py -> build\lib.win-amd64-cpython-38\gluonnlp\model
#   creating build\lib.win-amd64-cpython-38\gluonnlp\optimizer
#   copying src\gluonnlp\optimizer\bert_adam.py -> build\lib.win-amd64-cpython-38\gluonnlp\optimizer
#   copying src\gluonnlp\optimizer\__init__.py -> build\lib.win-amd64-cpython-38\gluonnlp\optimizer
#   creating build\lib.win-amd64-cpython-38\gluonnlp\utils
#   copying src\gluonnlp\utils\files.py -> build\lib.win-amd64-cpython-38\gluonnlp\utils
#   copying src\gluonnlp\utils\parallel.py -> build\lib.win-amd64-cpython-38\gluonnlp\utils
#   copying src\gluonnlp\utils\parameter.py -> build\lib.win-amd64-cpython-38\gluonnlp\utils
#   copying src\gluonnlp\utils\seed.py -> build\lib.win-amd64-cpython-38\gluonnlp\utils
#   copying src\gluonnlp\utils\version.py -> build\lib.win-amd64-cpython-38\gluonnlp\utils
#   copying src\gluonnlp\utils\__init__.py -> build\lib.win-amd64-cpython-38\gluonnlp\utils
#   creating build\lib.win-amd64-cpython-38\gluonnlp\vocab
#   copying src\gluonnlp\vocab\bert.py -> build\lib.win-amd64-cpython-38\gluonnlp\vocab
#   copying src\gluonnlp\vocab\elmo.py -> build\lib.win-amd64-cpython-38\gluonnlp\vocab
#   copying src\gluonnlp\vocab\subwords.py -> build\lib.win-amd64-cpython-38\gluonnlp\vocab
#   copying src\gluonnlp\vocab\vocab.py -> build\lib.win-amd64-cpython-38\gluonnlp\vocab
#   copying src\gluonnlp\vocab\__init__.py -> build\lib.win-amd64-cpython-38\gluonnlp\vocab
#   creating build\lib.win-amd64-cpython-38\gluonnlp\data\batchify
#   copying src\gluonnlp\data\batchify\batchify.py -> build\lib.win-amd64-cpython-38\gluonnlp\data\batchify
#   copying src\gluonnlp\data\batchify\embedding.py -> build\lib.win-amd64-cpython-38\gluonnlp\data\batchify
#   copying src\gluonnlp\data\batchify\language_model.py -> build\lib.win-amd64-cpython-38\gluonnlp\data\batchify
#   copying src\gluonnlp\data\batchify\__init__.py -> build\lib.win-amd64-cpython-38\gluonnlp\data\batchify
#   creating build\lib.win-amd64-cpython-38\gluonnlp\data\bert
#   copying src\gluonnlp\data\bert\glue.py -> build\lib.win-amd64-cpython-38\gluonnlp\data\bert
#   copying src\gluonnlp\data\bert\squad.py -> build\lib.win-amd64-cpython-38\gluonnlp\data\bert
#   copying src\gluonnlp\data\bert\__init__.py -> build\lib.win-amd64-cpython-38\gluonnlp\data\bert
#   creating build\lib.win-amd64-cpython-38\gluonnlp\data\corpora
#   copying src\gluonnlp\data\corpora\google_billion_word.py -> build\lib.win-amd64-cpython-38\gluonnlp\data\corpora
#   copying src\gluonnlp\data\corpora\large_text_compression_benchmark.py -> build\lib.win-amd64-cpython-38\gluonnlp\data\corpora
#   copying src\gluonnlp\data\corpora\wikitext.py -> build\lib.win-amd64-cpython-38\gluonnlp\data\corpora
#   copying src\gluonnlp\data\corpora\__init__.py -> build\lib.win-amd64-cpython-38\gluonnlp\data\corpora
#   creating build\lib.win-amd64-cpython-38\gluonnlp\data\xlnet
#   copying src\gluonnlp\data\xlnet\squad.py -> build\lib.win-amd64-cpython-38\gluonnlp\data\xlnet
#   copying src\gluonnlp\data\xlnet\__init__.py -> build\lib.win-amd64-cpython-38\gluonnlp\data\xlnet
#   creating build\lib.win-amd64-cpython-38\gluonnlp\model\train
#   copying src\gluonnlp\model\train\cache.py -> build\lib.win-amd64-cpython-38\gluonnlp\model\train
#   copying src\gluonnlp\model\train\embedding.py -> build\lib.win-amd64-cpython-38\gluonnlp\model\train
#   copying src\gluonnlp\model\train\language_model.py -> build\lib.win-amd64-cpython-38\gluonnlp\model\train
#   copying src\gluonnlp\model\train\__init__.py -> build\lib.win-amd64-cpython-38\gluonnlp\model\train
#   running egg_info
#   writing src\gluonnlp.egg-info\PKG-INFO
#   writing dependency_links to src\gluonnlp.egg-info\dependency_links.txt
#   writing requirements to src\gluonnlp.egg-info\requires.txt
#   writing top-level names to src\gluonnlp.egg-info\top_level.txt
#   reading manifest file 'src\gluonnlp.egg-info\SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no files found matching '*.py' under directory 'gluonnlp'
#   warning: no previously-included files matching '*' found under directory 'tests'
#   warning: no previously-included files matching '*' found under directory 'scripts'
#   adding license file 'LICENSE'
#   writing manifest file 'src\gluonnlp.egg-info\SOURCES.txt'
#   copying src\gluonnlp\data\fast_bert_tokenizer.c -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\fast_bert_tokenizer.pyx -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   running build_ext
#   skipping 'src/gluonnlp/data\fast_bert_tokenizer.c' Cython extension (up-to-date)
#   building 'gluonnlp.data.fast_bert_tokenizer' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for gluonnlp
#   error: subprocess-exited-with-error
#
#   Running setup.py install for gluonnlp did not run successfully.
#   exit code: 1
#
#   [126 lines of output]
#   running install
#   C:\Users\seoye\anaconda3\envs\python3.8\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#     warnings.warn(
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-38
#   creating build\lib.win-amd64-cpython-38\gluonnlp
#   copying src\gluonnlp\base.py -> build\lib.win-amd64-cpython-38\gluonnlp
#   copying src\gluonnlp\_constants.py -> build\lib.win-amd64-cpython-38\gluonnlp
#   copying src\gluonnlp\__init__.py -> build\lib.win-amd64-cpython-38\gluonnlp
#   creating build\lib.win-amd64-cpython-38\gluonnlp\calibration
#   copying src\gluonnlp\calibration\collector.py -> build\lib.win-amd64-cpython-38\gluonnlp\calibration
#   copying src\gluonnlp\calibration\__init__.py -> build\lib.win-amd64-cpython-38\gluonnlp\calibration
#   creating build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\baidu_ernie_data.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\candidate_sampler.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\classification.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\conll.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\dataloader.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\dataset.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\datasetloader.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\glue.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\intent_slot.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\question_answering.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\registry.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\sampler.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\sentiment.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\stream.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\super_glue.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\transforms.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\translation.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\utils.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\word_embedding_evaluation.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\__init__.py -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   creating build\lib.win-amd64-cpython-38\gluonnlp\embedding
#   copying src\gluonnlp\embedding\evaluation.py -> build\lib.win-amd64-cpython-38\gluonnlp\embedding
#   copying src\gluonnlp\embedding\token_embedding.py -> build\lib.win-amd64-cpython-38\gluonnlp\embedding
#   copying src\gluonnlp\embedding\__init__.py -> build\lib.win-amd64-cpython-38\gluonnlp\embedding
#   creating build\lib.win-amd64-cpython-38\gluonnlp\initializer
#   copying src\gluonnlp\initializer\initializer.py -> build\lib.win-amd64-cpython-38\gluonnlp\initializer
#   copying src\gluonnlp\initializer\__init__.py -> build\lib.win-amd64-cpython-38\gluonnlp\initializer
#   creating build\lib.win-amd64-cpython-38\gluonnlp\loss
#   copying src\gluonnlp\loss\activation_regularizer.py -> build\lib.win-amd64-cpython-38\gluonnlp\loss
#   copying src\gluonnlp\loss\label_smoothing.py -> build\lib.win-amd64-cpython-38\gluonnlp\loss
#   copying src\gluonnlp\loss\loss.py -> build\lib.win-amd64-cpython-38\gluonnlp\loss
#   copying src\gluonnlp\loss\__init__.py -> build\lib.win-amd64-cpython-38\gluonnlp\loss
#   creating build\lib.win-amd64-cpython-38\gluonnlp\metric
#   copying src\gluonnlp\metric\length_normalized_loss.py -> build\lib.win-amd64-cpython-38\gluonnlp\metric
#   copying src\gluonnlp\metric\masked_accuracy.py -> build\lib.win-amd64-cpython-38\gluonnlp\metric
#   copying src\gluonnlp\metric\__init__.py -> build\lib.win-amd64-cpython-38\gluonnlp\metric
#   creating build\lib.win-amd64-cpython-38\gluonnlp\model
#   copying src\gluonnlp\model\attention_cell.py -> build\lib.win-amd64-cpython-38\gluonnlp\model
#   copying src\gluonnlp\model\bert.py -> build\lib.win-amd64-cpython-38\gluonnlp\model
#   copying src\gluonnlp\model\bilm_encoder.py -> build\lib.win-amd64-cpython-38\gluonnlp\model
#   copying src\gluonnlp\model\block.py -> build\lib.win-amd64-cpython-38\gluonnlp\model
#   copying src\gluonnlp\model\convolutional_encoder.py -> build\lib.win-amd64-cpython-38\gluonnlp\model
#   copying src\gluonnlp\model\elmo.py -> build\lib.win-amd64-cpython-38\gluonnlp\model
#   copying src\gluonnlp\model\highway.py -> build\lib.win-amd64-cpython-38\gluonnlp\model
#   copying src\gluonnlp\model\info.py -> build\lib.win-amd64-cpython-38\gluonnlp\model
#   copying src\gluonnlp\model\language_model.py -> build\lib.win-amd64-cpython-38\gluonnlp\model
#   copying src\gluonnlp\model\lstmpcellwithclip.py -> build\lib.win-amd64-cpython-38\gluonnlp\model
#   copying src\gluonnlp\model\parameter.py -> build\lib.win-amd64-cpython-38\gluonnlp\model
#   copying src\gluonnlp\model\sampled_block.py -> build\lib.win-amd64-cpython-38\gluonnlp\model
#   copying src\gluonnlp\model\seq2seq_encoder_decoder.py -> build\lib.win-amd64-cpython-38\gluonnlp\model
#   copying src\gluonnlp\model\sequence_sampler.py -> build\lib.win-amd64-cpython-38\gluonnlp\model
#   copying src\gluonnlp\model\transformer.py -> build\lib.win-amd64-cpython-38\gluonnlp\model
#   copying src\gluonnlp\model\translation.py -> build\lib.win-amd64-cpython-38\gluonnlp\model
#   copying src\gluonnlp\model\utils.py -> build\lib.win-amd64-cpython-38\gluonnlp\model
#   copying src\gluonnlp\model\__init__.py -> build\lib.win-amd64-cpython-38\gluonnlp\model
#   creating build\lib.win-amd64-cpython-38\gluonnlp\optimizer
#   copying src\gluonnlp\optimizer\bert_adam.py -> build\lib.win-amd64-cpython-38\gluonnlp\optimizer
#   copying src\gluonnlp\optimizer\__init__.py -> build\lib.win-amd64-cpython-38\gluonnlp\optimizer
#   creating build\lib.win-amd64-cpython-38\gluonnlp\utils
#   copying src\gluonnlp\utils\files.py -> build\lib.win-amd64-cpython-38\gluonnlp\utils
#   copying src\gluonnlp\utils\parallel.py -> build\lib.win-amd64-cpython-38\gluonnlp\utils
#   copying src\gluonnlp\utils\parameter.py -> build\lib.win-amd64-cpython-38\gluonnlp\utils
#   copying src\gluonnlp\utils\seed.py -> build\lib.win-amd64-cpython-38\gluonnlp\utils
#   copying src\gluonnlp\utils\version.py -> build\lib.win-amd64-cpython-38\gluonnlp\utils
#   copying src\gluonnlp\utils\__init__.py -> build\lib.win-amd64-cpython-38\gluonnlp\utils
#   creating build\lib.win-amd64-cpython-38\gluonnlp\vocab
#   copying src\gluonnlp\vocab\bert.py -> build\lib.win-amd64-cpython-38\gluonnlp\vocab
#   copying src\gluonnlp\vocab\elmo.py -> build\lib.win-amd64-cpython-38\gluonnlp\vocab
#   copying src\gluonnlp\vocab\subwords.py -> build\lib.win-amd64-cpython-38\gluonnlp\vocab
#   copying src\gluonnlp\vocab\vocab.py -> build\lib.win-amd64-cpython-38\gluonnlp\vocab
#   copying src\gluonnlp\vocab\__init__.py -> build\lib.win-amd64-cpython-38\gluonnlp\vocab
#   creating build\lib.win-amd64-cpython-38\gluonnlp\data\batchify
#   copying src\gluonnlp\data\batchify\batchify.py -> build\lib.win-amd64-cpython-38\gluonnlp\data\batchify
#   copying src\gluonnlp\data\batchify\embedding.py -> build\lib.win-amd64-cpython-38\gluonnlp\data\batchify
#   copying src\gluonnlp\data\batchify\language_model.py -> build\lib.win-amd64-cpython-38\gluonnlp\data\batchify
#   copying src\gluonnlp\data\batchify\__init__.py -> build\lib.win-amd64-cpython-38\gluonnlp\data\batchify
#   creating build\lib.win-amd64-cpython-38\gluonnlp\data\bert
#   copying src\gluonnlp\data\bert\glue.py -> build\lib.win-amd64-cpython-38\gluonnlp\data\bert
#   copying src\gluonnlp\data\bert\squad.py -> build\lib.win-amd64-cpython-38\gluonnlp\data\bert
#   copying src\gluonnlp\data\bert\__init__.py -> build\lib.win-amd64-cpython-38\gluonnlp\data\bert
#   creating build\lib.win-amd64-cpython-38\gluonnlp\data\corpora
#   copying src\gluonnlp\data\corpora\google_billion_word.py -> build\lib.win-amd64-cpython-38\gluonnlp\data\corpora
#   copying src\gluonnlp\data\corpora\large_text_compression_benchmark.py -> build\lib.win-amd64-cpython-38\gluonnlp\data\corpora
#   copying src\gluonnlp\data\corpora\wikitext.py -> build\lib.win-amd64-cpython-38\gluonnlp\data\corpora
#   copying src\gluonnlp\data\corpora\__init__.py -> build\lib.win-amd64-cpython-38\gluonnlp\data\corpora
#   creating build\lib.win-amd64-cpython-38\gluonnlp\data\xlnet
#   copying src\gluonnlp\data\xlnet\squad.py -> build\lib.win-amd64-cpython-38\gluonnlp\data\xlnet
#   copying src\gluonnlp\data\xlnet\__init__.py -> build\lib.win-amd64-cpython-38\gluonnlp\data\xlnet
#   creating build\lib.win-amd64-cpython-38\gluonnlp\model\train
#   copying src\gluonnlp\model\train\cache.py -> build\lib.win-amd64-cpython-38\gluonnlp\model\train
#   copying src\gluonnlp\model\train\embedding.py -> build\lib.win-amd64-cpython-38\gluonnlp\model\train
#   copying src\gluonnlp\model\train\language_model.py -> build\lib.win-amd64-cpython-38\gluonnlp\model\train
#   copying src\gluonnlp\model\train\__init__.py -> build\lib.win-amd64-cpython-38\gluonnlp\model\train
#   running egg_info
#   writing src\gluonnlp.egg-info\PKG-INFO
#   writing dependency_links to src\gluonnlp.egg-info\dependency_links.txt
#   writing requirements to src\gluonnlp.egg-info\requires.txt
#   writing top-level names to src\gluonnlp.egg-info\top_level.txt
#   reading manifest file 'src\gluonnlp.egg-info\SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no files found matching '*.py' under directory 'gluonnlp'
#   warning: no previously-included files matching '*' found under directory 'tests'
#   warning: no previously-included files matching '*' found under directory 'scripts'
#   adding license file 'LICENSE'
#   writing manifest file 'src\gluonnlp.egg-info\SOURCES.txt'
#   copying src\gluonnlp\data\fast_bert_tokenizer.c -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   copying src\gluonnlp\data\fast_bert_tokenizer.pyx -> build\lib.win-amd64-cpython-38\gluonnlp\data
#   running build_ext
#   skipping 'src/gluonnlp/data\fast_bert_tokenizer.c' Cython extension (up-to-date)
#   building 'gluonnlp.data.fast_bert_tokenizer' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# Encountered error while trying to install package.
#
# gluonnlp
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp38-cp38-win_amd64.whl (1.1 MB)
#      ---------------------------------------- 1.1/1.1 MB 6.5 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.97
# Collecting transformers==3.0.2
#   Using cached transformers-3.0.2-py3-none-any.whl (769 kB)
# Requirement already satisfied: tqdm>=4.27 in c:\users\seoye\anaconda3\envs\python3.8\lib\site-packages (from transformers==3.0.2) (4.64.1)
# Collecting regex!=2019.12.17
#   Downloading regex-2022.9.11-cp38-cp38-win_amd64.whl (263 kB)
#      -------------------------------------- 263.1/263.1 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in c:\users\seoye\anaconda3\envs\python3.8\lib\site-packages (from transformers==3.0.2) (3.8.0)
# Requirement already satisfied: sentencepiece!=0.1.92 in c:\users\seoye\anaconda3\envs\python3.8\lib\site-packages (from transformers==3.0.2) (0.1.97)
# Requirement already satisfied: packaging in c:\users\seoye\anaconda3\envs\python3.8\lib\site-packages (from transformers==3.0.2) (21.3)
# Requirement already satisfied: numpy in c:\users\seoye\anaconda3\envs\python3.8\lib\site-packages (from transformers==3.0.2) (1.23.3)
# Collecting tokenizers==0.8.1.rc1
#   Downloading tokenizers-0.8.1rc1-cp38-cp38-win_amd64.whl (1.9 MB)
#      ---------------------------------------- 1.9/1.9 MB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: requests in c:\users\seoye\anaconda3\envs\python3.8\lib\site-packages (from transformers==3.0.2) (2.18.4)
# Collecting sacremoses
#   Using cached sacremoses-0.0.53.tar.gz (880 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: colorama in c:\users\seoye\anaconda3\envs\python3.8\lib\site-packages (from tqdm>=4.27->transformers==3.0.2) (0.4.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\seoye\anaconda3\envs\python3.8\lib\site-packages (from packaging->transformers==3.0.2) (3.0.9)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in c:\users\seoye\anaconda3\envs\python3.8\lib\site-packages (from requests->transformers==3.0.2) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\seoye\anaconda3\envs\python3.8\lib\site-packages (from requests->transformers==3.0.2) (2022.6.15)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\seoye\anaconda3\envs\python3.8\lib\site-packages (from requests->transformers==3.0.2) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in c:\users\seoye\anaconda3\envs\python3.8\lib\site-packages (from requests->transformers==3.0.2) (2.6)
# Requirement already satisfied: six in c:\users\seoye\anaconda3\envs\python3.8\lib\site-packages (from sacremoses->transformers==3.0.2) (1.16.0)
# Collecting click
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Collecting joblib
#   Using cached joblib-1.1.0-py2.py3-none-any.whl (306 kB)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py): started
#   Building wheel for sacremoses (setup.py): finished with status 'done'
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895241 sha256=5e301fa815490620be92a6a6ea0cbabfc3be43d825bccb87bf534f883c607189
#   Stored in directory: c:\users\seoye\appdata\local\pip\cache\wheels\82\ab\9b\c15899bf659ba74f623ac776e861cf2eb8608c1825ddec66a4
# Successfully built sacremoses
# Installing collected packages: tokenizers, regex, joblib, click, sacremoses, transformers
# Successfully installed click-8.1.3 joblib-1.1.0 regex-2022.9.11 sacremoses-0.0.53 tokenizers-0.8.1rc1 transformers-3.0.2
# Collecting torch
#   Downloading torch-1.12.1-cp38-cp38-win_amd64.whl (161.9 MB)
#      -------------------------------------- 161.9/161.9 MB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in c:\users\seoye\anaconda3\envs\python3.8\lib\site-packages (from torch) (4.3.0)
# Installing collected packages: torch
# Successfully installed torch-1.12.1
